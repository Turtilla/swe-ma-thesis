# %% [markdown]
# # MARMOT EVALUATION

# %% [markdown]
# ### IMPORTS, VARIABLES

# %%
import conllu
import sklearn.metrics
import pandas as pd
import matplotlib.pyplot as plt
import time

pd.set_option('display.max_rows', None)

# %%
xpos_predictions = './marmot/test_hist_XPOS.out.txt'
upos_predictions = './marmot/test_hist_UPOS.out.txt'

xpos_standard = './marmot/test_hist_XPOS.txt'
upos_standard = './marmot/test_hist_UPOS.txt'

test_predictions = './marmot/test.out.txt'
test_standard = './marmot/test.txt'

# %%
from functions import get_measures, extract_conllu_data, get_comparison

# %% [markdown]
# ### FUNCTIONS

# %%
def get_marmot_tags_and_tokens(filename: str):
    with open(filename) as f:
        tags = f.readlines()
        tokens = [x.strip().split()[0] for x in tags if len(x.strip()) > 0]
        upos = [x.strip().split()[1] for x in tags if len(x.strip()) > 0]
        xpos = [x.strip().split()[2] for x in tags if len(x.strip()) > 0]
        
    return tokens, upos, xpos

# %% [markdown]
# ### EXECUTION - STANDARD
# Since unlike the BERT-based tagger Marmot does not output any training/evaluation/testing measures, I need to obtain them myself from contemporary test data.

# %%
# Marmot returns files in a CoNLL-2009 format; it can still be parsed using conllu and my function, but the names of
# the features do not match; here 'feats' corresponds to UPOS tags and 'deprel' to XPOS.
test_tokens, test_upos_preds = extract_conllu_data(test_predictions, 'feats', sentences=False, fulltext=False)
test_tokens, test_xpos_preds = extract_conllu_data(test_predictions, 'deprel', sentences=False, fulltext=False)
# Due to the issue mentioned above, UPOS tags need to be further processed.
test_upos_preds = [list(x.keys())[0] for x in test_upos_preds]

# %%
# Retrieving the gold standard tags
_, test_upos_standard, test_xpos_standard = get_marmot_tags_and_tokens(test_standard)

# %%
get_measures(test_upos_standard, test_upos_preds, details=True)
# Out:
# MEASURES:
# Accuracy: 97.73%
# Precision (weighted): 97.75%
# Recall (weighted): 97.73%
# F1 (weighted): 97.73%
# Matthew's Correlation Coefficient: 97.38%
#
# MEASURES PER CLASS:
# Precision:
# 	ADJ: 97.25%
# 	ADP: 99.46%
# 	ADV: 95.59%
# 	AUX: 91.67%
# 	CCONJ: 96.17%
# 	DET: 98.44%
# 	INTJ: 46.15%
# 	NOUN: 98.23%
# 	NUM: 98.04%
# 	PART: 93.49%
# 	PRON: 99.05%
# 	PROPN: 91.30%
# 	PUNCT: 99.95%
# 	SCONJ: 96.49%
# 	SYM: 100.00%
# 	VERB: 97.96%
# 	X: 89.33%
# Recall:
# 	ADJ: 97.71%
# 	ADP: 99.74%
# 	ADV: 95.33%
# 	AUX: 95.60%
# 	CCONJ: 96.26%
# 	DET: 96.93%
# 	INTJ: 60.00%
# 	NOUN: 98.04%
# 	NUM: 94.34%
# 	PART: 92.42%
# 	PRON: 98.31%
# 	PROPN: 94.09%
# 	PUNCT: 99.95%
# 	SCONJ: 96.21%
# 	SYM: 25.00%
# 	VERB: 97.43%
# 	X: 86.73%

# %%
get_measures(test_xpos_standard, test_xpos_preds)  # measures per class are not as informative here
# Out:
# MEASURES:
# Accuracy: 89.27%
# Precision (weighted): 88.95%
# Recall (weighted): 89.27%
# F1 (weighted): 88.81%
# Matthew's Correlation Coefficient: 88.83%

# %% [markdown]
# ### EXECUTION - PREDICTIONS

# %%
# The same is done with the historical data.
hist_upos_tokens, hist_upos_preds = extract_conllu_data(upos_predictions, 'feats', sentences=False, fulltext=False)
hist_xpos_tokens, hist_xpos_preds = extract_conllu_data(xpos_predictions, 'deprel', sentences=False, fulltext=False)

hist_upos_preds = [list(x.keys())[0] for x in hist_upos_preds]

# %%
# Retrieving the gold standard tags - since we have two different files for XPOS and UPOS annotations we need two function calls
_, hist_upos_standard, _ = get_marmot_tags_and_tokens(upos_standard)
_, _, hist_xpos_standard = get_marmot_tags_and_tokens(xpos_standard)

# %%
get_measures(hist_upos_standard, hist_upos_preds, details=True)
# Out:
# MEASURES:
# Accuracy: 90.19%
# Precision (weighted): 90.35%
# Recall (weighted): 90.19%
# F1 (weighted): 90.18%
# Matthew's Correlation Coefficient: 88.86%
#
# MEASURES PER CLASS:
# Precision:
# 	ADJ: 80.48%
# 	ADP: 99.49%
# 	ADV: 85.03%
# 	AUX: 82.26%
# 	CCONJ: 97.20%
# 	DET: 93.47%
# 	NOUN: 89.12%
# 	NUM: 96.97%
# 	PART: 76.38%
# 	PRON: 90.87%
# 	PROPN: 78.65%
# 	PUNCT: 100.00%
# 	SCONJ: 86.26%
# 	VERB: 91.32%
# 	X: 63.16%
# Recall:
# 	ADJ: 84.61%
# 	ADP: 98.74%
# 	ADV: 83.78%
# 	AUX: 85.83%
# 	CCONJ: 95.94%
# 	DET: 74.82%
# 	NOUN: 90.79%
# 	NUM: 72.73%
# 	PART: 73.43%
# 	PRON: 85.71%
# 	PROPN: 86.04%
# 	PUNCT: 100.00%
# 	SCONJ: 91.00%
# 	VERB: 91.88%
# 	X: 50.70%

# %%
get_measures(hist_xpos_standard, hist_xpos_preds)
# Out:
# MEASURES:
# Accuracy: 78.78%
# Precision (weighted): 79.73%
# Recall (weighted): 78.78%
# F1 (weighted): 78.39%
# Matthew's Correlation Coefficient: 78.11%

# %%
comparison_upos = get_comparison(hist_upos_standard, hist_upos_preds, hist_upos_tokens)
comparison_upos.to_excel('../data/mistakes/marmot_UPOS_mistakes.xlsx')

# %%
comparison_xpos = get_comparison(hist_xpos_standard, hist_xpos_preds, hist_xpos_tokens)
comparison_xpos.to_excel('../data/mistakes/marmot_XPOS_mistakes.xlsx')

# %%
comparison_upos
# Out:
#                  Token Gold Standard Prediction
# 0             Melchior         PROPN       NOUN
# 1            Komornika          NOUN      PROPN
# 2                    ś             X        AUX
# 3           Pinińskich         PROPN        ADJ
# 4                 Dóbr          NOUN      PROPN
# 5              Dąbrowy         PROPN        ADJ
# 6                   śp             X       NOUN
# 7         Dobrzyńskiej         PROPN        ADJ
# 8                Panna          NOUN      PROPN
# 9                   śp             X       NOUN
# 10            Melchior         PROPN       NOUN
# 11               jedną           NUM        ADJ
# 12              Ciotka          NOUN      PROPN
# 13                  17           NUM        ADJ
# 14                było           AUX       VERB
# 15             Niewiem          VERB       PART
# 16              jakoby         SCONJ       PART
# 17               Dziad          NOUN      PROPN
# 18                jego           DET       PRON
# 19            Starostą          NOUN      PROPN
# 20           Potockich         PROPN        ADJ
# 21                jego           DET       PRON
# 22          chłopczyna          NOUN        ADJ
# 23                  to          PRON        AUX
# 24               jeden           NUM        ADJ
# 25            Starosta          NOUN      PROPN
# 26              rychło           ADV       NOUN
# 27                 tak           ADV       PART
# 28             Patrona          NOUN      PROPN
# 29                Panu          NOUN      PROPN
# 30                Myśl          NOUN       VERB
# 31                Panu          NOUN      PROPN
# 32                Panu          NOUN      PROPN
# 33          Szczęśliwa           ADJ       NOUN
# 34              Dziada          NOUN      PROPN
# 35                jego           DET       PRON
# 36                Panu          NOUN      PROPN
# 37                 był           AUX       VERB
# 38                 owe           DET        ADJ
# 39              piękny           ADJ       NOUN
# 40                 tem          PRON       NOUN
# 41                jego           DET       PRON
# 42                  to           AUX       PRON
# 43                 być           AUX       VERB
# 44            Halickim           ADJ      PROPN
# 45               Panną          NOUN      PROPN
# 46            Kobylską         PROPN        ADJ
# 47               Około          PART        ADP
# 48            Dzianott         PROPN       NOUN
# 49                  by         SCONJ        AUX
# 50                rada           ADJ       NOUN
# 51            gosposia          NOUN        ADJ
# 52              Jesteś          VERB        AUX
# 53               wdowa          NOUN        ADJ
# 54             wdowiec          NOUN       VERB
# 55                  że         SCONJ       PART
# 56                więc         CCONJ      SCONJ
# 57              Pannie          NOUN        ADV
# 58             Dziekan          NOUN      PROPN
# 59              Oyciec          NOUN      PROPN
# 60             osiedli          VERB       NOUN
# 61               Babki          NOUN      PROPN
# 62                pono          PART       VERB
# 63        Czermińskiej         PROPN        ADJ
# 64               druga           ADJ       NOUN
# 65       Świeżawskiego         PROPN        ADJ
# 66             Cyrkule          NOUN      PROPN
# 67          Samborskim         PROPN        ADJ
# 68               jeden           NUM        ADJ
# 69               oddał          VERB       NOUN
# 70               Abbum             X      PROPN
# 71         Treterianum             X      PROPN
# 72               Lwowa         PROPN        ADJ
# 73             została          VERB        AUX
# 74          zniszczały          VERB       NOUN
# 75                jego           DET       PRON
# 76                  to          PART      SCONJ
# 77                  to          PART      SCONJ
# 78           oświecony          VERB        ADJ
# 79               Zaraz           ADV       PART
# 80                Tobą          PRON      PROPN
# 81                tyle           DET        ADV
# 82                 mię          PRON       NOUN
# 83                zato          PRON       VERB
# 84                  Ci          PRON        DET
# 85                 Bóg          NOUN      PROPN
# 86                 ich           DET       PRON
# 87         Świerzawski         PROPN        ADJ
# 88        Polanowskich         PROPN        ADJ
# 89            oblegany           ADJ       NOUN
# 90                 móy           DET        ADJ
# 91             służąca          NOUN        ADJ
# 92             Niewiem          VERB       NOUN
# 93          Treterówną         PROPN        ADJ
# 94          Treterówną         PROPN        ADJ
# 95                  aż          PART      SCONJ
# 96                 nim          PRON      SCONJ
# 97                 móy           DET       NOUN
# 98                 być           AUX       VERB
# 99          podpodczas           ADP       NOUN
# 100             Cobary             X      PROPN
# 101             Ułanów          NOUN      PROPN
# 102                 14           NUM          X
# 103           niewiele           DET        ADV
# 104                  ś             X        AUX
# 105          najwięcej           ADJ        DET
# 106             Oyciec          NOUN      PROPN
# 107                móy           DET        ADJ
# 108             Oyciec          NOUN      PROPN
# 109              około           ADP       PART
# 110               1808           ADJ        NUM
# 111               1809           ADJ          X
# 112                był          VERB        AUX
# 113             pieszy           ADJ       VERB
# 114          skrzętnem           ADJ       NOUN
# 115                tem          PRON       NOUN
# 116                set           NUM       NOUN
# 117      Rozwadowskiej         PROPN        ADJ
# 118      Rozwadowskiej         PROPN        ADJ
# 119           Dziedzic          NOUN      PROPN
# 120            któremi           DET       NOUN
# 121          pierwszey           ADJ       NOUN
# 122                Zaś         CCONJ        ADP
# 123               byli          VERB        AUX
# 124                 ci          PRON        DET
# 125              pewną           ADJ        DET
# 126                 ci          PRON        DET
# 127               tego           DET       PRON
# 128              jeden           NUM        ADJ
# 129               tego           DET       PRON
# 130                 ci          PRON       NOUN
# 131             spaśne          NOUN        ADJ
# 132              pewną           ADJ        DET
# 133          pastwisko          NOUN        ADV
# 134             Wieleż           DET       NOUN
# 135                 to          PART        AUX
# 136               jego           DET       PRON
# 137             suchey           ADJ       NOUN
# 138       nayskładniey           ADV       NOUN
# 139             Niebył           AUX       VERB
# 140                 to           AUX       PRON
# 141         Oycowskiey           ADJ      PROPN
# 142                tak         CCONJ        ADV
# 143            poddani          NOUN        ADJ
# 144             takiem           DET       NOUN
# 145                tak           ADV       PART
# 146               Herb          NOUN      PROPN
# 147          Dziedzica          NOUN      PROPN
# 148             dokoła           ADP        ADV
# 149           Dominium          NOUN      PROPN
# 150       Nieszlachcic          NOUN      PROPN
# 151           Dziedzic          NOUN      PROPN
# 152             swojem           DET       NOUN
# 153      Mandatariusza          NOUN      PROPN
# 154                Był          VERB        AUX
# 155            dopokąd         SCONJ        ADV
# 156            Dominii          NOUN      PROPN
# 157                  A         CCONJ       PART
# 158            chociaż         SCONJ       PART
# 159              ktoby          PRON       NOUN
# 160          szlachcic          NOUN       VERB
# 161          poddanych          NOUN        ADJ
# 162                móy           DET        ADJ
# 163               tego           DET       PRON
# 164           ludowemi           ADJ       NOUN
# 165              lizną          VERB        ADJ
# 166             trochę           DET        ADV
# 167             trochę           DET        ADV
# 168              prawa          NOUN        ADJ
# 169        manipulacyi          NOUN       VERB
# 170          urzędowey           ADJ       NOUN
# 171         Starostwie          NOUN      PROPN
# 172            Cyrkule          NOUN      PROPN
# 173      Mandataryusza          NOUN      PROPN
# 174       Mandatyrusza          NOUN      PROPN
# 175           Dziedzic          NOUN      PROPN
# 176       Mandataryusz          NOUN      PROPN
# 177               opał          NOUN       VERB
# 178          Dziedzica          NOUN      PROPN
# 179            dotacyi          NOUN       VERB
# 180                one           DET       PRON
# 181                  4           NUM          X
# 182               żyta          NOUN        ADJ
# 183                  1           NUM        ADJ
# 184                 fl             X       NOUN
# 185                 10           NUM          X
# 186            przytem          PRON       NOUN
# 187                 ci           DET       PRON
# 188              ładąn           ADJ          X
# 189                 fl             X       NOUN
# 190                móy           DET        ADJ
# 191              jeden           NUM        ADJ
# 192               jego           DET       PRON
# 193                 to          PART        AUX
# 194             dokoła           ADP        ADV
# 195            niewiem          VERB       NOUN
# 196                czy          PART      CCONJ
# 197                czy          PART      CCONJ
# 198            naprzód           ADP        ADV
# 199               Panu          NOUN      PROPN
# 200        Dziedzicowi          NOUN      PROPN
# 201                móy           DET        ADJ
# 202         człowiecze          NOUN       VERB
# 203                  A         CCONJ       PART
# 204           Dziedzic          NOUN      PROPN
# 205               jego           DET       PRON
# 206             Takich           DET        ADJ
# 207              mojey           DET       NOUN
# 208                owe           DET        ADJ
# 209                był          VERB        AUX
# 210            jaszcze          PART        ADJ
# 211          księżunio          NOUN      CCONJ
# 212                  I         CCONJ       PART
# 213             późney           ADV      SCONJ
# 214                móy           DET        ADJ
# 215               Toje             X      PROPN
# 216               diło             X       VERB
# 217             daruju             X       NOUN
# 218         ukochanomu             X       NOUN
# 219               Synu             X       NOUN
# 220             mojomu             X       NOUN
# 221         Mychayłowu             X      PROPN
# 222              iOycu          NOUN      PROPN
# 223                móy           DET        ADJ
# 224                tak          PART        ADV
# 225               Oyca          NOUN      PROPN
# 226               pono          PART       VERB
# 227               1813           ADJ          X
# 228               1814           ADJ          X
# 229                móy           DET       NOUN
# 230             Siebie          PRON      PROPN
# 231               Oyca          NOUN      PROPN
# 232                Nim          PRON      PROPN
# 233                móy           DET        ADJ
# 234                 Mu          PRON      PROPN
# 235             Doktor          NOUN      PROPN
# 236                ile           ADV        DET
# 237               1826           ADJ          X
# 238               pono          PART       VERB
# 239           niewinem          VERB       NOUN
# 240         Zabilskich         PROPN        ADJ
# 241           jedynaka          NOUN        ADJ
# 242             Oyciec          NOUN      PROPN
# 243              Oycem          NOUN      PROPN
# 244                 24           NUM        ADJ
# 245              Matkę          NOUN      PROPN
# 246               temu           DET        ADP
# 247               pono          PART       VERB
# 248            Dorchów         PROPN       NOUN
# 249             więcey           ADV        ADJ
# 250              wgłos           ADV       NOUN
# 251                Był          VERB        AUX
# 252                tey           DET       NOUN
# 253                 ci          PRON        DET
# 254           niemogli          VERB       NOUN
# 255           nietylko          PART        ADV
# 256            czeladź          NOUN       VERB
# 257              sądny           ADJ       NOUN
# 258           niemożna          VERB        ADJ
# 259                mim          PRON        ADJ
# 260               Oyca          NOUN      PROPN
# 261           rodzonym           ADJ       NOUN
# 262         Treterowej         PROPN        ADJ
# 263               Oyca          NOUN      PROPN
# 264              Panną          NOUN        ADJ
# 265         Świeżyńską         PROPN        ADJ
# 266           urodzoną           ADJ       NOUN
# 267         Zawadzkich         PROPN        ADJ
# 268          Stryiskim         PROPN        ADJ
# 269        Kruszelnicę         PROPN       NOUN
# 270             jednem           NUM       NOUN
# 271                  2           NUM        ADJ
# 272              Panny          NOUN      PROPN
# 273              Panna          NOUN      PROPN
# 274           Rudzkich         PROPN        ADJ
# 275                tąd           ADV       NOUN
# 276              Jakby         SCONJ       PART
# 277                jey          PRON       NOUN
# 278           niemogła          VERB       NOUN
# 279            osiadły           ADJ       VERB
# 280              Panny          NOUN      PROPN
# 281              niema          VERB       NOUN
# 282               Panu          NOUN      PROPN
# 283         niechciało          VERB        ADV
# 284               hoża           ADJ       NOUN
# 285              Panna          NOUN      PROPN
# 286               Było           AUX       VERB
# 287                 to           AUX       PRON
# 288              około           ADP       PART
# 289               tego           DET       PRON
# 290               była          VERB        AUX
# 291        Siemiginowa         PROPN        ADJ
# 292         Bałamuciła          VERB       NOUN
# 293              około           ADP       PART
# 294                 24           ADJ        NUM
# 295          liczącego          VERB       NOUN
# 296          próżniaka          NOUN       VERB
# 297          Separacya          NOUN      PROPN
# 298            secundo             X        ADV
# 299               voto             X       VERB
# 300              Mosty         PROPN       NOUN
# 301              Panną          NOUN        ADJ
# 302             Ciotką          NOUN      PROPN
# 303                jak         SCONJ        ADV
# 304                móy           DET        ADJ
# 305           Bludniki         PROPN       NOUN
# 306              Matce          NOUN      PROPN
# 307                wuy          NOUN        ADJ
# 308               Oyca          NOUN      PROPN
# 309                 Mu          PRON      PROPN
# 310              Pannę          NOUN      PROPN
# 311        Ostaszewską         PROPN        ADJ
# 312          Chorążego          NOUN      PROPN
# 313          Kawaleryi          NOUN      PROPN
# 314          Narodowey           ADJ      PROPN
# 315          Dziedzica          NOUN      PROPN
# 316          Załęskich         PROPN        ADJ
# 317              Jakoż         CCONJ      PROPN
# 318                 Go          PRON      PROPN
# 319       Ostaszewskim         PROPN        ADJ
# 320               Oycu          NOUN       INTJ
# 321              Panna          NOUN      PROPN
# 322                Jey           DET        ADJ
# 323       etykietalney           ADJ       NOUN
# 324          pierwszey           ADJ       NOUN
# 325             został          VERB        AUX
# 326               Veni             X        ADJ
# 327               vici             X       NOUN
# 328            Niewiem          VERB      SCONJ
# 329             swojey           DET       NOUN
# 330                 al             X       NOUN
# 331             fresco             X       NOUN
# 332            Bludnik         PROPN       NOUN
# 333              Skała          NOUN       VERB
# 334               niey          PRON        ADJ
# 335            Łomnica         PROPN       NOUN
# 336                  Ś             X      PROPN
# 337     tegoStanisława             X      PROPN
# 338            Łomnicą         PROPN       NOUN
# 339           Dniestru         PROPN       NOUN
# 340                 to           AUX      SCONJ
# 341              Ruiny          NOUN      PROPN
# 342             opodal           ADP        ADV
# 343              droga          NOUN        ADJ
# 344               niey          PRON       NOUN
# 345      nayjświętszey           ADJ       NOUN
# 346              Panny          NOUN      PROPN
# 347              daley           ADV        ADJ
# 348                jak           ADV      SCONJ
# 349           Swiętego           ADJ      PROPN
# 350                 to          PRON        DET
# 351           podobnem           ADJ       NOUN
# 352       niespotkałem          VERB        ADV
# 353          Łańcuckim         PROPN        ADJ
# 354                jak           ADV      SCONJ
# 355                  i         CCONJ       PART
# 356            łamiąca           ADJ       VERB
# 357              skałą          NOUN        ADJ
# 358             wysoką           ADJ       NOUN
# 359              ujęta          VERB        ADJ
# 360             strome           ADJ       NOUN
# 361            Łomnicy         PROPN       NOUN
# 362              Skała          NOUN       VERB
# 363           tysiącem           NUM       NOUN
# 364       przyjezdnych          NOUN        ADJ
# 365         Bludnickey           ADJ      PROPN
# 366            Karpaty         PROPN       NOUN
# 367              droga          NOUN        ADJ
# 368           spaśnemi           ADJ       NOUN
# 369         przedewsią          NOUN       VERB
# 370            okolony           ADJ       NOUN
# 371            główney           ADJ       NOUN
# 372              prawo           ADV       NOUN
# 373             prawey           ADJ       NOUN
# 374              gumna          NOUN        ADJ
# 375            staynie          NOUN        ADV
# 376           oddziela          VERB          X
# 377           pośrodku           ADP        ADV
# 378         kamiennemi           ADJ       NOUN
# 379                tey           DET       NOUN
# 380          proporcyi          NOUN       VERB
# 381                jak           ADV      SCONJ
# 382                był          VERB        AUX
# 383               Oyca          NOUN      PROPN
# 384                  ś             X        AUX
# 385              Dziad          NOUN      PROPN
# 386           Wracając          NOUN       VERB
# 387                był          VERB        AUX
# 388             gładki           ADJ       NOUN
# 389              tylko          PART      CCONJ
# 390              szale          NOUN        ADV
# 391              takoż           ADV        ADP
# 392             obicie          NOUN      CCONJ
# 393          jedwabney           ADJ       NOUN
# 394               Sala          NOUN      PROPN
# 395             freski          NOUN        ADJ
# 396                jak           ADV      SCONJ
# 397               dziś          NOUN        ADV
# 398                jak         SCONJ        ADV
# 399              niemi          PRON       NOUN
# 400             takowy           DET        ADJ
# 401                tey           DET       NOUN
# 402               była          VERB        AUX
# 403            zarosła           ADJ       VERB
# 404            trzciną          NOUN        ADJ
# 405          widocznie           ADV       PART
# 406                 to           DET        AUX
# 407                był          VERB        AUX
# 408              Skała          NOUN       VERB
# 409       nieciosanemi           ADJ       NOUN
# 410                ani          PART      CCONJ
# 411           Swiętego          NOUN      PROPN
# 412             jednem           NUM        ADJ
# 413          widocznie           ADV       PART
# 414              Jakoż         SCONJ       PART
# 415                tem          PRON       NOUN
# 416          arędujący          VERB        ADJ
# 417                tey           DET       NOUN
# 418          zuchwałey           ADJ       NOUN
# 419           Oyciciec          NOUN       VERB
# 420               jego           DET       PRON
# 421               była          VERB        AUX
# 422         wszystkich           DET       PRON
# 423           zwodzony           ADJ       NOUN
# 424             Oyciec          NOUN      PROPN
# 425                móy           DET       VERB
# 426                Był          VERB        AUX
# 427               most          NOUN        ADV
# 428             niebył           AUX       VERB
# 429              cegły          NOUN        ADJ
# 430                czy          PART      CCONJ
# 431            jeźdźca          NOUN        ADJ
# 432             wprost          PART        ADV
# 433           murujący          VERB        ADJ
# 434                mię          PRON       NOUN
# 435               dwór          NOUN          X
# 436           okoloney           ADJ       NOUN
# 437                jej           DET       PRON
# 438       szczuplejszy           ADJ       NOUN
# 439             dokoła           ADP        ADV
# 440             czółno          NOUN        ADV
# 441             rześki           ADJ       NOUN
# 442             swojim           DET        ADJ
# 443            Kresach         PROPN       NOUN
# 444              oczem          PRON       NOUN
# 445             piękna           ADJ       NOUN
# 446      obywatelskiey           ADJ       NOUN
# 447            Matrona          NOUN      PROPN
# 448                był           AUX       VERB
# 449              całem           ADJ       NOUN
# 450               jako           ADV      SCONJ
# 451                owe           DET        ADJ
# 452           wzorowem           ADJ       NOUN
# 453            niebyło          VERB        ADV
# 454             prawie           ADV       PART
# 455                czy          PART      CCONJ
# 456             niebył           AUX       VERB
# 457        skoligacony           ADJ       NOUN
# 458      Ostaszewskich         PROPN        ADJ
# 459               Była          VERB        AUX
# 460              Matka          NOUN      PROPN
# 461                  A         CCONJ       PART
# 462      Ostaszewskiej         PROPN        ADJ
# 463                jey           DET       NOUN
# 464               tego           DET       PRON
# 465                 to          PART        AUX
# 466                móy           DET        ADJ
# 467             Oyciec          NOUN      PROPN
# 468             Swojey           DET      PROPN
# 469                móy           DET        ADJ
# 470                owe           DET        ADJ
# 471           gniadych           ADJ       NOUN
# 472    Simiginowskiego           ADJ      PROPN
# 473              Czyli         CCONJ       VERB
# 474                owe           DET        ADJ
# 475                 fl             X       NOUN
# 476                 to          PRON        AUX
# 477      Kopestyńskich         PROPN        ADJ
# 478         kochającey           ADJ       NOUN
# 479               lubo         SCONJ      CCONJ
# 480                 to          PART      SCONJ
# 481                 Ją          PRON        ADJ
# 482         Sanoczanie         PROPN       NOUN
# 483              niemi          PRON       NOUN
# 484             troski          NOUN        ADJ
# 485             jedney           ADJ       NOUN
# 486              Matkę          NOUN      PROPN
# 487               było           AUX       VERB
# 488              małem           ADJ       NOUN
# 489               niey          PRON        ADJ
# 490                ten          PRON        DET
# 491             Chrztu          NOUN      PROPN
# 492         niechciały          VERB       NOUN
# 493              ponim          PRON       PART
# 494           nietylko         CCONJ        ADV
# 495           troygiem           NUM       NOUN
# 496          pomarłemi           ADJ       VERB
# 497           okrywały          VERB        ADJ
# 498               były          VERB        AUX
# 499               pono          PART       VERB
# 500             Oyciec          NOUN      PROPN
# 501    naypięknieyszey           ADJ       NOUN
# 502                ani          PART      CCONJ
# 503             świeci          VERB       NOUN
# 504            Łomnicy         PROPN       NOUN
# 505                tak          PART        ADV
# 506            Dniestr         PROPN       NOUN
# 507         Łomnickiey           ADJ      PROPN
# 508                nim         SCONJ       PRON
# 509             Oyciec          NOUN       VERB
# 510            została          VERB        AUX
# 511             szkoda          NOUN       VERB
# 512                owe           DET        ADJ
# 513         stanowiąca           ADJ       NOUN
# 514                owe           DET        ADJ
# 515            fortuny          NOUN        ADJ
# 516                  a         CCONJ       PART
# 517           egzamina          NOUN       VERB
# 518                825           ADJ          X
# 519              febra          NOUN       VERB
# 520                mię          PRON       NOUN
# 521          niemogłem          VERB        ADV
# 522                jey          PRON       PART
# 523                 to          PART       PRON
# 524                 to          PRON        AUX
# 525               1821           ADJ          X
# 526                tak          PART        ADV
# 527           niemiano          VERB        ADP
# 528             Troska          NOUN        ADJ
# 529             obojga           NUM       NOUN
# 530                mię          PRON       NOUN
# 531       zatrętwiałem          VERB       NOUN
# 532                mię          PRON       NOUN
# 533             nieraz          NOUN        ADV
# 534                mię          PRON       NOUN
# 535            została          VERB        AUX
# 536              tempy           ADJ       NOUN
# 537                mię          PRON       NOUN
# 538             kupsze          NOUN       VERB
# 539              Biało           ADV       VERB
# 540             dużemi           ADJ       NOUN
# 541              zawoy          NOUN        ADJ
# 542          wzorzysta           ADJ       NOUN
# 543                jak           ADV      SCONJ
# 544                tey          PRON       NOUN
# 545               teme           DET       NOUN
# 546         niekontent           ADJ       NOUN
# 547                mię          PRON       NOUN
# 548            poufale           ADV       VERB
# 549                 to          PRON       PART
# 550               było           AUX       VERB
# 551                  x             X       NOUN
# 552                  6           NUM        ADJ
# 553                  x             X       NOUN
# 554                  3           NUM        ADJ
# 555                  x             X       NOUN
# 556               pono          PART       VERB
# 557               1811           ADJ          X
# 558                  A         CCONJ       PART
# 559                mię          PRON       NOUN
# 560               taże          PART      SCONJ
# 561               Więc         CCONJ      SCONJ
# 562                czy          PART      CCONJ
# 563                mię          PRON       NOUN
# 564                one           DET       PRON
# 565                tey           DET       NOUN
# 566               dużo           DET        ADV
# 567               hożą           ADJ       NOUN
# 568               tęga           ADJ       NOUN
# 569            modrych           ADJ       NOUN
# 570         ciemnoblnd           ADJ      CCONJ
# 571          roumianey           ADJ       NOUN
# 572            owalney           ADJ       NOUN
# 573            śniadey           ADJ       NOUN
# 574               Była          NOUN        AUX
# 575         przystoyna           ADJ       NOUN
# 576          jednająca          VERB        ADJ
# 577              mojey           DET       NOUN
# 578              Panem          NOUN      PROPN
# 579       naymłodszych           ADJ       NOUN
# 580              Matkę          NOUN      PROPN
# 581                tak           ADV       PART
# 582                mię          PRON       NOUN
# 583                tym           DET       PRON
# 584           nietylko          PART        ADV
# 585       Golejowskich         PROPN        ADJ
# 586            nietyle          PART        ADV
# 587              Panem          NOUN      PROPN
# 588              Panią          NOUN        ADJ
# 589       Czarnomskich         PROPN        ADJ
# 590         Golejowską         PROPN        ADJ
# 591        naywiększey           ADJ       NOUN
# 592            odemnie          PRON        ADV
# 593             swojey           DET       NOUN
# 594            późniey           ADV       NOUN
# 595               swóy           DET        ADJ
# 596                ich           DET       PRON
# 597             obadwa           NUM       NOUN
# 598               mało           ADV        DET
# 599             Oyciec          NOUN      PROPN
# 600                móy           DET        ADJ
# 601       Czortkowskim         PROPN        ADJ
# 602               pono          PART       VERB
# 603         skończoney           ADJ       NOUN
# 604              wdowa          NOUN       VERB
# 605                 Co           ADP       PART
# 606            młodych           ADJ       NOUN
# 607       Golejowskich         PROPN        ADJ
# 608               byli           AUX       VERB
# 609               Oyca          NOUN      PROPN
# 610             Kornel         PROPN       NOUN
# 611           Łosiówną          VERB      PROPN
# 612         Szczęsnego         PROPN        ADJ
# 613               dziś          NOUN        ADV
# 614        poczciwości          NOUN       VERB
# 615                jak           ADV      SCONJ
# 616               były          VERB        AUX
# 617            Luboscy         PROPN        ADJ
# 618              jedną           NUM        ADJ
# 619             ułomną           ADJ       VERB
# 620            milutka           ADJ       NOUN
# 621            powiena           ADJ       NOUN
# 622               pono          PART       VERB
# 623                 ci          PRON        DET
# 624            jakoteż         CCONJ        DET
# 625           Woyniłów         PROPN       NOUN
# 626      Kopystyńskich         PROPN        ADJ
# 627           Żelibory         PROPN      SCONJ
# 628      Kunaszowskich         PROPN        ADJ
# 629             jednem           ADJ       NOUN
# 630               obie           NUM       NOUN
# 631                831           ADJ          X
# 632                był          VERB        AUX
# 633            późniey           ADV        ADJ
# 634                Ten          PRON        DET
# 635                móy           DET        ADJ
# 636             Oyciec          NOUN      PROPN
# 637              Panem          NOUN      PROPN
# 638          niebędzie          VERB        ADV
# 639             zawadą          NOUN       VERB
# 640              mojeg           DET          X
# 641               Oyca          NOUN      PROPN
# 642             jestem          VERB        AUX
# 643               Oycu          NOUN      PROPN
# 644             zżadka           ADV       NOUN
# 645              bywał           AUX       VERB
# 646               byli           AUX       VERB
# 647             Oyciec          NOUN      PROPN
# 648               były          VERB        AUX
# 649             ormian         PROPN       NOUN
# 650           niemogła          VERB        ADV
# 651            Zabawne           ADV        ADJ
# 652               było          VERB        AUX
# 653        najzabawney           ADV       NOUN
# 654             bawiła          VERB       NOUN
# 655              tamtą          PRON       NOUN
# 656            zaczęty           ADJ       NOUN
# 657                 tu          PART        ADV
# 658             niewie          VERB       PART
# 659              która          PRON        DET
# 660                 to          PART       PRON
# 661                  A         CCONJ       PART
# 662              Panny          NOUN      PROPN
# 663             chwała          NOUN       VERB
# 664               Bogu          NOUN      PROPN
# 665                 ba          PART       NOUN
# 666                tem           DET       NOUN
# 667             Będzie          VERB        AUX
# 668                jak           ADV      SCONJ
# 669               temi           DET        ADJ
# 670           Godebska         PROPN        ADJ
# 671            Virtuti             X      PROPN
# 672           Militari             X      PROPN
# 673         Rzeźbiarza          NOUN      PROPN
# 674            obedwie           NUM       PART
# 675             jedney           ADJ       NOUN
# 676                móy           DET        ADJ
# 677            niewiem          VERB        ADV
# 678                jak           ADV      SCONJ
# 679              całey           ADJ       NOUN
# 680              jakby         SCONJ       PART
# 681             jedney           ADJ       NOUN
# 682             drugey           ADJ       NOUN
# 683                był           AUX       VERB
# 684           Ludwików         PROPN       NOUN
# 685           Rylskich         PROPN        ADJ
# 686          Ludwikowa         PROPN        ADJ
# 687                one           DET       PRON
# 688                Był           AUX       VERB
# 689             brudny           ADJ       NOUN
# 690             jednak         CCONJ       PART
# 691              Oycem          NOUN      PROPN
# 692              jedną           NUM        ADJ
# 693              Panną          NOUN        ADJ
# 694             Oyciec          NOUN      PROPN
# 695              Matka          NOUN      PROPN
# 696         gospodarzy          VERB       NOUN
# 697         Eustachego         PROPN        ADJ
# 698              młodo           ADV       NOUN
# 699               jego           DET       PRON
# 700        Obertyńskim         PROPN        ADJ
# 701       Szamanowskim         PROPN        ADJ
# 702       Rozwadowskim         PROPN        ADJ
# 703               Stoy          VERB       NOUN
# 704               stoy          VERB       NOUN
# 705             wywruż          VERB       PRON
# 706          niebędzie           AUX       NOUN
# 707                moi           DET       NOUN
# 708           Wiktorów         PROPN       NOUN
# 709      Ruszczewskich         PROPN        ADJ
# 710       Mociumdzieju          NOUN      PROPN
# 711            ogoloną           ADJ       NOUN
# 712                 to          PART       PRON
# 713                one           DET       PRON
# 714            dbający          VERB        ADJ
# 715             żonaty           ADJ       NOUN
# 716            Janicką         PROPN        ADJ
# 717               dużo           ADV        DET
# 718          naywięcej           ADV        ADJ
# 719          oryginała          NOUN       VERB
# 720            dawniey           ADV       NOUN
# 721                był           AUX       VERB
# 722         naystarsza           ADJ       NOUN
# 723             starey           ADJ       NOUN
# 724             Pannie          NOUN      PROPN
# 725                był           AUX       VERB
# 726               1830           ADJ          X
# 727               Oycu          NOUN      PROPN
# 728              mojey           DET       NOUN
# 729                móy           DET        ADJ
# 730             Oyciec          NOUN       VERB
# 731               jego           DET       PRON
# 732              Oycem          NOUN      PROPN
# 733             żonaty           ADJ       NOUN
# 734               jego           DET       PRON
# 735               pono          PART       VERB
# 736            niewiem          VERB       NOUN
# 737      Kunaszowskich         PROPN        ADJ
# 738          Oyczyźnie          NOUN      PROPN
# 739              Dziad          NOUN        ADP
# 740            pierwey           ADV       NOUN
# 741   Rzeczypospolitej          NOUN      PROPN
# 742                tem          PRON       NOUN
# 743           jadałney           ADJ       NOUN
# 744               Było           AUX       VERB
# 745           dziewięć           NUM       NOUN
# 746             więcej           ADV        DET
# 747              stali          NOUN        ADJ
# 748              okuci           ADJ       NOUN
# 749            niewiem          VERB       NOUN
# 750                czy          PART      CCONJ
# 751                owe           DET        ADJ
# 752        familiinemi           ADJ       NOUN
# 753            niemiec         PROPN       NOUN
# 754             opodal           ADP        ADV
# 755               Oyca          NOUN      PROPN
# 756         respektowa          NOUN        ADJ
# 757      Kunaszowskich         PROPN        ADJ
# 758                  ś             X        AUX
# 759            Swojego           DET      PROPN
# 760        Dobrodzieja          NOUN      PROPN
# 761                jey          PRON        ADJ
# 762               niey          PRON       NOUN
# 763          Paniczowi          NOUN      PROPN
# 764                ten          PRON        DET
# 765               Rano           ADV       NOUN
# 766              jakby         SCONJ       PART
# 767             odmowa          NOUN        ADJ
# 768                 aż          PART      SCONJ
# 769                jey          PRON       NOUN
# 770            niechay           AUX        ADJ
# 771                 aż          PART      SCONJ
# 772             będzie           AUX       VERB
# 773               Oyca          NOUN      PROPN
# 774         ociemniała           ADJ       VERB
# 775              prawi          VERB        ADJ
# 776                tem          PRON       NOUN
# 777              krępy           ADJ       NOUN
# 778              dużey           ADJ       NOUN
# 779           dziubaty           ADJ       NOUN
# 780            ogolony           ADJ       NOUN
# 781        ciaśnieysze           ADJ       NOUN
# 782           potrzeba          NOUN       VERB
# 783        zapalczywie           ADV       VERB
# 784              jeden           NUM        ADJ
# 785             piękne           ADV        ADJ
# 786             drapią          VERB       NOUN
# 787              wdowa          NOUN        ADJ
# 788            Niewiem          VERB      SCONJ
# 789               pono          PART       VERB
# 790            późniey           ADV       NOUN
# 791       Stanisławowa         PROPN        ADJ
# 792          Rafałoska         PROPN        ADJ
# 793               pono          PART       VERB
# 794               pono          PART       VERB
# 795       Michałoskich         PROPN        ADJ
# 796           wydawały          VERB       NOUN
# 797                owe           DET        ADJ
# 798               dziś           ADJ        ADV
# 799              cięto          VERB        ADV
# 800              jeden           NUM        ADJ
# 801                jak           ADV      SCONJ
# 802             Obadwa           NUM       NOUN
# 803             zasobą          PRON       NOUN
# 804            któremi           DET       NOUN
# 805             Kuzyna          NOUN      PROPN
# 806                  i         CCONJ       PART
# 807            niewiem          VERB      SCONJ
# 808               Zięć          NOUN       VERB
# 809               jego           DET       PRON
# 810             cieląt          NOUN          X
# 811             obydwa           NUM       NOUN
# 812              całem           ADJ       NOUN
# 813             pensya          NOUN        ADJ
# 814        Dyrektorska           ADJ       NOUN
# 815      Galicyiskiego           ADJ      PROPN
# 816                  i         CCONJ       PART
# 817                 to          PRON       PART
# 818             niebył           AUX       VERB
# 819               tęgi           ADJ       NOUN
# 820             pomimo           ADP        ADV
# 821          Inżyniryi          NOUN      PROPN
# 822                czy          PART      CCONJ
# 823           chłopski           ADJ       NOUN
# 824            przytem          PRON       NOUN
# 825                tem          PRON       NOUN
# 826           cywilney           ADJ       NOUN
# 827         poselskiey           ADJ       NOUN
# 828               jego           DET       PRON
# 829           Szczutka         PROPN       NOUN
# 830    przedstawiający          VERB        ADJ
# 831          śmieszney           ADJ       NOUN
# 832               Seym          NOUN      PROPN
# 833               Jego           DET       PRON
# 834             Obadwa           NUM       NOUN
# 835               byli           AUX       VERB
# 836               może          PART       VERB
# 837         powinowaci           ADJ       VERB
# 838               byli           AUX       VERB
# 839                 to          PART        DET
# 840             bywali           AUX       VERB
# 841        sympatyczni           ADJ       NOUN
# 842             Kuzyną          NOUN      PROPN
# 843        Jenerałówną          NOUN        ADJ
# 844          Drewnicką         PROPN       NOUN
# 845       Drewnickiego         PROPN        ADJ
# 846         Jenerałowa          NOUN      PROPN
# 847            Jenerał          NOUN      PROPN
# 848          Załęskiey         PROPN       NOUN
# 849           urodzony           ADJ       NOUN
# 850        Ostaszewska         PROPN        ADJ
# 851               Oyca          NOUN      PROPN
# 852                Jey           DET        ADJ
# 853                jak         SCONJ        ADV
# 854           Grochowa         PROPN        ADJ
# 855        wynędzniali           ADJ       VERB
# 856             czarni           ADJ       NOUN
# 857         obszarpani           ADJ       NOUN
# 858             raźnie           ADV       NOUN
# 859           zuchwało           ADV       VERB
# 860               Boże          NOUN        ADJ
# 861                móy           DET       NOUN
# 862               Boże          NOUN        ADJ
# 863             Jakież           DET       PART
# 864                 to          PRON       PART
# 865        uwolnionymi          NOUN        ADJ
# 866                 10           NUM          X
# 867                 to          PART       PRON
# 868             Spiewy          NOUN      PROPN
# 869               Oyca          NOUN      PROPN
# 870              zbuje          NOUN       VERB
# 871               Oyca          NOUN      PROPN
# 872                 to          PRON        AUX
# 873            niebyło          VERB       NOUN
# 874            jednego           NUM        ADJ
# 875                móy           DET        ADJ
# 876            Ocyciec          NOUN      PROPN
# 877                 to           AUX       PRON
# 878               może          PART       VERB
# 879                Jey           DET       NOUN
# 880                był          VERB        AUX
# 881               może          PART       VERB
# 882       Chomińskiego         PROPN        ADJ
# 883         Gubernator          NOUN      PROPN
# 884                tem          PRON       NOUN
# 885                tey           DET       NOUN
# 886         Samborskim         PROPN        ADJ
# 887              chory           ADJ       NOUN
# 888                tey           DET       NOUN
# 889                830           ADJ          X
# 890           narodowy          NOUN        ADJ
# 891              około           ADP       PART
# 892               Panu          NOUN      PROPN
# 893                ten          PRON        DET
# 894               2000           NUM        ADJ
# 895            Dukatów          NOUN      PROPN
# 896                  5             X        NUM
# 897        ciorodzieci             X       VERB
# 898            Dukatów          NOUN      PROPN
# 899             jakiem           DET       NOUN
# 900                tem          PRON       NOUN
# 901                tey           DET       NOUN
# 902                jak           ADV      SCONJ
# 903               Kasy          NOUN      PROPN
# 904             Oyciec          NOUN      PROPN
# 905        Gubernatora          NOUN      PROPN
# 906           niepomnę          VERB       NOUN
# 907               Oycu          NOUN      PROPN
# 908    niewytrzymałyby          VERB       NOUN
# 909             jakiem           DET       NOUN
# 910                809           ADJ          X
# 911            niemców         PROPN       NOUN
# 912             Dziada          NOUN       VERB
# 913                  i         CCONJ       PART
# 914                tak           ADV       PART
# 915                 co          PART       PRON
# 916      Jabłonowskich         PROPN        ADJ
# 917              Panną          NOUN        ADJ
# 918              Matkę          NOUN      PROPN
# 919           Apolonią         PROPN        ADJ
# 920           Ludwisię           ADP      PROPN
# 921              Matki          NOUN      PROPN
# 922            Podoską         PROPN        ADJ
# 923            zamężną           ADJ       VERB
# 924               była          VERB        AUX
# 925                jej           DET       PRON
# 926          Łepkowska         PROPN        ADJ
# 927          normalney           ADJ       NOUN
# 928              Panem          NOUN      PROPN
# 929               byli           AUX       VERB
# 930             karemi           ADJ       NOUN
# 931              końmi          NOUN        ADJ
# 932         wykręcania          NOUN       VERB
# 933               jest           AUX       VERB
# 934             dodana          VERB        ADJ
# 935             lekcye          NOUN        ADJ
# 936              Panny          NOUN      PROPN
# 937               czem          PRON       NOUN
# 938             takiey           DET       NOUN
# 939                był           AUX       VERB
# 940                 aż          PART      SCONJ
# 941          brzęczały          VERB       NOUN
# 942            dostawa          VERB       NOUN
# 943            niebyli           AUX       VERB
# 944        sprzęgnięci           ADJ       NOUN
# 945               wtem          PRON       NOUN
# 946                 to          PRON        DET
# 947                  A         CCONJ       PART
# 948                 to          PART       PRON
# 949              cięgi          NOUN        ADJ
# 950     Przybyszewskie         PROPN        ADJ
# 951               obje           NUM       VERB
# 952           posiedzi          VERB       NOUN
# 953              czemu           ADV       PRON
# 954           nieidzie          VERB        ADV
# 955                 bo         SCONJ       PART
# 956               wnet           ADV       NOUN
# 957          psipiólki          NOUN        ADJ
# 958                 by         SCONJ        AUX
# 959                jey          PRON        ADJ
# 960               dway           NUM       NOUN
# 961              Matki          NOUN      PROPN
# 962                jak           ADV      SCONJ
# 963              Niebu          NOUN      PROPN
# 964            została          VERB        AUX
# 965               1831           ADJ          X
# 966          spiżarnię          NOUN       VERB
# 967          dostatnią           ADJ       NOUN
# 968             prawie           ADV       PART
# 969                ten          PRON        DET
# 970              jakby         SCONJ       PART
# 971              Nieba          NOUN      PROPN
# 972         Golejowska         PROPN        ADJ
# 973              póyść          VERB       NOUN
# 974                  i         CCONJ       PART
# 975                tak           ADV       PART
# 976        Rafałoskiej         PROPN        ADJ
# 977              ognia          VERB       NOUN
# 978                móy           DET        ADJ
# 979                mię          PRON       NOUN
# 980               samą           ADJ       NOUN
# 981        Ostaszewską         PROPN        ADJ
# 982                Jey           DET      PROPN
# 983             późney           ADV      CCONJ
# 984                 fl             X       NOUN
# 985             Uherce         PROPN       NOUN
# 986     Niezabitowskie         PROPN        ADJ
# 987                Wuy          NOUN      PROPN
# 988            otwarty           ADJ       NOUN
# 989       Czermińskich         PROPN        ADJ
# 990           urodzony           ADJ       NOUN
# 991         Skarbkowie         PROPN       NOUN
# 992        urzędniczym           ADJ       NOUN
# 993        Arcyksięcia          NOUN      PROPN
# 994       Arcybiskupów          NOUN      PROPN
# 995                Wuy          NOUN      PROPN
# 996             został          VERB        AUX
# 997             Stanów          NOUN      PROPN
# 998               Była          VERB        AUX
# 999             został          VERB        AUX
# 1000                to          PART        AUX
# 1001           niebyło           AUX       VERB
# 1002   nayszczęśliwsze           ADJ       NOUN
# 1003              Lubo         SCONJ      PROPN
# 1004           niebyło          VERB        ADV
# 1005           sądowey           ADJ       NOUN
# 1006           Włodzio         PROPN        ADV
# 1007             Matce          NOUN      PROPN
# 1008            Oyciec          NOUN       VERB

# %%
comparison_xpos
# Out:
#                 Token                     Gold Standard  \
# 0               Dziad                   subst:sg:nom:m1
# 1                 mój                 adj:sg:nom:m1:pos
# 2            Melchior                   subst:sg:nom:m1
# 3            urodzony                 adj:sg:nom:m1:pos
# 4          Godziszewo               subst:sg:nom:n:ncol
# 5             parafii                    subst:sg:loc:f
# 6              Rypnin                   subst:sg:nom:m3
# 7            starszym                adj:sg:inst:m1:com
# 8              bratem                  subst:sg:inst:m1
# 9                   ś                          brev:pun
# 10                  p                         brev:npun
# 11              matki                    subst:sg:gen:f
# 12         Pinińskich                   subst:pl:gen:m1
# 13               Dóbr                 subst:pl:gen:n:pt
# 14           Strużewo               subst:sg:nom:n:ncol
# 15            Dąbrowy                    subst:sg:gen:f
# 16                 śp                         brev:npun
# 17              Dziad                   subst:sg:nom:m1
# 18                mój                 adj:sg:nom:m1:pos
# 19                był                praet:sg:m1:imperf
# 20                  z                    prep:inst:nwok
# 21       najstarszemu                 adj:sg:dat:m1:sup
# 22              bratu                   subst:sg:dat:m1
# 23                ośm            num:pl:acc:m3:rec:ncol
# 24            Stryjów                   subst:pl:acc:m1
# 25               miał                praet:sg:m1:imperf
# 26                 śp                          brev:pun
# 27           Melchior                   subst:sg:nom:m1
# 28           czterech          num:pl:acc:m1:congr:ncol
# 29         ożenionego           ppas:sg:acc:m1:perf:aff
# 30             trzech          num:pl:acc:m3:congr:ncol
# 31              synów                   subst:pl:acc:m1
# 32             Jakuba                   subst:sg:acc:m1
# 33            Łukasza                   subst:sg:acc:m1
# 34           Floyrana                   subst:sg:acc:m1
# 35               syna                   subst:sg:acc:m1
# 36            Ludwika                   subst:sg:acc:m1
# 37         wszystkich                 adj:pl:acc:m1:pos
# 38              braci                   subst:pl:acc:m1
# 39       stryjecznych                 adj:pl:acc:m1:pos
# 40                 17                 num:pl:nom:m1:rec
# 41           Antonich                   subst:pl:gen:m1
# 42               brat                   subst:sg:nom:m1
# 43          Melchiora                   subst:sg:gen:m1
# 44            Niewiem                 fin:sg:pri:imperf
# 45              stryj                   subst:sg:nom:m1
# 46        zaopiekował                  praet:sg:m1:perf
# 47   młodzieniaszkiem                  subst:sg:inst:m1
# 48         wychowanie               subst:sg:acc:n:ncol
# 49              jakim                adj:sg:inst:m1:pos
# 50          Potockich                   subst:pl:gen:m1
# 51     prawdopodobnie                              part
# 52            Brzeżan                 subst:pl:gen:n:pt
# 53            Skolego               subst:sg:gen:n:ncol
# 54               Pana                   subst:sg:acc:m1
# 55           Starostę                   subst:sg:acc:m1
# 56         chłopczyna                   subst:sg:nom:m1
# 57                 co               subst:sg:nom:n:ncol
# 58                 go  ppron3:sg:acc:m1:ter:nakc:npraep
# 59             rychło                           adv:pos
# 60                tak                           adv:pos
# 61           Brzeżany                 subst:pl:nom:n:pt
# 62            Skolego               subst:sg:gen:n:ncol
# 63                 go  ppron3:sg:acc:m1:ter:nakc:npraep
# 64            Skolego               subst:sg:gen:n:ncol
# 65            intraty                    subst:sg:gen:f
# 66               Myśl                    subst:sg:nom:f
# 67           podobała                 praet:sg:f:imperf
# 68         Szczęśliwa                  adj:sg:nom:f:pos
# 69               jego   ppron3:sg:loc:m1:ter:akc:npraep
# 70             okazał                  praet:sg:m1:perf
# 71                mój                 adj:sg:nom:m1:pos
# 72              Dziad                   subst:sg:nom:m1
# 73                jak                           adv:pos
# 74             piękny                 adj:sg:nom:m3:pos
# 75              ujęty           ppas:sg:nom:m1:perf:aff
# 76                tem              subst:sg:inst:n:ncol
# 77                 to                              pred
# 78                jak                           adv:pos
# 79           Czołhany                 subst:pl:acc:n:pt
# 80           Halickim                 adj:sg:loc:m3:pos
# 81           Kobylską                   subst:sg:inst:f
# 82             trzech          num:pl:gen:m1:congr:ncol
# 83           owdowiał                  praet:sg:m1:perf
# 84             wołami                  subst:pl:inst:m2
# 85        Chyrowskiey                  adj:sg:loc:f:pos
# 86          zapędziły                  praet:pl:m2:perf
# 87               woły                   subst:pl:nom:m2
# 88               parę                  num:pl:acc:f:rec
# 89           Dzianott                    subst:sg:nom:f
# 90              wdowa                    subst:sg:nom:f
# 91              dwóch          num:pl:loc:m1:congr:ncol
# 92             mężach                   subst:pl:loc:m1
# 93                 by                              comp
# 94      wynagrodzeniu               subst:sg:loc:n:ncol
# 95             starym                 adj:sg:inst:n:pos
# 96              winem              subst:sg:inst:n:ncol
# 97               rada                  adj:sg:nom:f:pos
# 98           gosposia                    subst:sg:nom:f
# 99           gościowi                   subst:sg:dat:m1
# 100               oko                subst:sg:acc:n:col
# 101          Asińdźka                    subst:sg:voc:f
# 102             wdowa                    subst:sg:nom:f
# 103           wdowiec                   subst:sg:nom:m1
# 104                Ja              ppron12:sg:nom:f:pri
# 105                że                              comp
# 106                mi         ppron12:sg:dat:f:pri:nakc
# 107          Waszmość                   subst:sg:nom:m1
# 108           podobał                praet:sg:m1:imperf
# 109                co               subst:sg:nom:n:ncol
# 110          ucałował                  praet:sg:m1:perf
# 111            drżącą                  adj:sg:acc:f:pos
# 112            Pannie                    subst:sg:dat:f
# 113       submittować                          inf:perf
# 114              1784                     adj:sg:loc:m3
# 115              dwie           num:pl:nom:f:congr:ncol
# 116             córki                    subst:pl:nom:f
# 117            Starsi                 adj:pl:nom:m1:com
# 118            mojego                 adj:sg:gen:m1:pos
# 119              Ojca                   subst:sg:gen:m1
# 120             nauki                    subst:sg:gen:f
# 121           osiedli                  praet:pl:m1:perf
# 122             córki                    subst:pl:nom:f
# 123              pono                              part
# 124        Bolechowie               subst:sg:loc:n:ncol
# 125            bawiły                 praet:pl:n:imperf
# 126      Czermińskiej                    subst:sg:gen:f
# 127               mąż                              frag
# 128      szambelanica                   subst:sg:acc:m1
# 129             druga                  adj:sg:nom:f:pos
# 130     Świeżawskiego                   subst:sg:acc:m1
# 131         komornika                   subst:sg:acc:m1
# 132        ziemskiego                 adj:sg:acc:m1:pos
# 133        Maksymowic                   subst:sg:gen:m3
# 134               był                praet:sg:m1:imperf
# 135       szambelanem                  subst:sg:inst:m1
# 136    Poniatowskiego                   subst:sg:acc:m1
# 137            wielki                 adj:sg:nom:m1:pos
# 138           literat                   subst:sg:nom:m1
# 139               jak                           adv:pos
# 140               dwa          num:pl:nom:m3:congr:ncol
# 141            pokoje                   subst:pl:nom:m3
# 142             oddał                  praet:sg:m1:perf
# 143          akademii                    subst:sg:dat:f
# 144            oddany                 adj:sg:nom:m3:pos
# 145             Abbum                               ign
# 146       Treterianum                               ign
# 147             Lwowa                   subst:sg:gen:m3
# 148          obrucona                    subst:sg:nom:f
# 149              więc                              comp
# 150            zbiory                   subst:pl:nom:m3
# 151                te                 adj:pl:nom:m3:pos
# 152        zniszczały                  praet:pl:m3:perf
# 153               Syn                   subst:sg:nom:m1
# 154               mój                 adj:sg:nom:m1:pos
# 155               wuj                   subst:sg:nom:m1
# 156               był                praet:sg:m1:imperf
# 157          fantasta                   subst:sg:nom:m1
# 158          oryginał                   subst:sg:nom:m1
# 159            jakich                 adj:pl:gen:m1:pos
# 160                 i                              part
# 161            100000               num:pl:acc:m3:congr
# 162          polskich                 adj:pl:acc:m3:pos
# 163              jako                              conj
# 164          wielkimi                 adj:pl:inst:n:pos
# 165           dobrami                subst:pl:inst:n:pt
# 166        dzierżawił                praet:sg:m1:imperf
# 167         znajomych                   subst:pl:acc:m1
# 168             różne                  adj:pl:nom:f:pos
# 169              arye                    subst:pl:nom:f
# 170        krakowiaki                   subst:pl:nom:m3
# 171         kołomyjki                    subst:pl:nom:f
# 172                na                          prep:loc
# 173                po                          prep:acc
# 174         znajomych                   subst:pl:acc:m1
# 175           śpiewem                  subst:sg:inst:m3
# 176            mojego                 adj:sg:gen:m1:pos
# 177              Oyca                   subst:sg:gen:m1
# 178              dużo                 num:pl:gen:m3:rec
# 179              Oyca                    subst:sg:nom:f
# 180        Opowiadano                       imps:imperf
# 181                mi              subst:sg:acc:m1:ncol
# 182           pożycia             ger:sg:gen:n:perf:aff
# 183             moich                  adj:pl:gen:n:pos
# 184         oświecony                   subst:sg:nom:m3
# 185             Zaraz                               adv
# 186           czeladź                    subst:sg:nom:f
# 187               jak                           adv:pos
# 188      nieboszczyka                   subst:sg:gen:m1
# 189      nieboszczyka                   subst:sg:gen:m1
# 190              Tobą            ppron12:sg:inst:m1:sec
# 191            Stasiu                   subst:sg:voc:m1
# 192              tyle                 num:pl:nom:m3:rec
# 193              tyle                 num:pl:nom:m3:rec
# 194        Zostawiasz                 fin:sg:sec:imperf
# 195               mię        ppron12:sg:acc:m1:pri:nakc
# 196              kęsa                   subst:sg:gen:m3
# 197              zato               subst:sg:acc:n:ncol
# 198                Ci        ppron12:sg:dat:m1:sec:nakc
# 199      nieboszczyka                   subst:sg:acc:m1
# 200               ich    ppron3:pl:gen:n:ter:akc:npraep
# 201           rodziny                    subst:pl:acc:f
# 202             Drugi                 adj:sg:nom:m1:pos
# 203               mój                 adj:sg:nom:m1:pos
# 204               wuj                   subst:sg:nom:m1
# 205       Świerzawski                   subst:sg:nom:m1
# 206             kuzyn                   subst:sg:nom:m1
# 207      Polanowskich                   subst:pl:gen:m1
# 208         Bełzkiego               subst:sg:gen:n:ncol
# 209         Moszkowie               subst:sg:loc:n:ncol
# 210               Pań                    subst:pl:gen:f
# 211          oblegany         ppas:sg:nom:m1:imperf:aff
# 212         strojeniu           ger:sg:loc:n:imperf:aff
# 213         trefieniu           ger:sg:dat:n:imperf:aff
# 214           służąca                    subst:sg:nom:f
# 215         stopniach                   subst:pl:loc:m3
# 216      Komornikowej                    subst:sg:gen:f
# 217             dwóch            num:pl:nom:m1:rec:ncol
# 218             nauki                    subst:sg:gen:f
# 219           Niewiem                 fin:sg:pri:imperf
# 220         zniszczał                  praet:sg:m3:perf
# 221        Treterówną                   subst:sg:inst:f
# 222          nierobił                praet:sg:m1:imperf
# 223        Treterówną                   subst:sg:inst:f
# 224               nim  ppron3:sg:inst:m1:ter:akc:npraep
# 225          nierobił                   subst:sg:gen:m3
# 226               móy                 adj:sg:nom:m1:pos
# 227           sierota                   subst:sg:nom:m1
# 228            oddany           ppas:sg:nom:m1:perf:aff
# 229            niżeli                              conj
# 230                to                              pred
# 231             około                              part
# 232        podpodczas                          prep:gen
# 233           Sachsen                               ign
# 234            Cobary                               ign
# 235                14                 num:pl:acc:m3:rec
# 236          kadectwo               subst:sg:nom:n:ncol
# 237                 ś                          brev:pun
# 238                 p                         brev:npun
# 239             Oycem                  subst:sg:inst:m1
# 240  Młodzieniaszkiem                  subst:sg:inst:m1
# 241            oddany                 adj:sg:nom:m1:pos
# 242                 w                     prep:acc:nwok
# 243        sąsiedztwa               subst:pl:acc:n:ncol
# 244         najwięcej                 num:sg:acc:m3:rec
# 245           podróże                    subst:pl:nom:f
# 246         Zarszynie                   subst:sg:loc:m3
# 247            zajęty                 adj:sg:nom:m1:pos
# 248         zakończył                  praet:sg:m1:perf
# 249              1808                 adj:sg:gen:m3:pos
# 250              1809                 adj:sg:gen:m3:pos
# 251             kończ                   subst:sg:gen:m3
# 252             życia           ger:sg:gen:n:imperf:aff
# 253             wielu                num:pl:loc:f:congr
# 254           bitwach                    subst:pl:loc:f
# 255             Iglan                  subst:sg:inst:m3
# 256               pod                    prep:inst:nwok
# 257            Wagram                  subst:sg:inst:m3
# 258             armat                    subst:pl:gen:f
# 259      kontuzjowany           ppas:sg:nom:m1:perf:aff
# 260               jak                           adv:pos
# 261           nieżywy                 adj:sg:nom:m1:pos
# 262              cały                 adj:sg:acc:m3:pos
# 263              pułk                   subst:sg:acc:m3
# 264            pieszy                 adj:sg:acc:m3:pos
# 265         Francuzów                   subst:pl:gen:m1
# 266    przemaszerował                  praet:sg:m3:perf
# 267               nim    ppron3:sg:loc:m1:ter:akc:praep
# 268          zwinięty           ppas:sg:acc:m3:perf:aff
# 269         obwiązany           ppas:sg:acc:m3:perf:aff
# 270             plecy                 subst:pl:acc:n:pt
# 271              małe                  adj:pl:nom:n:pos
# 272           ukłucia               subst:pl:nom:n:ncol
# 273         dostawały                 praet:pl:n:imperf
# 274         skrzętnem                     adj:sg:inst:n
# 275              wieś                    subst:sg:acc:f
# 276        Siemiginów                   subst:pl:nom:m3
# 277               tem               subst:pl:gen:n:ncol
# 278               jak                           adv:pos
# 279         powiadano                       imps:imperf
# 280            indyki                   subst:pl:acc:m2
# 281           których                 adj:pl:gen:m2:pos
# 282             Lwowa                   subst:sg:gen:m3
# 283          Bludniki                 subst:pl:nom:n:pt
# 284             które                  adj:pl:nom:n:pos
# 285              Pani                    subst:sg:dat:f
# 286     Rozwadowskiej                    subst:sg:dat:f
# 287             10000                 num:pl:nom:m2:rec
# 288           dukatów                   subst:pl:gen:m2
# 289              2000                 num:pl:gen:m2:rec
# 290           dukatów                   subst:pl:gen:m2
# 291     Rozwadowskiej                    subst:sg:gen:f
# 292          zmieniał                praet:sg:m1:imperf
# 293            wójtem                  subst:sg:inst:m1
# 294                 w                     prep:acc:nwok
# 295                we                      prep:acc:wok
# 296        posiadanie               subst:sg:acc:n:ncol
# 297           osypami                  subst:pl:inst:m3
# 298          daninami                   subst:pl:inst:f
# 299           któremi                adj:pl:inst:m1:pos
# 300         obeymował                praet:sg:m1:imperf
# 301       juryzdyksye                    subst:sg:acc:f
# 302         pierwszey                  adj:sg:gen:f:pos
# 303               Zaś                              conj
# 304            daniny                    subst:pl:acc:f
# 305           robocie                    subst:sg:loc:f
# 306       posiadanych         ppas:pl:gen:m1:imperf:aff
# 307            bydłem              subst:sg:inst:n:ncol
# 308                co                          prep:acc
# 309              tego                 adj:sg:gen:m3:pos
# 310              owsa                   subst:sg:gen:m3
# 311               dwa          num:pl:acc:m3:congr:ncol
# 312                ci                 adj:pl:nom:m1:pos
# 313             zwane          ppas:sg:acc:n:imperf:aff
# 314            spaśne               subst:sg:acc:n:ncol
# 315              kury                    subst:pl:acc:f
# 316           kapłony                   subst:pl:acc:m2
# 317            kaczki                    subst:pl:acc:f
# 318              gęsi                    subst:pl:acc:f
# 319              jaja               subst:pl:acc:n:ncol
# 320         pastwiska               subst:pl:acc:n:ncol
# 321         pastwisko               subst:sg:acc:n:ncol
# 322           biedzie                    subst:sg:loc:f
# 323            zbożem              subst:sg:inst:n:ncol
# 324       inwentarzem                  subst:sg:inst:m3
# 325            Wieleż                 num:pl:acc:m3:rec
# 326                to                              part
# 327              razy                   subst:pl:acc:m3
# 328           Dziadka                   subst:sg:acc:m1
# 329     Ostaszewskigo                   subst:sg:acc:m1
# 330               jak                           adv:pos
# 331           kmiecie                   subst:sg:nom:m1
# 332             bydle               subst:sg:nom:n:ncol
# 333           robocze                  adj:sg:nom:n:pos
# 334            żalili                praet:pl:m1:imperf
# 335              koni                   subst:pl:gen:m2
# 336          Oddzieli                   fin:sg:ter:perf
# 337            suchey                  adj:sg:gen:f:pos
# 338        podedworem                   subst:sg:loc:m3
# 339      nayskładniey                           adv:sup
# 340          położone                 adj:pl:nom:m3:pos
# 341            kmieci                   subst:pl:gen:m1
# 342            Niebył                praet:sg:m3:imperf
# 343                to                              pred
# 344         obowiązek                   subst:sg:nom:m3
# 345         spełniony           ppas:sg:nom:m3:perf:aff
# 346        Oycowskiey                    subst:sg:acc:f
# 347             napar                   subst:sg:nom:m3
# 348             prawo               subst:sg:nom:n:ncol
# 349             prawo               subst:sg:nom:n:ncol
# 350         polowania               subst:sg:gen:n:ncol
# 351          dworskim                 adj:sg:loc:m3:pos
# 352        gromadzkim                 adj:sg:loc:m3:pos
# 353             leśni                   subst:pl:nom:m1
# 354           poddani                   subst:pl:nom:m1
# 355         suszonych         ppas:pl:gen:m3:imperf:aff
# 356           miarkmi                   subst:pl:inst:f
# 357            wianki                   subst:pl:nom:m3
# 358           powinny               winien:pl:m3:imperf
# 359              były                praet:pl:m3:imperf
# 360         dziesiąty                 adj:sg:acc:m3:pos
# 361             pniak                   subst:sg:acc:m3
# 362            takiem                  adj:sg:loc:n:pos
# 363             chłop                   subst:sg:nom:m1
# 364               był                praet:sg:m1:imperf
# 365            biedny                 adj:sg:nom:m1:pos
# 366               tak                           adv:pos
# 367           majątki                   subst:pl:nom:m3
# 368              były                praet:pl:m3:imperf
# 369         wyłącznie                              part
# 370               był                praet:sg:m3:imperf
# 371              Herb                   subst:sg:nom:m3
# 372         Dziedzica                   subst:sg:gen:m1
# 373          Dominium               subst:sg:nom:n:ncol
# 374          Bludniki                 subst:pl:nom:n:pt
# 375           Zarszyn                   subst:sg:nom:m3
# 376            swojem                  adj:sg:loc:n:pos
# 377           mieycus               subst:sg:loc:n:ncol
# 378     Mandatariusza                   subst:sg:acc:m1
# 379           rekruta                   subst:sg:acc:m1
# 380         urzędował                praet:sg:m1:imperf
# 381         egzekował                  praet:sg:m1:perf
# 382          niemogło                 praet:sg:n:imperf
# 383           dopokąd                              comp
# 384      nieprzyniósł                  praet:sg:m1:perf
# 385            kartki                    subst:sg:gen:f
# 386                 A                              conj
# 387             mogły                 praet:pl:n:imperf
# 388         nadużycia               subst:pl:nom:n:ncol
# 389             mogły                 praet:pl:n:imperf
# 390               one    ppron3:pl:nom:n:ter:akc:npraep
# 391         wyjątkowe                  adj:pl:nom:n:pos
# 392             ktoby                              part
# 393               był                praet:sg:m3:imperf
# 394  niesprawiedliwym                adj:sg:inst:m3:pos
# 395            stawał                praet:sg:m3:imperf
# 396             dbano                       imps:imperf
# 397         szlachcic                   subst:sg:nom:m1
# 398                 w                     prep:acc:nwok
# 399          Sanockie               subst:sg:acc:n:ncol
# 400         poddanych                   subst:pl:gen:m1
# 401                 P                         brev:npun
# 402              tego                 adj:sg:gen:m1:pos
# 403         obsadzane         ppas:pl:nom:m3:imperf:aff
# 404              były                praet:pl:m3:imperf
# 405         cząstkową                 adj:sg:inst:f:pos
# 406         czynszową                 adj:sg:inst:f:pos
# 407          ludowemi                     adj:pl:inst:f
# 408             lizną                  praet:sg:m1:perf
# 409            trochę                 num:pl:acc:m3:rec
# 410            łaciny                    subst:sg:gen:f
# 411         gymnazyum                   subst:sg:loc:m3
# 412             prawa               subst:sg:gen:n:ncol
# 413       manipulacyi                    subst:sg:gen:f
# 414         urzędowey                  adj:sg:gen:f:pos
# 415           Cyrkule                   subst:sg:loc:m3
# 416      Mandatyrusza                    subst:sg:acc:f
# 417        przyjmował                praet:sg:m1:imperf
# 418          Dziedzic                    subst:sg:nom:f
# 419          depozyta                   subst:pl:acc:m3
# 420     starościńskie                 adj:pl:acc:m3:pos
# 421         Dziedzica                   subst:sg:gen:m1
# 422               120                 num:pl:gen:m2:rec
# 423               200                 num:pl:gen:m2:rec
# 424               300                 num:pl:gen:m2:rec
# 425                20                 num:pl:gen:m3:rec
# 426                50                 num:pl:gen:m3:rec
# 427         ordynaryi                    subst:pl:gen:f
# 428      pomieszkanie             ger:sg:acc:n:perf:aff
# 429              opał                   subst:sg:acc:m3
# 430         pastwisko               subst:sg:acc:n:ncol
# 431        zastępował                praet:sg:m1:imperf
# 432         Dziedzica                   subst:sg:acc:m1
# 433         szczupłey                  adj:sg:gen:f:pos
# 434           dotacyi                    subst:sg:gen:f
# 435                 w                     prep:acc:nwok
# 436               one                 adj:pl:acc:m3:pos
# 437         kosztował                praet:sg:m3:imperf
# 438      dzisiejszych                 adj:pl:acc:m3:pos
# 439                 4                 num:pl:acc:m2:rec
# 440                 5                 num:pl:gen:m2:rec
# 441            centów                   subst:pl:gen:m2
# 442            korzec                   subst:sg:nom:m3
# 443              owsa                   subst:sg:gen:m3
# 444        cwansigera                   subst:sg:acc:m3
# 445                33                 num:pl:acc:m2:rec
# 446             centy                   subst:pl:nom:m2
# 447              żyta               subst:sg:gen:n:ncol
# 448      dzisiejszych                 adj:pl:gen:m2:pos
# 449                 1                 num:sg:acc:m2:rec
# 450                fl                         brev:npun
# 451                10                 num:pl:acc:m2:rec
# 452                14                 num:pl:gen:m2:rec
# 453            centów                   subst:pl:gen:m2
# 454           przytem               subst:sg:loc:n:ncol
# 455           Panowie                   subst:pl:nom:m1
# 456                ci                 adj:pl:nom:m1:pos
# 457            lepiey                           adv:com
# 458        dzisiejszy                 adj:sg:nom:m1:pos
# 459          komisarz                   subst:sg:nom:m1
# 460        cyrkularny                 adj:sg:nom:m1:pos
# 461       Cyrkularnym                 adj:sg:dat:m1:pos
# 462             ładąn                 adj:pl:inst:f:pos
# 463          siwoszów                   subst:pl:gen:m2
# 464            ubrany                 adj:sg:nom:m1:pos
# 465            pensyi                              part
# 466               600                 num:pl:acc:m2:rec
# 467                fl                         brev:npun
# 468               móy                 adj:sg:nom:m1:pos
# 469             Dziad                   subst:sg:nom:m1
# 470         Pokasowce                    subst:pl:nom:f
# 471         Siedliska                    subst:pl:nom:f
# 472      zakłopotania               subst:sg:gen:n:ncol
# 473        najbliższy                 adj:sg:nom:m1:sup
# 474            Notiak                    subst:sg:nom:f
# 475              jego   ppron3:sg:gen:m1:ter:akc:npraep
# 476                to                              part
# 477              jego   ppron3:sg:acc:m1:ter:akc:npraep
# 478            samego                 adj:sg:acc:m1:pos
# 479            dokoła                          prep:gen
# 480              ławy                    subst:sg:nom:f
# 481              stół                   subst:sg:nom:m3
# 482           nakryty           ppas:sg:nom:m3:perf:aff
# 483           bielone          ppas:sg:nom:n:imperf:aff
# 484             grube                  adj:sg:nom:n:pos
# 485         zkończone                 adj:sg:inst:f:pos
# 486          bochenek                   subst:sg:nom:m3
# 487               sól                    subst:sg:nom:f
# 488             dzban                   subst:sg:nom:m3
# 489           niewiem                 fin:sg:pri:imperf
# 490               czy                              part
# 491            gotowe               subst:sg:nom:n:ncol
# 492                Ty             ppron12:sg:voc:m1:sec
# 493        człowiecze                   subst:sg:voc:m1
# 494      nieporadzisz                   fin:sg:sec:perf
# 495         chłopisko                   subst:sg:nom:m1
# 496              2000                 num:pl:acc:m2:rec
# 497           Dukatów                   subst:pl:gen:m2
# 498         poradzisz                   fin:sg:sec:perf
# 499                 A                              conj
# 500         przyniósł             praet:sg:m1:perf:nagl
# 501              2000                 num:pl:acc:m2:rec
# 502             mojey                  adj:sg:gen:f:pos
# 503           liczono                       imps:imperf
# 504           sześciu            num:pl:nom:m1:rec:ncol
# 505    Mandatariuszem                  subst:sg:inst:m1
# 506           jaszcze                              part
# 507               tam                              part
# 508         księżunio                   subst:sg:nom:m1
# 509               był                praet:sg:m1:imperf
# 510            oyciec                   subst:sg:nom:m1
# 511             owego                 adj:sg:gen:m1:pos
# 512       Głoweckiego                   subst:sg:gen:m1
# 513             który                 adj:sg:nom:m1:pos
# 514         przeszedł                  praet:sg:m1:perf
# 515                 w                     prep:acc:nwok
# 516         Lubelskie               subst:sg:acc:n:ncol
# 517              jako                              conj
# 518               pop                   subst:sg:nom:m1
# 519       szyzmatycki                 adj:sg:nom:m1:pos
# 520              jako                              conj
# 521           renegat                   subst:sg:nom:m1
# 522                 I                              conj
# 523            późney                           adv:com
# 524             Dziad                   subst:sg:nom:m1
# 525               móy                 adj:sg:nom:m1:pos
# 526           Dorchów                   subst:sg:acc:m3
# 527           Kurypów                   subst:sg:acc:m3
# 528     nayjstarszego                 adj:sg:acc:m1:sup
# 529              Toje                               ign
# 530              diło                               ign
# 531            daruju                               ign
# 532        ukochanomu                               ign
# 533              Synu                               ign
# 534            mojomu                               ign
# 535        Mychayłowu                               ign
# 536          Bludniki                 subst:pl:nom:n:pt
# 537             iOycu                   subst:sg:dat:m1
# 538            mojemu                 adj:sg:dat:m1:pos
# 539               tak                              part
# 540            mojego                 adj:sg:gen:m1:pos
# 541              Oyca                   subst:sg:gen:m1
# 542              pono                              part
# 543              1813                 adj:sg:gen:m3:pos
# 544              1814                 adj:sg:gen:m3:pos
# 545              Pana                   subst:sg:acc:m1
# 546            Józefa                   subst:sg:acc:m1
# 547               móy                 adj:sg:nom:m1:pos
# 548            Siebie                        siebie:gen
# 549         dośmierci                    subst:pl:gen:f
# 550              Oyca                   subst:sg:gen:m1
# 551               Nim    ppron3:sg:loc:m1:ter:akc:praep
# 552         ociemniał                praet:sg:m1:imperf
# 553         Zdejmował                praet:sg:m1:imperf
# 554                Mu  ppron3:sg:dat:m1:ter:nakc:npraep
# 555               ile                               adv
# 556             około                              part
# 557              1826                 adj:sg:gen:m3:pos
# 558         Semiginów                   subst:pl:acc:m1
# 559            Oyciec                   subst:sg:nom:m1
# 560              pono                              part
# 561                to                              comp
# 562          niewinem                 fin:sg:pri:imperf
# 563        Bludnikami                subst:pl:inst:n:pt
# 564        Temerowiec               subst:pl:gen:n:ncol
# 565        Zabilskich                   subst:pl:acc:m1
# 566          jedynaka                   subst:sg:acc:m1
# 567            Sabina                   subst:sg:gen:m1
# 568                za                          prep:acc
# 569        doszedłszy                         pant:perf
# 570             około                              part
# 571                24                 num:pl:gen:m3:rec
# 572         przeszedł                  praet:sg:m3:perf
# 573             synie                   subst:sg:loc:m3
# 574           Dorchów                   subst:pl:acc:m3
# 575             bratu                   subst:sg:dat:m1
# 576              temu               subst:sg:dat:n:ncol
# 577              pono                              part
# 578               ten                 adj:sg:nom:m1:pos
# 579          zostawił                  praet:sg:m1:perf
# 580           Dorchów                   subst:pl:acc:m1
# 581            niebył               praet:sg:ter:imperf
# 582            więcey                           adv:com
# 583             wgłos                               adv
# 584              Pana                   subst:sg:acc:m1
# 585          Tadeusza                   subst:sg:acc:m1
# 586            masami                   subst:pl:inst:f
# 587          poziomki                    subst:pl:acc:f
# 588         częstował                praet:sg:m3:imperf
# 589         Zapraszał                praet:sg:m1:imperf
# 590               tey                  adj:sg:gen:f:pos
# 591                ci        ppron12:sg:dat:m1:sec:nakc
# 592          niemogli                praet:pl:m1:imperf
# 593          uciekali                praet:pl:m1:imperf
# 594         przyszedł                  praet:sg:m1:perf
# 595            wielki                 adj:sg:nom:m3:pos
# 596            piątek                   subst:sg:nom:m3
# 597          nietylko                              part
# 598           czeladź                    subst:sg:nom:f
# 599            suszyć                        inf:imperf
# 600             sądny                 adj:sg:nom:m3:pos
# 601          niemożna                              pred
# 602             prawa               subst:pl:acc:n:ncol
# 603               był                praet:sg:m1:imperf
# 604          oczytany           ppas:sg:nom:m1:perf:aff
# 605          poczciwy                 adj:sg:nom:m1:pos
# 606             zacny                 adj:sg:nom:m1:pos
# 607             tylko                              conj
# 608                go  ppron3:sg:acc:m1:ter:nakc:npraep
# 609         klęczącym                adj:sg:inst:m1:pos
# 610         złożonymi                 adj:pl:inst:f:pos
# 611            rękoma                   subst:pl:inst:f
# 612          nieżywym                 adj:pl:inst:f:pos
# 613                po                          prep:acc
# 614               mim    ppron3:sg:acc:m1:ter:akc:praep
# 615             część                    subst:sg:nom:f
# 616          Siostrom                    subst:pl:dat:f
# 617             swoim                  adj:sg:dat:f:pos
# 618          rodzonym          ppas:sg:dat:f:imperf:aff
# 619        Treterowej                    subst:sg:dat:f
# 620       Swieżaskiey                    subst:sg:dat:f
# 621              Oyca                    subst:sg:gen:f
# 622             Panną                   subst:sg:inst:f
# 623        Świeżyńską                   subst:sg:inst:f
# 624          urodzoną                 adj:sg:inst:f:pos
# 625                ze                      prep:gen:wok
# 626        Zawadzkich                   subst:pl:gen:m1
# 627          Łukowiec                   subst:sg:nom:m3
# 628               czy                              part
# 629             kilka             num:pl:nom:f:rec:ncol
# 630            jednem                 adj:sg:loc:m3:pos
# 631          obeyściu                   subst:sg:loc:m3
# 632               dwa          num:pl:nom:m3:congr:ncol
# 633             dwory                   subst:pl:nom:m3
# 634                 2                num:pl:nom:f:congr
# 635             Panny                    subst:pl:nom:f
# 636              obie           num:pl:nom:f:congr:ncol
# 637             jakby                              part
# 638             Panna                    subst:sg:nom:f
# 639             Julia                    subst:sg:nom:f
# 640           Bludnik                 subst:pl:gen:n:pt
# 641         Martynowa                   subst:sg:gen:m3
# 642          Rudzkich                 adj:pl:gen:m1:pos
# 643              były                 praet:pl:f:imperf
# 644              dwie           num:pl:nom:f:congr:ncol
# 645          panienki                    subst:pl:nom:f
# 646               tąd                               adv
# 647             Jakby                              comp
# 648               jey  ppron3:sg:gen:m1:ter:nakc:npraep
# 649          niemogła                 praet:sg:f:imperf
# 650           osiadły                 adj:sg:nom:m1:pos
# 651           talarki                   subst:pl:nom:m2
# 652            krewni                   subst:pl:nom:m1
# 653             niema                 fin:sg:ter:imperf
# 654       sukcessorów                   subst:pl:gen:m1
# 655         odmłodził                  praet:sg:m1:perf
# 656        niechciało                 praet:sg:n:imperf
# 657              Ojcu                   subst:sg:loc:m1
# 658    oddziedziczone            ppas:sg:acc:n:perf:aff
# 659              sady                   subst:pl:acc:m3
# 660             kilka             num:pl:acc:f:rec:ncol
# 661          odległey                  adj:sg:gen:f:pos
# 662        Siemignowa                   subst:sg:gen:m1
# 663              hoża                  adj:sg:nom:f:pos
# 664               jak                          prep:nom
# 665             łania                  adj:sg:nom:f:pos
# 666             Panna                    subst:sg:nom:f
# 667             Julia                    subst:sg:nom:f
# 668         Jegomości                   subst:pl:acc:m1
# 669                to                              pred
# 670             około                          prep:gen
# 671              tego                  adj:sg:gen:n:pos
# 672       sukcessorka                  adj:sg:nom:f:pos
# 673       Siemiginowa                    subst:sg:gen:f
# 674       miejscowość                    subst:sg:acc:f
# 675        Leśniowice                 subst:pl:acc:n:pt
# 676             życie               subst:sg:nom:n:ncol
# 677         zakończył                  praet:sg:m1:perf
# 678           ciepłey                  adj:sg:gen:f:pos
# 679             wdowy                    subst:sg:gen:f
# 680        Bałamuciła                 praet:sg:f:imperf
# 681              pana                   subst:sg:acc:m1
# 682                24                 num:pl:gen:m3:rec
# 683         liczącego         pact:sg:acc:m1:imperf:aff
# 684          sybarytę                   subst:sg:acc:m1
# 685         próżniaka                   subst:sg:acc:m1
# 686         dwuletnim                  adj:sg:loc:n:pos
# 687           pożyciu             ger:sg:dat:n:perf:aff
# 688           secundo                               ign
# 689              voto                               ign
# 690           procesa                   subst:sg:acc:m3
# 691               ich   ppron3:pl:acc:m3:ter:akc:npraep
# 692         przyległe                 adj:pl:acc:m3:pos
# 693             Mosty                 subst:pl:acc:n:pt
#
#                            Prediction
# 0                     subst:sg:nom:m3
# 1                   adj:sg:nom:m3:pos
# 2                     subst:sg:nom:m3
# 3             ppas:sg:nom:m3:perf:aff
# 4                 subst:sg:acc:n:ncol
# 5                      subst:sg:gen:f
# 6                     subst:sg:nom:m1
# 7                  adj:sg:inst:m3:pos
# 8                    subst:sg:inst:m3
# 9             aglt:sg:sec:imperf:nwok
# 10                           brev:pun
# 11                     subst:pl:nom:f
# 12                  adj:pl:gen:m1:pos
# 13                    subst:sg:nom:m1
# 14                    subst:sg:nom:m1
# 15                  adj:sg:nom:m3:pos
# 16                    subst:sg:nom:m3
# 17                    subst:sg:nom:m3
# 18                  adj:sg:nom:m3:pos
# 19                 praet:sg:m3:imperf
# 20                      prep:gen:nwok
# 21                  adj:pl:gen:m3:sup
# 22                    subst:sg:gen:m3
# 23                  num:pl:acc:m3:rec
# 24                    subst:sg:nom:m3
# 25                 praet:sg:m3:imperf
# 26                    subst:sg:nom:m3
# 27                    subst:sg:nom:m3
# 28                num:pl:gen:m1:congr
# 29            ppas:sg:gen:m3:perf:aff
# 30                  num:pl:nom:m1:rec
# 31                    subst:pl:gen:m1
# 32                    subst:sg:gen:m1
# 33                    subst:sg:gen:m1
# 34                    subst:sg:gen:m1
# 35                    subst:sg:gen:m1
# 36                    subst:sg:gen:m1
# 37                   adj:pl:gen:f:pos
# 38                     subst:pl:gen:f
# 39                   adj:pl:gen:f:pos
# 40                   adj:sg:nom:f:pos
# 41                    subst:sg:nom:m1
# 42                    subst:pl:gen:m1
# 43                    subst:sg:nom:m1
# 44                               part
# 45                    subst:sg:nom:m3
# 46                   praet:sg:m3:perf
# 47                   subst:sg:inst:m3
# 48              ger:sg:acc:n:perf:aff
# 49                  adj:sg:inst:n:pos
# 50                   adj:pl:gen:f:pos
# 51                            adv:pos
# 52                subst:sg:gen:n:ncol
# 53                    subst:sg:gen:m1
# 54                    subst:sg:gen:m1
# 55                     subst:sg:acc:f
# 56                   adj:sg:nom:f:pos
# 57                subst:sg:acc:n:ncol
# 58   ppron3:sg:acc:m3:ter:nakc:npraep
# 59                subst:sg:acc:n:ncol
# 60                               part
# 61                    subst:sg:gen:m1
# 62                    subst:sg:gen:m1
# 63   ppron3:sg:acc:m3:ter:nakc:npraep
# 64                    subst:sg:gen:m1
# 65                     subst:pl:nom:f
# 66                   impt:sg:sec:perf
# 67                    praet:sg:f:perf
# 68                     subst:sg:nom:f
# 69    ppron3:sg:gen:m1:ter:akc:npraep
# 70                   praet:sg:m3:perf
# 71                  adj:sg:nom:m3:pos
# 72                    subst:sg:nom:m3
# 73                               comp
# 74                     subst:sg:gen:f
# 75            ppas:sg:nom:m3:perf:aff
# 76                   subst:sg:inst:m3
# 77                subst:sg:acc:n:ncol
# 78                               comp
# 79                     subst:sg:gen:f
# 80                subst:sg:loc:n:ncol
# 81                  adj:sg:inst:f:pos
# 82                  num:pl:nom:m1:rec
# 83                 praet:sg:m1:imperf
# 84                    subst:pl:inst:f
# 85                    subst:sg:gen:m1
# 86                    praet:pl:f:perf
# 87                    subst:pl:nom:m3
# 88                   num:pl:nom:f:rec
# 89                    subst:sg:gen:m3
# 90                    subst:sg:gen:m3
# 91                num:pl:loc:m3:congr
# 92                    subst:pl:loc:m3
# 93                               part
# 94              ger:sg:loc:n:perf:aff
# 95                 adj:sg:inst:m3:pos
# 96                   subst:sg:inst:m3
# 97                     subst:sg:nom:f
# 98                   adj:sg:nom:f:pos
# 99                    subst:sg:dat:m3
# 100               subst:sg:acc:n:ncol
# 101                    subst:sg:nom:f
# 102                  adj:sg:nom:f:pos
# 103                          inf:perf
# 104             ppron12:sg:nom:m1:pri
# 105                              part
# 106        ppron12:sg:dat:m1:pri:nakc
# 107                    subst:sg:nom:f
# 108                praet:sg:m3:imperf
# 109               subst:sg:acc:n:ncol
# 110                praet:sg:m1:imperf
# 111          pact:sg:acc:f:imperf:aff
# 112                           adv:pos
# 113                        inf:imperf
# 114                 adj:sg:loc:m3:pos
# 115                num:pl:acc:f:congr
# 116                    subst:pl:acc:f
# 117                 adj:pl:nom:m1:pos
# 118                 adj:sg:gen:m3:pos
# 119                   subst:sg:gen:m3
# 120                    subst:pl:acc:f
# 121               subst:pl:gen:n:ncol
# 122                    subst:sg:gen:f
# 123                         imps:perf
# 124                   subst:sg:loc:m3
# 125                   praet:pl:f:perf
# 126                  adj:sg:gen:f:pos
# 127                   subst:sg:acc:m1
# 128                    subst:sg:nom:f
# 129                    subst:sg:nom:f
# 130                 adj:sg:gen:m3:pos
# 131                   subst:sg:gen:m3
# 132                 adj:sg:gen:m3:pos
# 133                 subst:pl:gen:n:pt
# 134                praet:sg:m3:imperf
# 135                  subst:sg:inst:m3
# 136                   subst:sg:gen:m1
# 137                 adj:sg:nom:m3:pos
# 138                   subst:sg:nom:m3
# 139                              comp
# 140               num:pl:acc:m3:congr
# 141                   subst:pl:acc:m3
# 142                   subst:sg:acc:m3
# 143                    subst:sg:gen:f
# 144           ppas:sg:nom:m3:perf:aff
# 145               subst:sg:gen:n:ncol
# 146               subst:sg:gen:n:ncol
# 147                  adj:sg:nom:f:pos
# 148            ppas:sg:nom:f:perf:aff
# 149                              conj
# 150                   subst:pl:acc:m3
# 151                 adj:pl:acc:m3:pos
# 152                   subst:pl:acc:m3
# 153                   subst:sg:nom:m3
# 154                 adj:sg:nom:m3:pos
# 155                   subst:sg:nom:m3
# 156                praet:sg:m3:imperf
# 157                    subst:sg:nom:f
# 158               subst:pl:gen:n:ncol
# 159                  adj:pl:gen:n:pos
# 160                              conj
# 161                 num:pl:acc:m2:rec
# 162                  adj:pl:gen:f:pos
# 163                              comp
# 164                adj:pl:inst:m3:pos
# 165                  subst:pl:inst:m3
# 166                  praet:sg:m1:perf
# 167                   subst:sg:acc:m3
# 168                 adj:pl:acc:m3:pos
# 169                   subst:pl:acc:m3
# 170                    subst:sg:gen:f
# 171                    subst:sg:gen:f
# 172                          prep:acc
# ...
# 294                     prep:loc:nwok
# 295                      prep:loc:wok
# 296           ger:sg:acc:n:imperf:aff
# 297              subst:pl:inst:n:ncol
# 298                  subst:pl:inst:m3
# 299                  subst:pl:inst:m3
# 300                  praet:sg:m1:perf
# 301                    subst:sg:dat:f
# 302                    subst:sg:gen:f
# 303                          prep:gen
# 304                    subst:sg:gen:f
# 305                   subst:sg:loc:m3
# 306           ppas:pl:gen:m3:perf:aff
# 307                  subst:sg:inst:m3
# 308                          prep:gen
# 309               subst:sg:gen:n:ncol
# 310                   subst:sg:gen:m1
# 311               num:pl:acc:m3:congr
# 312                   subst:pl:nom:m1
# 313         ppas:pl:acc:m3:imperf:aff
# 314                  adj:pl:nom:f:pos
# 315                    subst:pl:nom:f
# 316                    subst:sg:gen:f
# 317                    subst:sg:gen:f
# 318                    subst:sg:gen:f
# 319                    subst:sg:nom:f
# 320               subst:sg:gen:n:ncol
# 321                           adv:pos
# 322                   subst:sg:loc:m3
# 323                  subst:sg:inst:m3
# 324                  subst:sg:inst:m1
# 325                   subst:sg:nom:m3
# 326                              pred
# 327                   subst:pl:gen:m3
# 328                   subst:sg:gen:m1
# 329                   subst:sg:gen:m1
# 330                              comp
# 331                   subst:sg:loc:m3
# 332                    subst:pl:acc:f
# 333                  adj:pl:acc:f:pos
# 334                  praet:pl:m1:perf
# 335                    subst:sg:gen:f
# 336                  praet:pl:m1:perf
# 337                    subst:sg:gen:f
# 338                  subst:sg:inst:m3
# 339                   subst:pl:nom:m3
# 340           ppas:pl:nom:m3:perf:aff
# 341                    subst:sg:gen:f
# 342                  praet:sg:m1:perf
# 343               subst:sg:acc:n:ncol
# 344                   subst:sg:acc:m3
# 345           ppas:sg:acc:m3:perf:aff
# 346                    subst:sg:gen:f
# 347                    subst:pl:gen:f
# 348               subst:sg:acc:n:ncol
# 349               subst:sg:acc:n:ncol
# 350           ger:sg:gen:n:imperf:aff
# 351                  adj:sg:loc:n:pos
# 352                  adj:sg:loc:n:pos
# 353                 adj:pl:nom:m1:pos
# 354           ppas:pl:nom:m1:perf:aff
# 355                 adj:pl:gen:m3:pos
# 356                  subst:pl:inst:m1
# 357                    subst:sg:gen:f
# 358                winien:pl:n:imperf
# 359                 praet:pl:f:imperf
# 360                 adj:sg:nom:m3:pos
# 361                   subst:sg:nom:m3
# 362                  subst:sg:inst:m3
# 363                   subst:sg:nom:m3
# 364                praet:sg:m3:imperf
# 365                 adj:sg:nom:m3:pos
# 366                              part
# 367                    subst:pl:nom:f
# 368                 praet:pl:f:imperf
# 369                           adv:pos
# 370                praet:sg:m1:imperf
# 371                   subst:sg:nom:m1
# 372                   subst:sg:nom:m1
# 373               subst:sg:gen:n:ncol
# 374                    subst:sg:gen:f
# 375               subst:sg:nom:n:ncol
# 376                   subst:sg:acc:m3
# 377                   subst:sg:acc:m3
# 378                   subst:sg:gen:m1
# 379                 subst:pl:acc:n:pt
# 380                  praet:sg:m1:perf
# 381                praet:sg:m1:imperf
# 382                   praet:sg:n:perf
# 383                               adv
# 384             praet:sg:m1:perf:nagl
# 385                    subst:pl:acc:f
# 386                              part
# 387                 praet:pl:f:imperf
# 388             ger:pl:nom:n:perf:aff
# 389                 praet:pl:f:imperf
# 390    ppron3:pl:nom:f:ter:akc:npraep
# 391                  adj:sg:nom:n:pos
# 392                   subst:sg:nom:m1
# 393                praet:sg:m1:imperf
# 394                adj:sg:inst:m1:pos
# 395                praet:sg:m1:imperf
# 396                         imps:perf
# 397                       pcon:imperf
# 398                     prep:loc:nwok
# 399                    subst:sg:loc:f
# 400           ppas:pl:gen:m1:perf:aff
# 401                          brev:pun
# 402               subst:sg:gen:n:ncol
# 403          ppas:pl:nom:f:imperf:aff
# 404                 praet:pl:f:imperf
# 405                  adj:sg:acc:f:pos
# 406                  adj:sg:acc:f:pos
# 407                  subst:pl:inst:m3
# 408                  adj:sg:acc:f:pos
# 409                               adv
# 410                    subst:pl:acc:f
# 411               subst:sg:loc:n:ncol
# 412                  adj:sg:nom:f:pos
# 413                 fin:sg:ter:imperf
# 414                   subst:sg:nom:m1
# 415                    subst:sg:loc:f
# 416                   subst:sg:nom:m1
# 417                  praet:sg:m1:perf
# 418                   subst:sg:acc:m3
# 419               subst:pl:acc:n:ncol
# 420                  adj:pl:acc:n:pos
# 421                   subst:sg:gen:m3
# 422               num:pl:gen:m3:congr
# 423               num:pl:gen:m3:congr
# 424               num:pl:gen:m3:congr
# 425                 num:pl:nom:m3:rec
# 426               num:pl:gen:m3:congr
# 427                    subst:sg:gen:f
# 428               subst:sg:acc:n:ncol
# 429                  praet:sg:m1:perf
# 430               subst:sg:nom:n:ncol
# 431                  praet:sg:m1:perf
# 432                   subst:sg:nom:m1
# 433                 adj:sg:nom:m1:pos
# 434                 fin:sg:ter:imperf
# 435                     prep:loc:nwok
# 436   ppron3:pl:nom:m3:ter:akc:npraep
# 437                praet:sg:m1:imperf
# 438                  adj:pl:gen:f:com
# 439                               dig
# 440               num:pl:gen:m3:congr
# 441                   subst:pl:gen:m3
# 442                   subst:sg:acc:m3
# 443                   subst:sg:gen:m1
# 444                   subst:sg:gen:m1
# 445               num:pl:nom:m3:congr
# 446                   subst:pl:nom:m3
# 447            ppas:sg:nom:f:perf:aff
# 448                  adj:pl:gen:f:com
# 449                 adj:sg:acc:m3:pos
# 450                   subst:sg:acc:m3
# 451                               dig
# 452               num:pl:gen:m1:congr
# 453                   subst:pl:gen:m1
# 454                  subst:sg:inst:m3
# 455                   subst:pl:voc:m1
# 456        ppron12:sg:dat:m1:sec:nakc
# 457                 adj:sg:nom:m3:pos
# 458                 adj:sg:nom:m3:pos
# 459                   subst:sg:nom:m3
# 460                 adj:sg:nom:m3:pos
# 461                adj:sg:inst:m3:pos
# 462                         brev:npun
# 463                   subst:pl:gen:m3
# 464           ppas:sg:nom:m1:perf:aff
# 465                    subst:pl:acc:f
# 466                  num:pl:acc:f:rec
# 467                    subst:pl:gen:f
# 468                 adj:sg:acc:m3:pos
# 469                   subst:sg:acc:m3
# 470                    subst:sg:dat:f
# 471               subst:sg:gen:n:ncol
# 472             ger:sg:gen:n:perf:aff
# 473                 adj:sg:acc:m3:sup
# 474                   subst:sg:nom:m1
# 475   ppron3:sg:gen:m3:ter:akc:npraep
# 476                              pred
# 477   ppron3:sg:gen:m1:ter:akc:npraep
# 478                 adj:sg:gen:m1:pos
# 479                               adv
# 480                    subst:pl:acc:f
# 481                   subst:sg:acc:m3
# 482           ppas:sg:acc:m3:perf:aff
# 483                  adj:sg:nom:n:pos
# 484                  adj:pl:acc:f:pos
# 485            ppas:pl:nom:f:perf:aff
# 486                   subst:sg:acc:m3
# 487                   subst:sg:nom:m3
# 488               subst:sg:nom:n:ncol
# 489              subst:sg:inst:n:ncol
# 490                              conj
# 491                  adj:pl:nom:f:pos
# 492             ppron12:sg:nom:m1:sec
# 493                 fin:sg:ter:imperf
# 494                 fin:sg:sec:imperf
# 495               subst:sg:acc:n:ncol
# 496                  num:pl:acc:f:rec
# 497                   subst:pl:gen:m1
# 498                 fin:sg:sec:imperf
# 499                              part
# 500             praet:sg:m3:perf:nagl
# 501                  num:pl:acc:f:rec
# 502                   subst:pl:acc:m3
# 503                         imps:perf
# 504                 num:pl:nom:m1:rec
# 505                  subst:sg:inst:m3
# 506                  adj:pl:nom:f:pos
# 507                               adv
# 508                              conj
# 509                praet:sg:m3:imperf
# 510                   subst:sg:nom:m3
# 511                 adj:sg:gen:m3:pos
# 512                   subst:sg:gen:m3
# 513                 adj:sg:nom:m3:pos
# 514                  praet:sg:m3:perf
# 515                     prep:loc:nwok
# 516                   subst:sg:loc:m3
# 517                              comp
# 518                   subst:sg:nom:m3
# 519                 adj:sg:nom:m3:pos
# 520                              comp
# 521                   subst:sg:nom:m3
# 522                              part
# 523                              comp
# 524                   subst:sg:acc:m3
# 525                 adj:sg:acc:m3:pos
# 526                   subst:pl:gen:m1
# 527                   subst:pl:gen:m1
# 528                 adj:sg:acc:m1:pos
# 529               subst:sg:nom:n:ncol
# 530                   praet:sg:n:perf
# 531                   subst:sg:gen:m3
# 532                   subst:sg:gen:m3
# 533                   subst:sg:gen:m3
# 534                   subst:sg:gen:m3
# 535                   subst:sg:gen:m3
# 536                   subst:sg:nom:m1
# 537                   subst:sg:gen:m3
# 538                 adj:sg:gen:m3:pos
# 539                           adv:pos
# 540                 adj:sg:acc:m1:pos
# 541                   subst:sg:acc:m1
# 542                         imps:perf
# 543                               dig
# 544                               dig
# 545                   subst:sg:gen:m1
# 546                   subst:sg:gen:m1
# 547                    subst:sg:gen:f
# 548                    subst:sg:gen:f
# 549                   subst:pl:nom:m1
# 550                   subst:sg:gen:m3
# 551               subst:sg:loc:n:ncol
# 552                  praet:sg:m1:perf
# 553                  praet:sg:m1:perf
# 554                   subst:sg:dat:m1
# 555                 num:pl:acc:m3:rec
# 556                          prep:gen
# 557                               dig
# 558                   subst:pl:gen:m1
# 559                    subst:sg:acc:f
# 560                         imps:perf
# 561                              pred
# 562                  subst:sg:inst:m3
# 563                  subst:pl:inst:m1
# 564                 subst:pl:gen:n:pt
# 565                  adj:pl:gen:f:pos
# 566                  adj:sg:nom:f:pos
# 567                    subst:sg:nom:f
# 568                         prep:inst
# 569                   fin:sg:ter:perf
# 570                          prep:gen
# 571                 adj:sg:gen:m3:pos
# 572                  praet:sg:m1:perf
# 573                    subst:sg:loc:f
# 574                   subst:pl:acc:m1
# 575                   subst:sg:gen:m3
# 576                          prep:acc
# 577                         imps:perf
# 578                 adj:sg:nom:m3:pos
# 579                  praet:sg:m3:perf
# 580                   subst:pl:gen:m3
# 581                praet:sg:m1:imperf
# 582                 adj:sg:nom:m1:pos
# 583                   subst:sg:acc:m3
# 584                   subst:sg:gen:m1
# 585                   subst:sg:gen:m1
# 586                  subst:pl:inst:m3
# 587                    subst:sg:gen:f
# 588                praet:sg:m1:imperf
# 589                  praet:sg:m1:perf
# 590                    subst:sg:gen:f
# 591                 adj:pl:nom:m1:pos
# 592                   subst:pl:nom:m1
# 593                  praet:pl:m1:perf
# 594                  praet:sg:m3:perf
# 595                 adj:sg:acc:m3:pos
# 596                   subst:sg:acc:m3
# 597                           adv:pos
# 598                impt:sg:sec:imperf
# 599                          inf:perf
# 600                   subst:pl:nom:m3
# 601                  adj:sg:nom:f:pos
# 602               subst:sg:gen:n:ncol
# 603                praet:sg:m3:imperf
# 604                 adj:sg:nom:m3:pos
# 605                 adj:sg:nom:m3:pos
# 606                 adj:sg:nom:m3:pos
# 607                              part
# 608  ppron3:sg:acc:m3:ter:nakc:npraep
# 609        pact:sg:inst:m1:imperf:aff
# 610           ppas:pl:inst:f:perf:aff
# 611                  subst:sg:inst:m3
# 612                adj:sg:inst:m3:pos
# 613                          prep:loc
# 614                 adj:sg:loc:m3:pos
# 615                    subst:sg:acc:f
# 616                   subst:pl:dat:m1
# 617                 adj:pl:dat:m1:pos
# 618                   subst:pl:dat:m1
# 619                  adj:sg:gen:f:pos
# 620                   subst:sg:nom:m1
# 621                   subst:sg:gen:m1
# 622                 adj:sg:inst:f:pos
# 623                 adj:sg:inst:f:pos
# 624                   subst:sg:inst:f
# 625                     prep:inst:wok
# 626                 adj:pl:gen:m1:pos
# 627                   subst:sg:nom:m1
# 628                              conj
# 629                  num:pl:acc:f:rec
# 630               subst:sg:loc:n:ncol
# 631               subst:sg:loc:n:ncol
# 632               num:pl:acc:m3:congr
# 633                   subst:pl:acc:m3
# 634                  adj:sg:gen:f:pos
# 635                    subst:sg:gen:f
# 636                num:pl:nom:f:congr
# 637                              comp
# 638                   subst:sg:gen:m1
# 639                   subst:sg:gen:m1
# 640                   subst:sg:nom:m1
# 641               subst:sg:gen:n:ncol
# 642                 adj:pl:gen:m3:pos
# 643                 praet:pl:n:imperf
# 644                num:pl:acc:f:congr
# 645                    subst:pl:acc:f
# 646                    subst:pl:gen:f
# 647                              part
# 648                   subst:pl:nom:m2
# 649                   subst:sg:acc:m1
# 650                   praet:pl:f:perf
# 651                    subst:pl:acc:f
# 652                    subst:sg:nom:f
# 653                    subst:sg:nom:f
# 654                   subst:pl:gen:m3
# 655                  praet:sg:m3:perf
# 656                           adv:pos
# 657                   subst:sg:loc:m3
# 658                  adj:sg:acc:n:pos
# 659                    subst:pl:acc:f
# 660                  num:pl:acc:f:rec
# 661           ppas:sg:nom:m3:perf:aff
# 662                   subst:sg:gen:m3
# 663                    subst:sg:nom:f
# 664                              comp
# 665                    subst:sg:nom:f
# 666                   subst:sg:gen:m1
# 667                   subst:sg:gen:m1
# 668                    subst:pl:acc:f
# 669               subst:sg:nom:n:ncol
# 670                              part
# 671               subst:sg:gen:n:ncol
# 672                    subst:sg:nom:f
# 673                  adj:sg:nom:f:pos
# 674                   subst:sg:nom:m1
# 675                   subst:sg:nom:m1
# 676               subst:sg:acc:n:ncol
# 677                  praet:sg:m3:perf
# 678                 adj:sg:nom:m1:pos
# 679                   subst:sg:nom:m1
# 680                    subst:sg:nom:f
# 681                   subst:sg:gen:m1
# 682               num:pl:gen:m3:congr
# 683                   subst:sg:gen:m1
# 684                    subst:sg:acc:f
# 685                 fin:sg:ter:imperf
# 686                 adj:sg:loc:m3:pos
# 687             ger:sg:loc:n:perf:aff
# 688                           adv:pos
# 689                         imps:perf
# 690                    subst:sg:nom:f
# 691   ppron3:pl:acc:m1:ter:akc:npraep
# 692                 adj:pl:nom:m3:pos
# 693                   subst:pl:nom:m3
