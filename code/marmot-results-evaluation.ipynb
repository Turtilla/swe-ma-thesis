# %% [markdown]
# # MARMOT EVALUATION

# %% [markdown]
# ### IMPORTS, VARIABLES

# %%
import conllu
import sklearn.metrics
import pandas as pd
import matplotlib.pyplot as plt
import time

pd.set_option('display.max_rows', None)

# %%
xpos_predictions = './marmot/test_hist_XPOS.out.txt'
upos_predictions = './marmot/test_hist_UPOS.out.txt'

xpos_standard = './marmot/test_hist_XPOS.txt'
upos_standard = './marmot/test_hist_UPOS.txt'

test_predictions = './marmot/test.out.txt'
test_standard = './marmot/test.txt'

# %%
from functions import get_measures, extract_conllu_data, get_comparison

# %% [markdown]
# ### FUNCTIONS

# %%
def get_marmot_tags_and_tokens(filename: str):
    with open(filename) as f:
        tags = f.readlines()
        tokens = [x.strip().split()[0] for x in tags if len(x.strip()) > 0]
        upos = [x.strip().split()[1] for x in tags if len(x.strip()) > 0]
        xpos = [x.strip().split()[2] for x in tags if len(x.strip()) > 0]
        
    return tokens, upos, xpos

# %% [markdown]
# ### EXECUTION - MODERN
# Since unlike the BERT-based tagger Marmot does not output any training/evaluation/testing measures, I need to obtain them myself from contemporary test data.

# %%
# Marmot returns files in a CoNLL-2009 format; it can still be parsed using conllu and my function, but the names of
# the features do not match; here 'feats' corresponds to UPOS tags and 'deprel' to XPOS.
test_tokens, test_upos_preds = extract_conllu_data(test_predictions, 'feats', sentences=False, fulltext=False)
test_tokens, test_xpos_preds = extract_conllu_data(test_predictions, 'deprel', sentences=False, fulltext=False)
# Due to the issue mentioned above, UPOS tags need to be further processed.
test_upos_preds = [list(x.keys())[0] for x in test_upos_preds]

# %%
# Retrieving the gold standard tags
_, test_upos_standard, test_xpos_standard = get_marmot_tags_and_tokens(test_standard)

# %%
get_measures(test_upos_standard, test_upos_preds, details=True)
# Out:
# MEASURES:
# Accuracy: 97.73%
# Precision (weighted): 97.75%
# Recall (weighted): 97.73%
# F1 (weighted): 97.73%
# Matthew's Correlation Coefficient: 97.38%
#
# MEASURES PER CLASS:
# Precision:
# 	ADJ: 97.25%
# 	ADP: 99.46%
# 	ADV: 95.59%
# 	AUX: 91.67%
# 	CCONJ: 96.17%
# 	DET: 98.44%
# 	INTJ: 46.15%
# 	NOUN: 98.23%
# 	NUM: 98.04%
# 	PART: 93.49%
# 	PRON: 99.05%
# 	PROPN: 91.30%
# 	PUNCT: 99.95%
# 	SCONJ: 96.49%
# 	SYM: 100.00%
# 	VERB: 97.96%
# 	X: 89.33%
# Recall:
# 	ADJ: 97.71%
# 	ADP: 99.74%
# 	ADV: 95.33%
# 	AUX: 95.60%
# 	CCONJ: 96.26%
# 	DET: 96.93%
# 	INTJ: 60.00%
# 	NOUN: 98.04%
# 	NUM: 94.34%
# 	PART: 92.42%
# 	PRON: 98.31%
# 	PROPN: 94.09%
# 	PUNCT: 99.95%
# 	SCONJ: 96.21%
# 	SYM: 25.00%
# 	VERB: 97.43%
# 	X: 86.73%

# %%
get_measures(test_xpos_standard, test_xpos_preds)  # measures per class are not as informative here
# Out:
# MEASURES:
# Accuracy: 89.27%
# Precision (weighted): 88.95%
# Recall (weighted): 89.27%
# F1 (weighted): 88.81%
# Matthew's Correlation Coefficient: 88.83%

# %% [markdown]
# ### EXECUTION - HISTORICAL

# %%
# The same is done with the historical data.
hist_upos_tokens, hist_upos_preds = extract_conllu_data(upos_predictions, 'feats', sentences=False, fulltext=False)
hist_xpos_tokens, hist_xpos_preds = extract_conllu_data(xpos_predictions, 'deprel', sentences=False, fulltext=False)

hist_upos_preds = [list(x.keys())[0] for x in hist_upos_preds]

# %%
# Retrieving the gold standard tags - since we have two different files for XPOS and UPOS annotations we need two function calls
_, hist_upos_standard, _ = get_marmot_tags_and_tokens(upos_standard)
_, _, hist_xpos_standard = get_marmot_tags_and_tokens(xpos_standard)

# %%
get_measures(hist_upos_standard, hist_upos_preds, details=True)
# Out:
# MEASURES:
# Accuracy: 90.19%
# Precision (weighted): 90.35%
# Recall (weighted): 90.19%
# F1 (weighted): 90.18%
# Matthew's Correlation Coefficient: 88.86%
#
# MEASURES PER CLASS:
# Precision:
# 	ADJ: 80.48%
# 	ADP: 99.49%
# 	ADV: 85.03%
# 	AUX: 82.26%
# 	CCONJ: 97.20%
# 	DET: 93.47%
# 	NOUN: 89.12%
# 	NUM: 96.97%
# 	PART: 76.38%
# 	PRON: 90.87%
# 	PROPN: 78.65%
# 	PUNCT: 100.00%
# 	SCONJ: 86.26%
# 	VERB: 91.32%
# 	X: 63.16%
# Recall:
# 	ADJ: 84.61%
# 	ADP: 98.74%
# 	ADV: 83.78%
# 	AUX: 85.83%
# 	CCONJ: 95.94%
# 	DET: 74.82%
# 	NOUN: 90.79%
# 	NUM: 72.73%
# 	PART: 73.43%
# 	PRON: 85.71%
# 	PROPN: 86.04%
# 	PUNCT: 100.00%
# 	SCONJ: 91.00%
# 	VERB: 91.88%
# 	X: 50.70%

# %%
get_measures(hist_xpos_standard, hist_xpos_preds)
# Out:
# MEASURES:
# Accuracy: 78.75%
# Precision (weighted): 79.69%
# Recall (weighted): 78.75%
# F1 (weighted): 78.35%
# Matthew's Correlation Coefficient: 78.08%

# %%
comparison_upos = get_comparison(hist_upos_standard, hist_upos_preds, hist_upos_tokens)
comparison_upos.to_excel('../data/mistakes/marmot_UPOS_mistakes.xlsx')

# %%
comparison_xpos = get_comparison(hist_xpos_standard, hist_xpos_preds, hist_xpos_tokens)
comparison_xpos.to_excel('../data/mistakes/marmot_XPOS_mistakes.xlsx')

# %%
comparison_upos
# Out:
#                  Token                            Context Gold Standard  \
# 0             Melchior              mój Melchior urodzony         PROPN
# 1            Komornika               Jana Komornika ziemi          NOUN
# 2                    ś                         bratem ś .             X
# 3           Pinińskich           z Pinińskich właścicieli         PROPN
# 4                 Dóbr          właścicieli Dóbr Strużewo          NOUN
# 5              Dąbrowy                   , Dąbrowy części         PROPN
# 6                   śp                        że śp Dziad             X
# 7         Dobrzyńskiej              ziemi Dobrzyńskiej za         PROPN
# 8                Panna              siostra Panna Urszula          NOUN
# 9                   śp                          miał śp .             X
# 10            Melchior                . Melchior czterech         PROPN
# 11               jedną                     i jedną ciotkę           NUM
# 12              Ciotka                        – Ciotka za          NOUN
# 13                  17                          było 17 .           NUM
# 14                było                Antonich było dwóch           AUX
# 15             Niewiem                        . Niewiem o          VERB
# 16              jakoby                     – jakoby Dziad         SCONJ
# 17               Dziad                  jakoby Dziad jego          NOUN
# 18                jego                       Dziad jego a           DET
# 19            Starostą                 podobno Starostą ,          NOUN
# 20           Potockich                  Domem Potockich ,         PROPN
# 21                jego                  całą jego rodzinę           DET
# 22          chłopczyna                był chłopczyna więc          NOUN
# 23                  to                           co to za          PRON
# 24               jeden                         za jeden .           NUM
# 25            Starosta                  Pan Starosta całą          NOUN
# 26              rychło                 natury rychło ujął           ADV
# 27                 tak                        i tak umiał           ADV
# 28             Patrona                  swojego Patrona ,          NOUN
# 29                Panu       zaproponował Panu Potockiemu          NOUN
# 30                Myśl                         . Myśl się          NOUN
# 31                Panu           podobała Panu Potockiemu          NOUN
# 32                Panu      zaproponował Panu Melchiorowi          NOUN
# 33          Szczęśliwa                  . Szczęśliwa była           ADJ
# 34              Dziada                  dla Dziada mojego          NOUN
# 35                jego                 przyszłości jego .           DET
# 36                Panu              Dziad Panu Potockiemu          NOUN
# 37                 był                 Potockiemu był jak           AUX
# 38                 owe                       na owe czasy           DET
# 39              piękny                     czasy piękny –           ADJ
# 40                 tem             ujęty tem zaproponował          PRON
# 41                jego              początek jego fortuny           DET
# 42                  to                       mogło to być           AUX
# 43                 być                       to być około           AUX
# 44            Halickim                       w Halickim ,           ADJ
# 45               Panną                   z Panną Kobylską          NOUN
# 46            Kobylską                   Panną Kobylską ,         PROPN
# 47               Około                       . Około roku          PART
# 48            Dzianott                domu Dzianott wdowa         PROPN
# 49                  by                  dworu by zapłacić         SCONJ
# 50                rada                        – rada była           ADJ
# 51            gosposia             była gosposia gościowi          NOUN
# 52              Jesteś                     ? Jesteś wdowa          VERB
# 53               wdowa                     Jesteś wdowa –          NOUN
# 54             wdowiec                       ja wdowiec –          NOUN
# 55                  że                          ale że mi         SCONJ
# 56                więc                      , więc jeżeli         CCONJ
# 57              Pannie                  wstąpi Pannie się          NOUN
# 58             Dziekan                 ówczesny Dziekan i          NOUN
# 59              Oyciec              mój Oyciec Franciszek          NOUN
# 60             osiedli                   nauki osiedli na          VERB
# 61               Babki                      mojej Babki ,          NOUN
# 62                pono                       która pono w          PART
# 63        Czermińskiej         starościny Czermińskiej we         PROPN
# 64               druga                         , druga za           ADJ
# 65       Świeżawskiego         za Świeżawskiego komornika         PROPN
# 66             Cyrkule               w Cyrkule Samborskim          NOUN
# 67          Samborskim               Cyrkule Samborskim .         PROPN
# 68               jeden                        – jeden był           NUM
# 69               oddał                swój oddał akademii          VERB
# 70               Abbum         drzwiami Abbum Treterianum             X
# 71         Treterianum                Abbum Treterianum .             X
# 72               Lwowa           bombardowaniu Lwowa roku         PROPN
# 73             została                        w została w          VERB
# 74          zniszczały                    te zniszczały .          VERB
# 75                jego                         Syn jego a           DET
# 76                  to                     , to zarządzał          PART
# 77                  to                    , to dzierżawił          PART
# 78           oświecony               katafalk oświecony a          VERB
# 79               Zaraz                         . Zaraz na           ADV
# 80                Tobą                      z Tobą Stasiu          PRON
# 81                tyle                      Stasiu tyle a           DET
# 82                 mię                   Zostawiasz mię z          PRON
# 83                zato                           – zato ,          PRON
# 84                  Ci                       ażeby Ci Bóg          PRON
# 85                 Bóg                          Ci Bóg na          NOUN
# 86                 ich               obracają ich rodziny           DET
# 87         Świerzawski              wuj Świerzawski kuzyn         PROPN
# 88        Polanowskich               kuzyn Polanowskich z         PROPN
# 89            oblegany                     Pań oblegany –           ADJ
# 90                 móy            Dziadek móy Ostaszewski           DET
# 91             służąca               musiała służąca całą          NOUN
# 92             Niewiem                    . Niewiem jakim          VERB
# 93          Treterówną               siostrą Treterówną -         PROPN
# 94          Treterówną               siostrą Treterówną –         PROPN
# 95                  aż                           , aż się          PART
# 96                 nim                        się nim Pan          PRON
# 97                 móy                 Ojciec móy sierota           DET
# 98                 być                       to być około           AUX
# 99          podpodczas                 – podpodczas wojen           ADP
# 100             Cobary              Sachsen Cobary Ułanów             X
# 101             Ułanów                Cobary Ułanów mając          NOUN
# 102                 14                           lat 14 .           NUM
# 103           niewiele          czasów niewiele opowiadał           DET
# 104                  ś                             mi ś .             X
# 105          najwięcej                  a najwięcej czasu           ADJ
# 106             Oyciec                    a Oyciec ciągle          NOUN
# 107                móy                       . móy Oyciec           DET
# 108             Oyciec                   móy Oyciec około          NOUN
# 109              około                  Oyciec około 1808           ADP
# 110               1808                       około 1808 –           ADJ
# 111               1809                        albo 1809 –           ADJ
# 112                był                    Iglan był ranny          VERB
# 113             pieszy              pułk pieszy Francuzów           ADJ
# 114          skrzętnem    fortuny skrzętnem gospodarstwem           ADJ
# 115                tem                         po tem jak          PRON
# 116                set                     parę set sztuk           NUM
# 117      Rozwadowskiej           Pani Rozwadowskiej 10000         PROPN
# 118      Rozwadowskiej             Pani Rozwadowskiej nie         PROPN
# 119           Dziedzic             Nowy Dziedzic wchodził          NOUN
# 120            któremi              nad któremi obeymował           DET
# 121          pierwszey    policyjną pierwszey instantacyi           ADJ
# 122                Zaś                       . Zaś daniny         CCONJ
# 123               byli                        - byli więc          VERB
# 124                 ci                         – ci winni          PRON
# 125              pewną               odrabiać pewną ilość           ADJ
# 126                 ci                     - ci odrabiali          PRON
# 127               tego                      Oprócz tego z           DET
# 128              jeden              korce jeden gospodarz           NUM
# 129               tego                     Oprócz tego ci           DET
# 130                 ci                          tego ci i          PRON
# 131             spaśne                     zwane spaśne -          NOUN
# 132              pewną                chałupy pewną ilość           ADJ
# 133          pastwisko                - pastwisko ratował          NOUN
# 134             Wieleż                        . Wieleż to           DET
# 135                 to                     Wieleż to razy          PART
# 136               jego                    że jego kmiecie           DET
# 137             suchey                 morgów suchey łąki           ADJ
# 138       nayskładniey            a nayskładniey położone           ADV
# 139             Niebył                        . Niebył to           AUX
# 140                 to                Niebył to obowiązek           AUX
# 141         Oycowskiey                     . Oycowskiey .           ADJ
# 142                tak              obszarze tak dworskim         CCONJ
# 143            poddani                - poddani uwolnieni          NOUN
# 144             takiem             przy takiem obciążeniu           DET
# 145                tak                   jednakże tak nie           ADV
# 146               Herb                 był Herb Dziedzica          NOUN
# 147          Dziedzica                   Herb Dziedzica –          NOUN
# 148             dokoła                     a dokoła napis           ADP
# 149           Dominium            napis Dominium Bludniki          NOUN
# 150       Nieszlachcic             . Nieszlachcic niemógł          NOUN
# 151           Dziedzic             . Dziedzic postanawiał          NOUN
# 152             swojem                  na swojem mieycus           DET
# 153      Mandatariusza            mieycus Mandatariusza -          NOUN
# 154                Był                          . Był też          VERB
# 155            dopokąd                        – dopokąd z         SCONJ
# 156            Dominii             z Dominii nieprzyniósł          NOUN
# 157                  A                        . A chociaż         CCONJ
# 158            chociaż                        A chociaż i         SCONJ
# 159              ktoby                        a ktoby był          PRON
# 160          szlachcic                 Podola szlachcic w          NOUN
# 161          poddanych             zdzierstwa poddanych –          NOUN
# 162                móy                 Dziadek móy mawiał           DET
# 163               tego                      Pana tego nie           DET
# 164           ludowemi              dziś ludowemi zwanych           ADJ
# 165              lizną                czasem lizną trochę          VERB
# 166             trochę                lizną trochę łaciny           DET
# 167             trochę                   się trochę prawa           DET
# 168              prawa                     trochę prawa –          NOUN
# 169        manipulacyi            – manipulacyi urzędowey          NOUN
# 170          urzędowey            manipulacyi urzędowey –           ADJ
# 171         Starostwie                     w Starostwie w          NOUN
# 172            Cyrkule                        w Cyrkule i          NOUN
# 173      Mandataryusza              czyli Mandataryusza .          NOUN
# 174       Mandatyrusza          . Mandatyrusza przyjmował          NOUN
# 175           Dziedzic             przyjmował Dziedzic na          NOUN
# 176       Mandataryusz            . Mandataryusz pobierał          NOUN
# 177               opał                pomieszkanie opał –          NOUN
# 178          Dziedzica             zastępował Dziedzica .          NOUN
# 179            dotacyi    szczupłey dotacyi uwzględniając          NOUN
# 180                one                        w one czasy           DET
# 181                  4                  dzisiejszych 4 do           NUM
# 182               żyta           korzec żyta dzisiejszych          NOUN
# 183                  1                  dzisiejszych 1 fl           NUM
# 184                 fl                             1 fl –             X
# 185                 10                       korzec 10 do           NUM
# 186            przytem                mając przytem jakiś          PRON
# 187                 ci                   Panowie ci mieli           DET
# 188              ładąn                       – ładąn parą           ADJ
# 189                 fl                           600 fl .             X
# 190                móy                      gdy móy Dziad           DET
# 191              jeden                          – jeden z           NUM
# 192               jego                doskonale jego Syna           DET
# 193                 to                       może to jego          PART
# 194             dokoła               obszerna dokoła ławy           ADP
# 195            niewiem                      – niewiem czy          VERB
# 196                czy                      niewiem czy z          PART
# 197                czy                         jaką czy z          PART
# 198            naprzód                      się naprzód i           ADP
# 199               Panu                co Panu Dziedzicowi          NOUN
# 200        Dziedzicowi            Panu Dziedzicowi chodzi          NOUN
# 201                móy           Dziadek móy odpowiedział           DET
# 202         człowiecze                   Ty człowiecze na          NOUN
# 203                  A                        ? A wówczas         CCONJ
# 204           Dziedzic              żeby Dziedzic przyjął          NOUN
# 205               jego                 przyjął jego pomoc           DET
# 206             Takich                . Takich gospodarzy           DET
# 207              mojey                   za mojey pamięci           DET
# 208                owe                        w owe czasy           DET
# 209                był                      i był jaszcze          VERB
# 210            jaszcze                    był jaszcze tam          PART
# 211          księżunio                     , księżunio od          NOUN
# 212                  I                            . I tak         CCONJ
# 213             późney                 tak późney dokupił           ADV
# 214                móy                  Dziad móy Dorchów           DET
# 215               Toje                        – Toje diło             X
# 216               diło                   Toje diło daruju             X
# 217             daruju             diło daruju ukochanomu             X
# 218         ukochanomu             daruju ukochanomu Synu             X
# 219               Synu             ukochanomu Synu mojomu             X
# 220             mojomu             Synu mojomu Mychayłowu             X
# 221         Mychayłowu                mojomu Mychayłowu .             X
# 222              iOycu              Józefowi iOycu mojemu          NOUN
# 223                móy                   Oyciec móy objął           DET
# 224                tak                          to tak aż          PART
# 225               Oyca                   mojego Oyca pono          NOUN
# 226               pono                     Oyca pono 1813          PART
# 227               1813                     pono 1813 albo           ADJ
# 228               1814                        albo 1814 –           ADJ
# 229                móy                     Dziadek móy do           DET
# 230             Siebie                       do Siebie do          PRON
# 231               Oyca                dośmierci Oyca przy          NOUN
# 232                Nim                  przy Nim zostawał          PRON
# 233                móy                     Dziadek móy ku           DET
# 234                 Mu             Zdejmował Mu kataraktę          PRON
# 235             Doktor       kataraktę Doktor Słowikowski          NOUN
# 236                ile                        i ile sobie           ADV
# 237               1826                       około 1826 .           ADJ
# 238               pono                       końcu pono w          PART
# 239           niewinem                    Lipa niewinem .          VERB
# 240         Zabilskich            Stanisława Zabilskich –         PROPN
# 241           jedynaka               Syna jedynaka Sabina          NOUN
# 242             Oyciec                  go Oyciec odumarł          NOUN
# 243              Oycem                za Oycem doszedłszy          NOUN
# 244                 24                        około 24 na           NUM
# 245              Matkę                         na Matkę –          NOUN
# 246               temu                     żona temu pono           DET
# 247               pono                        temu pono z          PART
# 248            Dorchów           zostawił Dorchów swojemu         PROPN
# 249             więcey        gospodarzem więcey fantasta           ADV
# 250              wgłos                   czytywał wgłos „           ADV
# 251                Był                       . Był bardzo          VERB
# 252                tey                    do tey praktyki           DET
# 253                 ci                    ale ci niemogli          PRON
# 254           niemogli                  ci niemogli długo          VERB
# 255           nietylko                 – nietylko czeladź          PART
# 256            czeladź               nietylko czeladź ale          NOUN
# 257              sądny                      więc sądny to           ADJ
# 258           niemożna             obeyściu niemożna było          VERB
# 259                mim                           po mim ,          PRON
# 260               Oyca                mojego Oyca spadała          NOUN
# 261           rodzonym          swoim rodzonym Treterowej           ADJ
# 262         Treterowej              rodzonym Treterowej i         PROPN
# 263               Oyca                     śmierci Oyca z          NOUN
# 264              Panną                      z Panną Julią          NOUN
# 265         Świeżyńską          Julią Świeżyńską urodzoną         PROPN
# 266           urodzoną             Świeżyńską urodzoną ze           ADJ
# 267         Zawadzkich                    ze Zawadzkich –         PROPN
# 268          Stryiskim                      w Stryiskim w         PROPN
# 269        Kruszelnicę                  czy Kruszelnicę –         PROPN
# 270             jednem                 na jednem obeyściu           NUM
# 271                  2                          - 2 Panny           NUM
# 272              Panny                   2 Panny niemając          NOUN
# 273              Panna                  fatum Panna Julia          NOUN
# 274           Rudzkich             Państwa Rudzkich gdzie         PROPN
# 275                tąd                       z tąd bywała           ADV
# 276              Jakby              . Jakby instynktownie         SCONJ
# 277                jey                    moja jey znieść          PRON
# 278           niemogła                  znieść niemogła .          VERB
# 279            osiadły                   Józef osiadły na           ADJ
# 280              Panny                  krewni Panny Juli          NOUN
# 281              niema               że niema sukcessorów          VERB
# 282               Panu                  ale Panu Józefowi          NOUN
# 283         niechciało         Józefowi niechciało ruszać          VERB
# 284               hoża                       się hoża jak           ADJ
# 285              Panna                  łania Panna Julia          NOUN
# 286               Było                          . Było to           AUX
# 287                 to                      Było to około           AUX
# 288              około                      to około 1829           ADP
# 289               tego               małżeństwa tego była           DET
# 290               była                   tego była jedyna          VERB
# 291        Siemiginowa          sukcessorka Siemiginowa –         PROPN
# 292         Bałamuciła           . Bałamuciła przebierała          VERB
# 293              około                  młodzika około 24           ADP
# 294                 24                       około 24 lat           ADJ
# 295          liczącego                    lat liczącego –          VERB
# 296          próżniaka           sybarytę próżniaka toteż          NOUN
# 297          Separacya              nastąpiła Separacya .          NOUN
# 298            secundo                 Julia secundo voto             X
# 299               voto             secundo voto Szołayska             X
# 300              Mosty                  przyległe Mosty .         PROPN
# 301              Panną                 z Panną Polanowską          NOUN
# 302             Ciotką                      a Ciotką Pana          NOUN
# 303                jak                        Ale jak się         SCONJ
# 304                móy              dowiedział móy Oyciec           DET
# 305           Bludniki                  o Bludniki służbę         PROPN
# 306              Matce                       Po Matce wuy          NOUN
# 307                wuy                     Matce wuy Oyca          NOUN
# 308               Oyca              wuy Oyca Pieścioroski          NOUN
# 309                 Mu              zaproponował Mu Pannę          PRON
# 310              Pannę                Mu Pannę Franciszkę          NOUN
# 311        Ostaszewską       Franciszkę Ostaszewską córkę         PROPN
# 312          Chorążego          córkę Chorążego Kawaleryi          NOUN
# 313          Kawaleryi      Chorążego Kawaleryi Narodowey          NOUN
# 314          Narodowey              Kawaleryi Narodowey i           ADJ
# 315          Dziedzica               i Dziedzica Zarszyna          NOUN
# 316          Załęskich                     ze Załęskich .         PROPN
# 317              Jakoż              . Jakoż zaprezentował         CCONJ
# 318                 Go           zaprezentował Go Państwu          PRON
# 319       Ostaszewskim           Państwu Ostaszewskim Pan         PROPN
# 320               Oycu                      – Oycu mojemu          NOUN
# 321              Panna                     mojemu Panna i          NOUN
# 322                Jey           staropolski Jey Rodziców           DET
# 323       etykietalney     Zamiast etykietalney pierwszey           ADJ
# 324          pierwszey      etykietalney pierwszey wizyty           ADJ
# 325             został                – został zatrzymany          VERB
# 326               Veni                           . Veni –             X
# 327               vici                           – vici .             X
# 328            Niewiem                      . Niewiem czy          VERB
# 329             swojey               razą swojey bytności           DET
# 330                 al               malowidłem al fresco             X
# 331             fresco                        al fresco –             X
# 332            Bludnik                   widoki Bludnik i         PROPN
# 333              Skała                         – Skała na          NOUN
# 334               niey                    na niey Sokołów          PRON
# 335            Łomnica                    dołem Łomnica –         PROPN
# 336                  Ś                          widok Ś -             X
# 337     tegoStanisława         - tegoStanisława klasztoru             X
# 338            Łomnicą              nad Łomnicą wpadającą         PROPN
# 339           Dniestru                      do Dniestru ,         PROPN
# 340                 to                         , to znowu           AUX
# 341              Ruiny                  znowu Ruiny zamku          NOUN
# 342             opodal                Halickiego opodal –           ADP
# 343              droga                   wreszcie droga z          NOUN
# 344               niey                  przy niey kaplica          PRON
# 345      nayjświętszey        kaplica nayjświętszey Panny           ADJ
# 346              Panny  nayjświętszey Panny Niepokalanego          NOUN
# 347              daley                        – daley jak           ADV
# 348                jak                    daley jak droga           ADV
# 349           Swiętego              kaplica Swiętego Jana           ADJ
# 350                 to                    Wszystko to tak          PRON
# 351           podobnem        czemś podobnem niespotkałem           ADJ
# 352       niespotkałem        podobnem niespotkałem nawet          VERB
# 353          Łańcuckim         pałacu Łańcuckim nierobiły         PROPN
# 354                jak               wrażenia jak wówczas           ADV
# 355                  i                        też i temat         CCONJ
# 356            łamiąca                Łomnica łamiąca się           ADJ
# 357              skałą                   pod skałą wysoką          NOUN
# 358             wysoką              skałą wysoką oddającą           ADJ
# 359              ujęta                          – ujęta w          VERB
# 360             strome                w strome pochyłości           ADJ
# 361            Łomnicy                 ku Łomnicy porosłe         PROPN
# 362              Skała                   . Skała ożywiona          NOUN
# 363           tysiącem           ożywiona tysiącem gniazd           NUM
# 364       przyjezdnych    witających przyjezdnych wesołym          NOUN
# 365         Bludnickey              na Bludnickey stronie           ADJ
# 366            Karpaty     nibieszczeją Karpaty huculskie         PROPN
# 367              droga                         a droga do          NOUN
# 368           spaśnemi         ożewionemi spaśnemi wołami           ADJ
# 369         przedewsią           droga przedewsią smętarz          NOUN
# 370            okolony                   płotem okolony –           ADJ
# 371            główney               drogi główney traktu           ADJ
# 372              prawo                         na prawo –           ADV
# 373             prawey                   po prawey ciągną           ADJ
# 374              gumna                  się gumna staynie          NOUN
# 375            staynie             gumna staynie wozownia          NOUN
# 376           oddziela                   żywy oddziela od          VERB
# 377           pośrodku                   a pośrodku front           ADP
# 378         kamiennemi              płytami kamiennemi na           ADJ
# 379                tey                    w tey proporcyi           DET
# 380          proporcyi                  tey proporcyi jak          NOUN
# 381                jak               proporcyi jak środek           ADV
# 382                był                       – był zamiar          VERB
# 383               Oyca                  zamiar Oyca takie          NOUN
# 384                  ś                 prawdopodobnie ś .             X
# 385              Dziad                    . Dziad murować          NOUN
# 386           Wracając                      . Wracając do          NOUN
# 387                był                    pokoi był drugi          VERB
# 388             gładki                 szafirowy gładki ,           ADJ
# 389              tylko                         , tylko od          PART
# 390              szale         koloru szale podtrzymywane          NOUN
# 391              takoż            orłami takoż bronzowemi           ADV
# 392             obicie                         , obicie z          NOUN
# 393          jedwabney           żółtej jedwabney materyi           ADJ
# 394               Sala                     . Sala jadalna          NOUN
# 395             freski                   to freski bardzo          NOUN
# 396                jak                     palmowe jak na           ADV
# 397               dziś                          po dziś .          NOUN
# 398                jak                    pamiętam jak mi         SCONJ
# 399              niemi                pod niemi siedzenia          PRON
# 400             takowy               most takowy obszerny           DET
# 401                tey                    Dokoło tey kępy           DET
# 402               była                  kępy była szeroka          VERB
# 403            zarosła              fosa zarosła szuwarem           ADJ
# 404            trzciną                        i trzciną –          NOUN
# 405          widocznie                – widocznie miejsce           ADV
# 406                 to                    miejsce to było           DET
# 407                był                 kamiennym był duży          VERB
# 408              Skała                          . Skała w          NOUN
# 409       nieciosanemi       bryłami nieciosanemi ułożona           ADJ
# 410                ani         niechwytało ani pruchniało          PART
# 411           Swiętego                broda Swiętego była          NOUN
# 412             jednem                   w jednem miejscu           NUM
# 413          widocznie                  – widocznie przez           ADV
# 414              Jakoż                   . Jakoż pamiętam         SCONJ
# 415                tem                        o tem takie          PRON
# 416          arędujący             Sadownik arędujący ten          VERB
# 417                tey             dopuścić tey zuchwałey           DET
# 418          zuchwałey             tey zuchwałey rozpusty           ADJ
# 419           Oyciciec                    . Oyciciec jego          NOUN
# 420               jego          Oyciciec jego zobaczywszy           DET
# 421               była                   Kapliczka była u          VERB
# 422         wszystkich                     u wszystkich w           DET
# 423           zwodzony               drewniany zwodzony .           ADJ
# 424             Oyciec                 Dopiero Oyciec móy          NOUN
# 425                móy                      Oyciec móy go           DET
# 426                Był                      . Był wówczas          VERB
# 427               most                   się most murował          NOUN
# 428             niebył         Jeszcze niebył zasklepiony           AUX
# 429              cegły                    kamień cegły na          NOUN
# 430                czy               Treter czy Swieżaski          PART
# 431            jeźdźca               uniósł jeźdźca pędem          NOUN
# 432             wprost                    pędem wprost na          PART
# 433           murujący                    na murujący się          VERB
# 434                mię                        ratuj mię !          PRON
# 435               dwór                       – dwór także          NOUN
# 436           okoloney             kępie okoloney różanym           ADJ
# 437                jej            obszar jej szczuplejszy           DET
# 438       szczuplejszy        jej szczuplejszy dochodziło           ADJ
# 439             dokoła                    ale dokoła staw           ADP
# 440             czółno                 i czółno przyjemna          NOUN
# 441             rześki             Dziadek rześki starzec           ADJ
# 442             swojim                  pobycie swojim na           DET
# 443            Kresach                       na Kresach ,         PROPN
# 444              oczem                Krasickiego oczem w          PRON
# 445             piękna                      – piękna miła           ADJ
# 446      obywatelskiey    dystynkcy obywatelskiey Matrona           ADJ
# 447            Matrona            obywatelskiey Matrona –          NOUN
# 448                był                          Dom był w           AUX
# 449              całem                  w całem Sanockiem           ADJ
# 450               jako                  domowych jako też           ADV
# 451                owe                       na owe czasy           DET
# 452           wzorowem                   czasy wzorowem .           ADJ
# 453            niebyło                   A niebyło prawie          VERB
# 454             prawie                niebyło prawie domu           ADV
# 455                czy                   bliżej czy dalej          PART
# 456             niebył           dalej niebył skoligacony           AUX
# 457        skoligacony               niebył skoligacony z           ADJ
# 458      Ostaszewskich        Kazimierzów Ostaszewskich .         PROPN
# 459               Była                         . Była też          VERB
# 460              Matka        pomieszkanie Matka Kraińska          NOUN
# 461                  A                            . A gdy         CCONJ
# 462      Ostaszewskiej              Pani Ostaszewskiej do         PROPN
# 463                jey                      50 jey wnuków           DET
# 464               tego                         Do tego to           DET
# 465                 to                       tego to domu          PART
# 466                móy              przyjechał móy Oyciec           DET
# 467             Oyciec                      móy Oyciec do          NOUN
# 468             Swojey                    do Swojey Frani           DET
# 469                móy                Oyciec móy wystąpił           DET
# 470                owe                       na owe czasy           DET
# 471           gniadych                rosłych gniadych ze           ADJ
# 472    Simiginowskiego     stada Simiginowskiego wartości           ADJ
# 473              Czyli                         . Czyli na         CCONJ
# 474                owe                       na owe czasy           DET
# 475                 fl                           120 fl .             X
# 476                 to                       Była to cena          PRON
# 477      Kopestyńskich      Komornikostwa Kopestyńskich –         PROPN
# 478         kochającey             grona kochającey Matkę           ADJ
# 479               lubo                     a lubo okolica         SCONJ
# 480                 to                      , to niemogła          PART
# 481                 Ją              Odwiedzali Ją Rodzice          PRON
# 482         Sanoczanie               Rodzice Sanoczanie ,         PROPN
# 483              niemi                z niemi nieodzownie          PRON
# 484             troski           nieodzownie troski obawy          NOUN
# 485             jedney                    z jedney strony           ADJ
# 486              Matkę                   końcu Matkę moją          NOUN
# 487               było                Dzieci było ośmioro           AUX
# 488              małem             umarła małem dzieckiem           ADJ
# 489               niey                  po niey przyszedł          PRON
# 490                ten                        , ten małym          PRON
# 491             Chrztu                 do Chrztu Świętego          NOUN
# 492         niechciały                chować niechciały –          VERB
# 493              ponim                         i ponim ja          PRON
# 494           nietylko         Ale nietylko niepowodzenie         CCONJ
# 495           troygiem            z troygiem naystarszych           NUM
# 496          pomarłemi         dziećmi pomarłemi okrywały           ADJ
# 497           okrywały          pomarłemi okrywały żałobą          VERB
# 498               były                         – były też          VERB
# 499               pono                ożenieniu pono 1815          PART
# 500             Oyciec              wyjechał Oyciec konno          NOUN
# 501    naypięknieyszey       wśród naypięknieyszey pogody           ADJ
# 502                ani                       – ani kropli          PART
# 503             świeci                   słońce świeci aż          VERB
# 504            Łomnicy                       na Łomnicy –         PROPN
# 505                tak                        – tak nagle          PART
# 506            Dniestr            trzeciey Dniestr sparty         PROPN
# 507         Łomnickiey                 wody Łomnickiey że           ADJ
# 508                nim                      że nim Oyciec         SCONJ
# 509             Oyciec                     nim Oyciec się          NOUN
# 510            została         płaszczyzna została zalana          VERB
# 511             szkoda               inwentarza szkoda na          NOUN
# 512                owe                       na owe czasy           DET
# 513         stanowiąca               majątku stanowiąca .           ADJ
# 514                owe                        w owe czasy           DET
# 515            fortuny                   , fortuny prędko          NOUN
# 516                  a                Zarszynie a chłopcy         CCONJ
# 517           egzamina                      ja egzamina w          NOUN
# 518                825                   urodzony 825 był           ADJ
# 519              febra                        – febra mię          NOUN
# 520                mię                  febra mię męczyła          PRON
# 521          niemogłem                    , niemogłem się          VERB
# 522                jey                     się jey pozbyć          PRON
# 523                 to                          Już to od          PART
# 524                 to                  urodzenia to jest          PRON
# 525               1821                     lipca 1821 był           ADJ
# 526                tak                   wątły tak dalece          PART
# 527           niemiano               że niemiano nadzieji          VERB
# 528             Troska                    . Troska obojga          NOUN
# 529             obojga                Troska obojga moich           NUM
# 530                mię                         o mię była          PRON
# 531       zatrętwiałem               raz zatrętwiałem tak          VERB
# 532                mię                     że mię kompano          PRON
# 533             nieraz                    m nieraz złapał          NOUN
# 534                mię                   odchuchano mię –          PRON
# 535            została                    – została tylko          VERB
# 536              tempy                      i tempy słuch           ADJ
# 537                mię                  odwiedzała mię co          PRON
# 538             kupsze                       jak kupsze .          NOUN
# 539              Biało                        . Biało się           ADV
# 540             dużemi             okryta dużemi koralami           ADJ
# 541              zawoy                  jak zawoy turecki          NOUN
# 542          wzorzysta                turecki wzorzysta .           ADJ
# 543                jak            młodzieniaszkiem jak po           ADV
# 544                tey                       od tey która          PRON
# 545               teme                      w teme słyszę           DET
# 546         niekontent                  się niekontent że           ADJ
# 547                mię                         że mię tak          PRON
# 548            poufale                      tak poufale w           ADV
# 549                 to                         a to jakaś          PRON
# 550               było                    których było 30           AUX
# 551                  x                             30 x i             X
# 552                  6                           były 6 x           NUM
# 553                  x                              6 x i             X
# 554                  3                              i 3 x           NUM
# 555                  x                              3 x –             X
# 556               pono                 redukcyi pono 1811          PART
# 557               1811                        pono 1811 .           ADJ
# 558                  A                   – A niepoznajesz         CCONJ
# 559                mię                 niepoznajesz mię ,          PRON
# 560               taże                          , taże ja          PART
# 561               Więc                        ! Więc choć         CCONJ
# 562                czy                         em czy mię          PART
# 563                mię                        czy mię kto          PRON
# 564                one                        W one czasy           DET
# 565                tey                       na tey ulicy           DET
# 566               dużo                    ulicy dużo było           DET
# 567               hożą                       to hożą tęga           ADJ
# 568               tęga                hożą tęga średniego           ADJ
# 569            modrych             wzrostu modrych oczach           ADJ
# 570         ciemnoblnd           oczach ciemnoblnd włosów           ADJ
# 571          roumianey                o roumianey owalney           ADJ
# 572            owalney           roumianey owalney twarzy           ADJ
# 573            śniadey                     cery śniadey .           ADJ
# 574               Była                           . Była .          NOUN
# 575         przystoyna          . przystoyna usposobienia           ADJ
# 576          jednająca      towarzyskiego jednająca sobie          VERB
# 577              mojey                matki mojey spotkał           DET
# 578              Panem                    z Panem Józefem          NOUN
# 579       naymłodszych                od naymłodszych lat           ADJ
# 580              Matkę                       moją Matkę –          NOUN
# 581                tak                        i tak gdzie           ADV
# 582                mię              spotkało mię uprzejme          PRON
# 583                tym                 Dzięki tym pięknym           DET
# 584           nietylko              zachowanie nietylko w          PART
# 585       Golejowskich            Julianów Golejowskich z         PROPN
# 586            nietyle                      ale nietyle z          PART
# 587              Panem                   z Panem Julianem          NOUN
# 588              Panią                       z Panią Różą          NOUN
# 589       Czarnomskich          z Czarnomskich Golejowską         PROPN
# 590         Golejowską       Czarnomskich Golejowską były         PROPN
# 591        naywiększey            w naywiększey przyjaźni           ADJ
# 592            odemnie                starszego odemnie i          PRON
# 593             swojey                 Ciotce swojey Pani           DET
# 594            późniey             umarł późniey bezżenny           ADV
# 595               swóy             majątek swóy Antoniemu           DET
# 596                ich                towarzystwo ich dla           DET
# 597             obadwa                dokazywali obadwa –           NUM
# 598               mało                 o mało nieprzyszło           ADV
# 599             Oyciec                       a Oyciec móy          NOUN
# 600                móy                   Oyciec móy objął           DET
# 601       Czortkowskim                   w Czortkowskim ,         PROPN
# 602               pono               brat pono stryjeczny          PART
# 603         skończoney              po skończoney żałobie           ADJ
# 604              wdowa                    prędko wdowa po          NOUN
# 605                 Co                            . Co do           ADP
# 606            młodych   towarzystwa młodych Golejowskich           ADJ
# 607       Golejowskich             młodych Golejowskich –         PROPN
# 608               byli                     jakim byli śmy           AUX
# 609               Oyca                przez Oyca trzymani          NOUN
# 610             Kornel                       . Kornel był         PROPN
# 611           Łosiówną                       z Łosiówną –          VERB
# 612         Szczęsnego      za Szczęsnego Koziobrodzkiego         PROPN
# 613               dziś                      po dziś dzień          NOUN
# 614        poczciwości           Jan poczciwości człowiek          NOUN
# 615                jak                     go jak jakiego           ADV
# 616               były                  domem były ciągłe          VERB
# 617            Luboscy                  Państwo Luboscy –         PROPN
# 618              jedną                 córkę jedną ułomną           NUM
# 619             ułomną                     jedną ułomną –           ADJ
# 620            milutka            Marynia milutka powiena           ADJ
# 621            powiena                  milutka powiena –           ADJ
# 622               pono            Martynowie pono Janiccy          PART
# 623                 ci                     ale ci jakoteż          PRON
# 624            jakoteż                       ci jakoteż z         CCONJ
# 625           Woyniłów     należał Woyniłów Kopystyńskich         PROPN
# 626      Kopystyńskich           Woyniłów Kopystyńskich ,         PROPN
# 627           Żelibory           , Żelibory Kunaszowskich         PROPN
# 628      Kunaszowskich       Żelibory Kunaszowskich gdzie         PROPN
# 629             jednem                 która jednem okiem           ADJ
# 630               obie             nieszpetne obie wyszły           NUM
# 631                831                    powstaniu 831 –           ADJ
# 632                był                  drugi był późniey          VERB
# 633            późniey               był późniey sąsiadem           ADV
# 634                Ten                    . Ten niechciał          PRON
# 635                móy                      to móy Oyciec           DET
# 636             Oyciec               móy Oyciec zgorszony          NOUN
# 637              Panem        zgorszony Panem Władysławem          NOUN
# 638          niebędzie                 i niebędzie zawadą          VERB
# ...
# 120        NOUN
# 121        NOUN
# 122         ADP
# 123         AUX
# 124         DET
# 125         DET
# 126         DET
# 127        PRON
# 128         ADJ
# 129        PRON
# 130        NOUN
# 131         ADJ
# 132         DET
# 133         ADV
# 134        NOUN
# 135         AUX
# 136        PRON
# 137        NOUN
# 138        NOUN
# 139        VERB
# 140        PRON
# 141       PROPN
# 142         ADV
# 143         ADJ
# 144        NOUN
# 145        PART
# 146       PROPN
# 147       PROPN
# 148         ADV
# 149       PROPN
# 150       PROPN
# 151       PROPN
# 152        NOUN
# 153       PROPN
# 154         AUX
# 155         ADV
# 156       PROPN
# 157        PART
# 158        PART
# 159        NOUN
# 160        VERB
# 161         ADJ
# 162         ADJ
# 163        PRON
# 164        NOUN
# 165         ADJ
# 166         ADV
# 167         ADV
# 168         ADJ
# 169        VERB
# 170        NOUN
# 171       PROPN
# 172       PROPN
# 173       PROPN
# 174       PROPN
# 175       PROPN
# 176       PROPN
# 177        VERB
# 178       PROPN
# 179        VERB
# 180        PRON
# 181           X
# 182         ADJ
# 183         ADJ
# 184        NOUN
# 185           X
# 186        NOUN
# 187        PRON
# 188           X
# 189        NOUN
# 190         ADJ
# 191         ADJ
# 192        PRON
# 193         AUX
# 194         ADV
# 195        NOUN
# 196       CCONJ
# 197       CCONJ
# 198         ADV
# 199       PROPN
# 200       PROPN
# 201         ADJ
# 202        VERB
# 203        PART
# 204       PROPN
# 205        PRON
# 206         ADJ
# 207        NOUN
# 208         ADJ
# 209         AUX
# 210         ADJ
# 211       CCONJ
# 212        PART
# 213       SCONJ
# 214         ADJ
# 215       PROPN
# 216        VERB
# 217        NOUN
# 218        NOUN
# 219        NOUN
# 220        NOUN
# 221       PROPN
# 222       PROPN
# 223         ADJ
# 224         ADV
# 225       PROPN
# 226        VERB
# 227           X
# 228           X
# 229        NOUN
# 230       PROPN
# 231       PROPN
# 232       PROPN
# 233         ADJ
# 234       PROPN
# 235       PROPN
# 236         DET
# 237           X
# 238        VERB
# 239        NOUN
# 240         ADJ
# 241         ADJ
# 242       PROPN
# 243       PROPN
# 244         ADJ
# 245       PROPN
# 246         ADP
# 247        VERB
# 248        NOUN
# 249         ADJ
# 250        NOUN
# 251         AUX
# 252        NOUN
# 253         DET
# 254        NOUN
# 255         ADV
# 256        VERB
# 257        NOUN
# 258         ADJ
# 259         ADJ
# 260       PROPN
# 261        NOUN
# 262         ADJ
# 263       PROPN
# 264         ADJ
# 265         ADJ
# 266        NOUN
# 267         ADJ
# 268         ADJ
# 269        NOUN
# 270        NOUN
# 271         ADJ
# 272       PROPN
# 273       PROPN
# 274         ADJ
# 275        NOUN
# 276        PART
# 277        NOUN
# 278        NOUN
# 279        VERB
# 280       PROPN
# 281        NOUN
# 282       PROPN
# 283         ADV
# 284        NOUN
# 285       PROPN
# 286        VERB
# 287        PRON
# 288        PART
# 289        PRON
# 290         AUX
# 291         ADJ
# 292        NOUN
# 293        PART
# 294         NUM
# 295        NOUN
# 296        VERB
# 297       PROPN
# 298         ADV
# 299        VERB
# 300        NOUN
# 301         ADJ
# 302       PROPN
# 303         ADV
# 304         ADJ
# 305        NOUN
# 306       PROPN
# 307         ADJ
# 308       PROPN
# 309       PROPN
# 310       PROPN
# 311         ADJ
# 312       PROPN
# 313       PROPN
# 314       PROPN
# 315       PROPN
# 316         ADJ
# 317       PROPN
# 318       PROPN
# 319         ADJ
# 320        INTJ
# 321       PROPN
# 322         ADJ
# 323        NOUN
# 324        NOUN
# 325         AUX
# 326         ADJ
# 327        NOUN
# 328       SCONJ
# 329        NOUN
# 330        NOUN
# 331        NOUN
# 332        NOUN
# 333        VERB
# 334         ADJ
# 335        NOUN
# 336       PROPN
# 337       PROPN
# 338        NOUN
# 339        NOUN
# 340       SCONJ
# 341       PROPN
# 342         ADV
# 343         ADJ
# 344        NOUN
# 345        NOUN
# 346       PROPN
# 347         ADJ
# 348       SCONJ
# 349       PROPN
# 350         DET
# 351        NOUN
# 352         ADV
# 353         ADJ
# 354       SCONJ
# 355        PART
# 356        VERB
# 357         ADJ
# 358        NOUN
# 359         ADJ
# 360        NOUN
# 361        NOUN
# 362        VERB
# 363        NOUN
# 364         ADJ
# 365       PROPN
# 366        NOUN
# 367         ADJ
# 368        NOUN
# 369        VERB
# 370        NOUN
# 371        NOUN
# 372        NOUN
# 373        NOUN
# 374         ADJ
# 375         ADV
# 376           X
# 377         ADV
# 378        NOUN
# 379        NOUN
# 380        VERB
# 381       SCONJ
# 382         AUX
# 383       PROPN
# 384         AUX
# 385       PROPN
# 386        VERB
# 387         AUX
# 388        NOUN
# 389       CCONJ
# 390         ADV
# 391         ADP
# 392       CCONJ
# 393        NOUN
# 394       PROPN
# 395         ADJ
# 396       SCONJ
# 397         ADV
# 398         ADV
# 399        NOUN
# 400         ADJ
# 401        NOUN
# 402         AUX
# 403        VERB
# 404         ADJ
# 405        PART
# 406         AUX
# 407         AUX
# 408        VERB
# 409        NOUN
# 410       CCONJ
# 411       PROPN
# 412         ADJ
# 413        PART
# 414        PART
# 415        NOUN
# 416         ADJ
# 417        NOUN
# 418        NOUN
# 419        VERB
# 420        PRON
# 421         AUX
# 422        PRON
# 423        NOUN
# 424       PROPN
# 425        VERB
# 426         AUX
# 427         ADV
# 428        VERB
# 429         ADJ
# 430       CCONJ
# 431         ADJ
# 432         ADV
# 433         ADJ
# 434        NOUN
# 435           X
# 436        NOUN
# 437        PRON
# 438        NOUN
# 439         ADV
# 440         ADV
# 441        NOUN
# 442         ADJ
# 443        NOUN
# 444        NOUN
# 445        NOUN
# 446        NOUN
# 447       PROPN
# 448        VERB
# 449        NOUN
# 450       SCONJ
# 451         ADJ
# 452        NOUN
# 453         ADV
# 454        PART
# 455       CCONJ
# 456        VERB
# 457        NOUN
# 458         ADJ
# 459         AUX
# 460       PROPN
# 461        PART
# 462         ADJ
# 463        NOUN
# 464        PRON
# 465         AUX
# 466         ADJ
# 467       PROPN
# 468       PROPN
# 469         ADJ
# 470         ADJ
# 471        NOUN
# 472       PROPN
# 473        VERB
# 474         ADJ
# 475        NOUN
# 476         AUX
# 477         ADJ
# 478        NOUN
# 479       CCONJ
# 480       SCONJ
# 481         ADJ
# 482        NOUN
# 483        NOUN
# 484         ADJ
# 485        NOUN
# 486       PROPN
# 487        VERB
# 488        NOUN
# 489         ADJ
# 490         DET
# 491       PROPN
# 492        NOUN
# 493        PART
# 494         ADV
# 495        NOUN
# 496        VERB
# 497         ADJ
# 498         AUX
# 499        VERB
# 500       PROPN
# 501        NOUN
# 502       CCONJ
# 503        NOUN
# 504        NOUN
# 505         ADV
# 506        NOUN
# 507       PROPN
# 508        PRON
# 509        VERB
# 510         AUX
# 511        VERB
# 512         ADJ
# 513        NOUN
# 514         ADJ
# 515         ADJ
# 516        PART
# 517        VERB
# 518           X
# 519        VERB
# 520        NOUN
# 521         ADV
# 522        PART
# 523        PRON
# 524         AUX
# 525           X
# 526         ADV
# 527         ADP
# 528         ADJ
# 529        NOUN
# 530        NOUN
# 531        NOUN
# 532        NOUN
# 533         ADV
# 534        NOUN
# 535         AUX
# 536        NOUN
# 537        NOUN
# 538        VERB
# 539        VERB
# 540        NOUN
# 541         ADJ
# 542        NOUN
# 543       SCONJ
# 544        NOUN
# 545        NOUN
# 546        NOUN
# 547        NOUN
# 548        VERB
# 549        PART
# 550        VERB
# 551        NOUN
# 552         ADJ
# 553        NOUN
# 554         ADJ
# 555        NOUN
# 556        VERB
# 557           X
# 558        PART
# 559        NOUN
# 560       SCONJ
# 561       SCONJ
# 562       CCONJ
# 563        NOUN
# 564        PRON
# 565        NOUN
# 566         ADV
# 567        NOUN
# 568        NOUN
# 569        NOUN
# 570       CCONJ
# 571        NOUN
# 572        NOUN
# 573        NOUN
# 574         AUX
# 575        NOUN
# 576         ADJ
# 577        NOUN
# 578       PROPN
# 579        NOUN
# 580       PROPN
# 581        PART
# 582        NOUN
# 583        PRON
# 584         ADV
# 585         ADJ
# 586         ADV
# 587       PROPN
# 588         ADJ
# 589         ADJ
# 590         ADJ
# 591        NOUN
# 592         ADV
# 593        NOUN
# 594        NOUN
# 595         ADJ
# 596        PRON
# 597        NOUN
# 598         DET
# 599       PROPN
# 600         ADJ
# 601         ADJ
# 602        VERB
# 603        NOUN
# 604        VERB
# 605        PART
# 606        NOUN
# 607         ADJ
# 608        VERB
# 609       PROPN
# 610        NOUN
# 611       PROPN
# 612         ADJ
# 613         ADV
# 614        VERB
# 615       SCONJ
# 616         AUX
# 617         ADJ
# 618         ADJ
# 619        VERB
# 620        NOUN
# 621        NOUN
# 622        VERB
# 623         DET
# 624         DET
# 625        NOUN
# 626         ADJ
# 627       SCONJ
# 628         ADJ
# 629        NOUN
# 630        NOUN
# 631           X
# 632         AUX
# 633         ADJ
# 634         DET
# 635         ADJ
# 636       PROPN
# 637       PROPN
# 638         ADV
# 639        VERB
# 640           X
# 641       PROPN
# 642         AUX
# 643       PROPN
# 644        NOUN
# 645        VERB
# 646        VERB
# 647       PROPN
# 648         AUX
# 649        NOUN
# 650         ADV
# 651         ADJ
# 652         AUX
# 653        NOUN
# 654        NOUN
# 655        NOUN
# 656        NOUN
# 657         ADV
# 658        PART
# 659         DET
# 660        PRON
# 661        PART
# 662       PROPN
# 663        VERB
# 664       PROPN
# 665        NOUN
# 666        NOUN
# 667         AUX
# 668       SCONJ
# 669         ADJ
# 670         ADJ
# 671       PROPN
# 672       PROPN
# 673       PROPN
# 674        PART
# 675        NOUN
# 676         ADJ
# 677         ADV
# 678       SCONJ
# 679        NOUN
# 680        PART
# 681        NOUN
# 682        NOUN
# 683        VERB
# 684        NOUN
# 685         ADJ
# 686         ADJ
# 687        PRON
# 688        VERB
# 689        NOUN
# 690        PART
# 691       PROPN
# 692         ADJ
# 693         ADJ
# 694       PROPN
# 695       PROPN
# 696        NOUN
# 697         ADJ
# 698        NOUN
# 699        PRON
# 700         ADJ
# 701         ADJ
# 702         ADJ
# 703        NOUN
# 704        NOUN
# 705        PRON
# 706        NOUN
# 707        NOUN
# 708        NOUN
# 709         ADJ
# 710       PROPN
# 711        NOUN
# 712        PRON
# 713        PRON
# 714         ADJ
# 715        NOUN
# 716         ADJ
# 717         DET
# 718         ADJ
# 719        VERB
# 720        NOUN
# 721        VERB
# 722        NOUN
# 723        NOUN
# 724       PROPN
# 725        VERB
# 726           X
# 727       PROPN
# 728        NOUN
# 729         ADJ
# 730        VERB
# 731        PRON
# 732       PROPN
# 733        NOUN
# 734        PRON
# 735        VERB
# 736        NOUN
# 737         ADJ
# 738       PROPN
# 739         ADP
# 740        NOUN
# 741       PROPN
# 742        NOUN
# 743        NOUN
# 744        VERB
# 745        NOUN
# 746         DET
# 747         ADJ
# 748        NOUN
# 749        NOUN
# 750       CCONJ
# 751         ADJ
# 752        NOUN
# 753        NOUN
# 754         ADV
# 755       PROPN
# 756         ADJ
# 757         ADJ
# 758         AUX
# 759       PROPN
# 760       PROPN
# 761         ADJ
# 762        NOUN
# 763       PROPN
# 764         DET
# 765        NOUN
# 766        PART
# 767         ADJ
# 768       SCONJ
# 769        NOUN
# 770         ADJ
# 771       SCONJ
# 772        VERB
# 773       PROPN
# 774        VERB
# 775         ADJ
# 776        NOUN
# 777        NOUN
# 778        NOUN
# 779        NOUN
# 780        NOUN
# 781        NOUN
# 782        VERB
# 783        VERB
# 784         ADJ
# 785         ADJ
# 786        NOUN
# 787         ADJ
# 788       SCONJ
# 789        VERB
# 790        NOUN
# 791         ADJ
# 792         ADJ
# 793        VERB
# 794        VERB
# 795         ADJ
# 796        NOUN
# 797         ADJ
# 798         ADV
# 799         ADV
# 800         ADJ
# 801       SCONJ
# 802        NOUN
# 803        NOUN
# 804        NOUN
# 805       PROPN
# 806        PART
# 807       SCONJ
# 808        VERB
# 809        PRON
# 810           X
# 811        NOUN
# 812        NOUN
# 813         ADJ
# 814        NOUN
# 815       PROPN
# 816        PART
# 817        PART
# 818        VERB
# 819        NOUN
# 820         ADV
# 821       PROPN
# 822       CCONJ
# 823        NOUN
# 824        NOUN
# 825        NOUN
# 826        NOUN
# 827        NOUN
# 828        PRON
# 829        NOUN
# 830         ADJ
# 831        NOUN
# 832       PROPN
# 833        PRON
# 834        NOUN
# 835        VERB
# 836        VERB
# 837        VERB
# 838        VERB
# 839         DET
# 840        VERB
# 841        NOUN
# 842       PROPN
# 843         ADJ
# 844        NOUN
# 845         ADJ
# 846       PROPN
# 847       PROPN
# 848        NOUN
# 849        NOUN
# 850         ADJ
# 851       PROPN
# 852         ADJ
# 853         ADV
# 854         ADJ
# 855        VERB
# 856        NOUN
# 857        NOUN
# 858        NOUN
# 859        VERB
# 860         ADJ
# 861        NOUN
# 862         ADJ
# 863        PART
# 864        PART
# 865         ADJ
# 866           X
# 867        PRON
# 868       PROPN
# 869       PROPN
# 870        VERB
# 871       PROPN
# 872         AUX
# 873        NOUN
# 874         ADJ
# 875         ADJ
# 876       PROPN
# 877        PRON
# 878        VERB
# 879        NOUN
# 880         AUX
# 881        VERB
# 882         ADJ
# 883       PROPN
# 884        NOUN
# 885        NOUN
# 886         ADJ
# 887        NOUN
# 888        NOUN
# 889           X
# 890         ADJ
# 891        PART
# 892       PROPN
# 893         DET
# 894         ADJ
# 895       PROPN
# 896         NUM
# 897        VERB
# 898       PROPN
# 899        NOUN
# 900        NOUN
# 901        NOUN
# 902       SCONJ
# 903       PROPN
# 904       PROPN
# 905       PROPN
# 906        NOUN
# 907       PROPN
# 908        NOUN
# 909        NOUN
# 910           X
# 911        NOUN
# 912        VERB
# 913        PART
# 914        PART
# 915        PRON
# 916         ADJ
# 917         ADJ
# 918       PROPN
# 919         ADJ
# 920       PROPN
# 921       PROPN
# 922         ADJ
# 923        VERB
# 924         AUX
# 925        PRON
# 926         ADJ
# 927        NOUN
# 928       PROPN
# 929        VERB
# 930        NOUN
# 931         ADJ
# 932        VERB
# 933        VERB
# 934         ADJ
# 935         ADJ
# 936       PROPN
# 937        NOUN
# 938        NOUN
# 939        VERB
# 940       SCONJ
# 941        NOUN
# 942        NOUN
# 943        VERB
# 944        NOUN
# 945        NOUN
# 946         DET
# 947        PART
# 948        PRON
# 949         ADJ
# 950         ADJ
# 951        VERB
# 952        NOUN
# 953        PRON
# 954         ADV
# 955        PART
# 956        NOUN
# 957         ADJ
# 958         AUX
# 959         ADJ
# 960        NOUN
# 961       PROPN
# 962       SCONJ
# 963       PROPN
# 964         AUX
# 965           X
# 966        VERB
# 967        NOUN
# 968        PART
# 969         DET
# 970        PART
# 971       PROPN
# 972         ADJ
# 973        NOUN
# 974        PART
# 975        PART
# 976         ADJ
# 977        NOUN
# 978         ADJ
# 979        NOUN
# 980        NOUN
# 981         ADJ
# 982       PROPN
# 983       CCONJ
# 984        NOUN
# 985        NOUN
# 986         ADJ
# 987       PROPN
# 988        NOUN
# 989         ADJ
# 990        NOUN
# 991        NOUN
# 992        NOUN
# 993       PROPN
# 994       PROPN
# 995       PROPN
# 996         AUX
# 997       PROPN
# 998         AUX
# 999         AUX
# 1000        AUX
# 1001       VERB
# 1002       NOUN
# 1003      PROPN
# 1004        ADV
# 1005       NOUN
# 1006        ADV
# 1007      PROPN
# 1008       VERB

# %%
comparison_xpos
# Out:
#                 Token                             Context  \
# 0               Dziad                           Dziad mój
# 1                 mój                  Dziad mój Melchior
# 2            Melchior               mój Melchior urodzony
# 3            urodzony              Melchior urodzony roku
# 4          Godziszewo              wsi Godziszewo parafii
# 5             parafii           Godziszewo parafii Rypnin
# 6              Rypnin                  parafii Rypnin syn
# 7            starszym                 był starszym bratem
# 8              bratem                   starszym bratem ś
# 9                   ś                          bratem ś .
# 10                  p                               . p .
# 11              matki                         i matki Ewy
# 12         Pinińskich            z Pinińskich właścicieli
# 13               Dóbr           właścicieli Dóbr Strużewo
# 14           Strużewo                     Dóbr Strużewo z
# 15            Dąbrowy                    , Dąbrowy części
# 16                 śp                         że śp Dziad
# 17              Dziad                        śp Dziad mój
# 18                mój                       Dziad mój był
# 19                był                  mój był najmłodszy
# 20                  z                    piąty z pomiędzy
# 21       najstarszemu            część najstarszemu bratu
# 22              bratu          najstarszemu bratu swojemu
# 23                ośm                      za ośm tysięcy
# 24             tynfów                    tysięcy tynfów .
# 25            Stryjów                      . Stryjów miał
# 26               miał                     Stryjów miał śp
# 27                 śp                           miał śp .
# 28           Melchior                 . Melchior czterech
# 29           czterech                 Melchior czterech i
# 30         ożenionego              Wawrzyńca ożenionego z
# 31             trzech                   niej trzech synów
# 32              synów                 trzech synów Jakuba
# 33             Jakuba                      synów Jakuba ,
# 34            Łukasza                         , Łukasza i
# 35           Floyrana                        i Floyrana .
# 36               syna                  mieli syna Ludwika
# 37            Ludwika                      syna Ludwika –
# 38         wszystkich                  – wszystkich braci
# 39              braci       wszystkich braci stryjecznych
# 40       stryjecznych               braci stryjecznych śp
# 41                 17                           było 17 .
# 42           Antonich                     . Antonich było
# 43               brat                     dwóch brat Jana
# 44          Melchiora                    brat Melchiora .
# 45            Niewiem                         . Niewiem o
# 46              stryj                   a stryj Melchiora
# 47        zaopiekował           Melchiora zaopiekował się
# 48   młodzieniaszkiem              się młodzieniaszkiem i
# 49         wychowanie                    na wychowanie po
# 50              jakim               ale jakim niepamiętam
# 51          Potockich                   Domem Potockich ,
# 52     prawdopodobnie                  , prawdopodobnie ,
# 53            Brzeżan                Dziedziców Brzeżan i
# 54            Skolego                         i Skolego w
# 55               Pana             odwiedzał Pana Starostę
# 56           Starostę                     Pana Starostę ,
# 57         chłopczyna                 był chłopczyna więc
# 58                 co                       Potocki co to
# 59                 go                       chce go wziąć
# 60             rychło                  natury rychło ujął
# 61                tak                         i tak umiał
# 62           Brzeżany                   swoich Brzeżany i
# 63            Skolego                     i Skolego wziął
# 64                 go                      wziął go sobie
# 65            Skolego                do Skolego przekonał
# 66            intraty                    czynią intraty –
# 67               Myśl                          . Myśl się
# 68           podobała                   się podobała Panu
# 69         Szczęśliwa                   . Szczęśliwa była
# 70               jego                  przyszłości jego .
# 71             okazał                     jaki okazał mój
# 72                mój                    okazał mój Dziad
# 73              Dziad                      mój Dziad Panu
# 74                jak                          był jak na
# 75             piękny                      czasy piękny –
# 76              ujęty                        że ujęty tem
# 77                tem              ujęty tem zaproponował
# 78                 to                        mogło to być
# 79                jak                       – jak świętej
# 80           Czołhany                dzierżawę Czołhany w
# 81           Halickim                        w Halickim ,
# 82           Kobylską                    Panną Kobylską ,
# 83             trzech                    nią trzech synów
# 84           owdowiał                 niebawem owdowiał .
# 85             wołami                         za wołami .
# 86        Chyrowskiey      Posadzie Chyrowskiey zapędziły
# 87          zapędziły           Chyrowskiey zapędziły się
# 88               woły                          się woły w
# 89               parę                        i parę sztuk
# 90           Dzianott                 domu Dzianott wdowa
# 91              wdowa                   Dzianott wdowa po
# 92              dwóch                     po dwóch mężach
# 93             mężach                      dwóch mężach –
# 94                 by                   dworu by zapłacić
# 95      wynagrodzeniu                 o wynagrodzeniu nie
# 96             starym                      z starym winem
# 97              winem                      starym winem –
# 98               rada                         – rada była
# 99           gosposia              była gosposia gościowi
# 100          gościowi                 gosposia gościowi a
# 101               oko                             w oko –
# 102          Asińdźka                   wiesz Asińdźka co
# 103             wdowa                      Jesteś wdowa –
# 104           wdowiec                        ja wdowiec –
# 105                Ja                            „ Ja już
# 106                że                           ale że mi
# 107                mi                           że mi się
# 108          Waszmość                się Waszmość podobał
# 109           podobał                 Waszmość podobał eś
# 110                co                 wyobrazić co działo
# 111          ucałował                   , ucałował rączkę
# 112            drżącą                   rączkę drżącą Pan
# 113            Pannie                   wstąpi Pannie się
# 114       submittować                   się submittować .
# 115              1784                         W 1784 roku
# 116              dwie                     były dwie córki
# 117             córki                        dwie córki i
# 118            Starsi                     . Starsi bracia
# 119            mojego                  bracia mojego Ojca
# 120              Ojca            mojego Ojca pokończywszy
# 121             nauki          pokończywszy nauki osiedli
# 122           osiedli                    nauki osiedli na
# 123             córki                           a córki w
# 124              pono                        która pono w
# 125        Bolechowie                 w Bolechowie umarła
# 126            bawiły                        , bawiły pod
# 127      Czermińskiej          starościny Czermińskiej we
# 128               mąż                        za mąż jedna
# 129      szambelanica                    – szambelanica ,
# 130             druga                          , druga za
# 131     Świeżawskiego          za Świeżawskiego komornika
# 132         komornika  Świeżawskiego komornika ziemskiego
# 133        ziemskiego              komornika ziemskiego i
# 134        Maksymowic            właściciela Maksymowic w
# 135               był             Tretera był szambelanem
# 136       szambelanem                  był szambelanem za
# 137    Poniatowskiego                  . Poniatowskiego –
# 138            wielki                    – wielki literat
# 139           literat                    wielki literat .
# 140               jak                     go jak mieszkał
# 141               dwa                 oficynie dwa pokoje
# 142            pokoje                        dwa pokoje –
# 143             oddał                 swój oddał akademii
# 144          akademii                   oddał akademii we
# 145            oddany                    gabinet oddany z
# 146             Abbum          drzwiami Abbum Treterianum
# 147       Treterianum                 Abbum Treterianum .
# 148             Lwowa            bombardowaniu Lwowa roku
# 149          obrucona                  perzynę obrucona –
# 150              więc                            – więc i
# 151            zbiory                         i zbiory te
# 152                te                zbiory te zniszczały
# 153        zniszczały                     te zniszczały .
# 154               Syn                          . Syn jego
# 155               mój                           a mój wuj
# 156               wuj                         mój wuj był
# 157               był                          wuj był to
# 158          fantasta                       to fantasta –
# 159          oryginał                   – oryginał jakich
# 160            jakich                oryginał jakich dziś
# 161                 i                             bo i po
# 162            100000                     wziął 100000 zł
# 163          polskich                        . polskich w
# 164              jako          zarządzał jako plenipotent
# 165          wielkimi        plenipotent wielkimi dobrami
# 166           dobrami                  wielkimi dobrami ,
# 167        dzierżawił                     to dzierżawił –
# 168         znajomych                      po znajomych i
# 169             różne              wyśpiewywał różne arye
# 170              arye               różne arye krakowiaki
# 171        krakowiaki                   arye krakowiaki i
# 172         kołomyjki                       i kołomyjki .
# 173                na                    jeździł na koniu
# 174                po                  koniu po znajomych
# 175         znajomych                      po znajomych a
# 176           śpiewem                       ze śpiewem na
# 177            mojego                    domu mojego Oyca
# 178              Oyca                       mojego Oyca –
# 179              dużo                niej dużo szczegółów
# 180              Oyca                    familii Oyca się
# 181        Opowiadano                     . Opowiadano mi
# 182                mi                   Opowiadano mi też
# 183           pożycia                     z pożycia moich
# 184             moich              pożycia moich wujostwa
# 185         oświecony                katafalk oświecony a
# 186             Zaraz                          . Zaraz na
# 187           czeladź                       jej czeladź ,
# 188               jak                   wiedzieć jak Pani
# 189      nieboszczyka               żałuje nieboszczyka -
# 190      nieboszczyka           do nieboszczyka przemawia
# 191              Tobą                       z Tobą Stasiu
# 192            Stasiu                    Tobą Stasiu tyle
# 193              tyle                       Stasiu tyle a
# 194              tyle                          a tyle lat
# 195        Zostawiasz                    ! Zostawiasz mię
# 196               mię                    Zostawiasz mię z
# 197              kęsa                     ani kęsa chleba
# 198              zato                            – zato ,
# 199                Ci                        ażeby Ci Bóg
# 200      nieboszczyka              okładać nieboszczyka –
# 201               ich                obracają ich rodziny
# 202           rodziny                       ich rodziny .
# 203             Drugi                         . Drugi mój
# 204               mój                       Drugi mój wuj
# 205               wuj                 mój wuj Świerzawski
# 206       Świerzawski               wuj Świerzawski kuzyn
# 207             kuzyn      Świerzawski kuzyn Polanowskich
# 208      Polanowskich                kuzyn Polanowskich z
# 209         Bełzkiego                  z Bełzkiego często
# 210         Moszkowie                       w Moszkowie z
# 211               Pań                     od Pań oblegany
# 212          oblegany                      Pań oblegany –
# 213         strojeniu                    na strojeniu się
# 214         trefieniu                       i trefieniu a
# 215           służąca                musiała służąca całą
# 216         stopniach                 na stopniach powozu
# 217      Komornikowej        Pani Komornikowej niepomięła
# 218             dwóch                    było dwóch synów
# 219             nauki                pokończyli nauki ale
# 220           Niewiem                     . Niewiem jakim
# 221         zniszczał                 majątek zniszczał –
# 222        Treterówną                siostrą Treterówną -
# 223          nierobił                   wstydu nierobił .
# 224        Treterówną                siostrą Treterówną –
# 225               nim                         się nim Pan
# 226          nierobił                   wstydu nierobił .
# 227               móy                  Ojciec móy sierota
# 228           sierota                  móy sierota oddany
# 229            oddany                   sierota oddany do
# 230            niżeli                    , niżeli książki
# 231                to                        Mogło to być
# 232             około                      być około 1801
# 233        podpodczas                  – podpodczas wojen
# 234           Sachsen                   do Sachsen Cobary
# 235            Cobary               Sachsen Cobary Ułanów
# 236                14                            lat 14 .
# 237          kadectwo                   Ojciec kadectwo ,
# 238                 ś                              mi ś .
# 239                 p                               . p .
# 240             Oycem                          z Oycem na
# 241  Młodzieniaszkiem           . Młodzieniaszkiem oddany
# 242            oddany          Młodzieniaszkiem oddany do
# 243                 w                spacery w sąsiedztwa
# 244        sąsiedztwa                      w sąsiedztwa ,
# 245         najwięcej                   a najwięcej czasu
# 246           podróże                     czasu podróże i
# 247         Zarszynie                       w Zarszynie i
# 248            zajęty         ciągle zajęty gospodarstwem
# 249         zakończył               wojskową zakończył śp
# 250              1808                        około 1808 –
# 251              1809                         albo 1809 –
# 252             kończ                      do kończ życia
# 253             życia                       kończ życia .
# 254             wielu                    we wielu bitwach
# 255           bitwach                     wielu bitwach –
# 256             Iglan                       pod Iglan był
# 257               pod                        a pod Wagram
# 258            Wagram                   pod Wagram stojąc
# 259             armat           assekuracyi armat utracił
# 260      kontuzjowany              sam kontuzjowany leżał
# 261               jak             pobojowisku jak nieżywy
# 262           nieżywy                       jak nieżywy –
# 263              cały                         – cały pułk
# 264              pułk                    cały pułk pieszy
# 265            pieszy               pułk pieszy Francuzów
# 266         Francuzów     pieszy Francuzów przemaszerował
# 267    przemaszerował         Francuzów przemaszerował po
# 268               nim                            po nim ,
# 269          zwinięty          płaszcz zwinięty obwiązany
# 270         obwiązany            zwinięty obwiązany przez
# 271             plecy                           i plecy ,
# 272              małe                  tylko małe ukłucia
# 273           ukłucia              małe ukłucia dostawały
# 274         dostawały               ukłucia dostawały się
# 275         skrzętnem     fortuny skrzętnem gospodarstwem
# 276              wieś            własność wieś Siemiginów
# 277        Siemiginów                   wieś Siemiginów w
# 278               tem                          po tem jak
# 279               jak                   tem jak powiadano
# 280         powiadano                    jak powiadano za
# 281            indyki                   za indyki których
# 282           których                   indyki których po
# 283             Lwowa                          do Lwowa w
# 284          Bludniki                   kupił Bludniki za
# 285             które                   za które wyliczył
# 286              Pani         wyliczył Pani Rozwadowskiej
# 287     Rozwadowskiej            Pani Rozwadowskiej 10000
# 288             10000         Rozwadowskiej 10000 dukatów
# 289           dukatów                     10000 dukatów .
# 290              2000              brakowało 2000 dukatów
# 291           dukatów          2000 dukatów pełnłnomocnik
# 292     Rozwadowskiej              Pani Rozwadowskiej nie
# 293          zmieniał               właściciel zmieniał –
# 294            wójtem                         z wójtem na
# 295                 w                   sposób w fizyczne
# 296                we              fizyczne we posiadanie
# 297        posiadanie               we posiadanie majątku
# 298           osypami   pańszczyźnianymi osypami daninami
# 299          daninami                 osypami daninami od
# 300           któremi               nad któremi obeymował
# 301         obeymował       któremi obeymował Dziedzictwo
# 302       juryzdyksye           prawną juryzdyksye sądową
# 303         pierwszey     policyjną pierwszey instantacyi
# 304               Zaś                        . Zaś daniny
# 305            daniny                        Zaś daniny w
# 306           robocie                  w robocie odbywali
# 307       posiadanych           ilości posiadanych morgów
# 308            bydłem                       dni bydłem co
# 309                co                  bydłem co tygodnia
# 310              tego                       Oprócz tego z
# 311              owsa                        ilość owsa –
# 312               dwa                      albo dwa korce
# 313                ci                           tego ci i
# 314             zwane                    tak zwane spaśne
# 315            spaśne                      zwane spaśne -
# 316              kury                      - kury kapłony
# 317           kapłony                 kury kapłony kaczki
# 318            kaczki                    kapłony kaczki i
# 319              gęsi                            i gęsi ,
# 320              jaja                            , jaja –
# 321         pastwiska                   oni pastwiska dla
# 322         pastwisko                 - pastwisko ratował
# 323           biedzie                    w biedzie zbożem
# 324            zbożem                    biedzie zbożem a
# 325       inwentarzem                 nawet inwentarzem .
# 326            Wieleż                         . Wieleż to
# 327                to                      Wieleż to razy
# 328              razy                     to razy słyszał
# 329           Dziadka             . Dziadka Ostaszewskigo
# 330     Ostaszewskigo           Dziadka Ostaszewskigo jak
# 331               jak               Ostaszewskigo jak się
# 332           kmiecie                     jego kmiecie na
# 333             bydle                 padło bydle robocze
# 334           robocze                     bydle robocze –
# 335            żalili                 Dłużanie żalili się
# 336              koni                          dla koni –
# 337          Oddzieli                       – Oddzieli śp
# 338            suchey                  morgów suchey łąki
# 339        podedworem                   łąki podedworem a
# 340      nayskładniey             a nayskładniey położone
# 341          położone           nayskładniey położone dla
# 342            kmieci                        dla kmieci ,
# 343            Niebył                         . Niebył to
# 344                to                 Niebył to obowiązek
# 345         obowiązek              to obowiązek spełniony
# 346         spełniony             obowiązek spełniony ale
# 347        Oycowskiey                      . Oycowskiey .
# 348             napar                wyszynku napar prawo
# 349             prawo                napar prawo warżenia
# 350             prawo               wódki prawo stawiania
# 351         polowania                      i polowania na
# 352          dworskim                    tak dworskim jak
# 353        gromadzkim                      i gromadzkim .
# 354             leśni                        byli leśni -
# 355           poddani                 - poddani uwolnieni
# 356         suszonych            wianki suszonych grzybów
# 357           miarkmi                    – miarkmi wianki
# 358            wianki              miarkmi wianki powinny
# 359           powinny                 wianki powinny były
# 360              były                powinny były mierzyć
# 361         dziesiąty                jest dziesiąty pniak
# 362             pniak                  dziesiąty pniak do
# 363            takiem              przy takiem obciążeniu
# 364             chłop                         – chłop był
# 365               był                    chłop był biedny
# 366            biedny                        był biedny -
# 367               tak                    jednakże tak nie
# 368           majątki                      – majątki były
# 369              były              majątki były wyłącznie
# 370         wyłącznie                    były wyłącznie w
# 371               był                jurysdykcyi był Herb
# 372              Herb                  był Herb Dziedzica
# 373         Dziedzica                    Herb Dziedzica –
# 374          Dominium             napis Dominium Bludniki
# 375          Bludniki                 Dominium Bludniki –
# 376           Zarszyn                         – Zarszyn –
# 377            swojem                   na swojem mieycus
# 378           mieycus        swojem mieycus Mandatariusza
# 379     Mandatariusza             mieycus Mandatariusza -
# 380           rekruta                  wybierał rekruta i
# 381         urzędował                       , urzędował –
# 382         egzekował                       – egzekował –
# 383          niemogło                      – niemogło się
# 384           dopokąd                         – dopokąd z
# 385      nieprzyniósł         Dominii nieprzyniósł kartki
# 386            kartki      nieprzyniósł kartki pozwolenia
# 387                 A                         . A chociaż
# 388             mogły                        tu mogły się
# 389         nadużycia                   dziać nadużycia –
# 390             mogły                         – mogły one
# 391               one                       mogły one być
# 392         wyjątkowe                     być wyjątkowe ,
# 393             ktoby                         a ktoby był
# 394               był          ktoby był niesprawiedliwym
# 395  niesprawiedliwym            był niesprawiedliwym dla
# 396            stawał                poddanych stawał pod
# 397             dbano                        czas dbano o
# 398         szlachcic                  Podola szlachcic w
# 399                 w                szlachcic w Sanockie
# 400          Sanockie                        w Sanockie –
# 401         poddanych              zdzierstwa poddanych –
# 402                 P                            domu P .
# 403              tego                       Pana tego nie
# 404         obsadzane               części obsadzane były
# 405              były             obsadzane były szlachtą
# 406         cząstkową                       – cząstkową –
# 407         czynszową                       – czynszową –
# 408          ludowemi               dziś ludowemi zwanych
# 409             lizną                 czasem lizną trochę
# 410            trochę                 lizną trochę łaciny
# 411            łaciny                     trochę łaciny w
# 412         gymnazyum                       w gymnazyum –
# 413             prawa                      trochę prawa –
# 414       manipulacyi             – manipulacyi urzędowey
# 415         urzędowey             manipulacyi urzędowey –
# 416           Cyrkule                         w Cyrkule i
# 417      Mandatyrusza           . Mandatyrusza przyjmował
# 418        przyjmował    Mandatyrusza przyjmował Dziedzic
# 419          Dziedzic              przyjmował Dziedzic na
# 420          depozyta            i depozyta starościńskie
# 421     starościńskie            depozyta starościńskie .
# 422         Dziedzica                 od Dziedzica pensyę
# 423               120                           od 120 do
# 424               200                            do 200 –
# 425               300                            – 300 fl
# 426                20                            fl 20 do
# 427                50                         do 50 korcy
# 428         ordynaryi                   korcy ordynaryi –
# 429      pomieszkanie                 , pomieszkanie opał
# 430              opał                 pomieszkanie opał –
# 431         pastwisko                       – pastwisko –
# 432        zastępował          jakim zastępował Dziedzica
# 433         Dziedzica              zastępował Dziedzica .
# 434         szczupłey               tak szczupłey dotacyi
# 435           dotacyi     szczupłey dotacyi uwzględniając
# 436                 w                         życia w one
# 437               one                         w one czasy
# 438         kosztował        mięsa kosztował dzisiejszych
# 439      dzisiejszych            kosztował dzisiejszych 4
# 440                 4                   dzisiejszych 4 do
# 441                 5                         do 5 centów
# 442            centów                          5 centów –
# 443            korzec                       – korzec owsa
# 444              owsa              korzec owsa cwansigera
# 445        cwansigera                   owsa cwansigera –
# 446                33                      czyli 33 centy
# 447             centy                          33 centy –
# 448              żyta            korzec żyta dzisiejszych
# 449      dzisiejszych                 żyta dzisiejszych 1
# 450                 1                   dzisiejszych 1 fl
# 451                fl                              1 fl –
# 452                10                        korzec 10 do
# 453                14                        do 14 centów
# 454            centów                         14 centów –
# 455           przytem                 mając przytem jakiś
# 456           Panowie                  obrywki Panowie ci
# 457                ci                    Panowie ci mieli
# 458            lepiey                   nieraz lepiey jak
# 459        dzisiejszy             jak dzisiejszy komisarz
# 460          komisarz      dzisiejszy komisarz cyrkularny
# 461        cyrkularny               komisarz cyrkularny .
# 462       Cyrkularnym            Urzędnikom Cyrkularnym –
# 463             ładąn                        – ładąn parą
# 464          siwoszów                     parą siwoszów ,
# 465            ubrany                  elegancko ubrany –
# 466            pensyi                     brał pensyi 600
# 467               600                       pensyi 600 fl
# 468                fl                            600 fl .
# 469               móy                       gdy móy Dziad
# 470             Dziad               móy Dziad podbierając
# 471         Pokasowce                należały Pokasowce i
# 472         Siedliska                       i Siedliska –
# 473      zakłopotania           wobec zakłopotania nowego
# 474        najbliższy           gromady najbliższy sąsiad
# 475            Notiak                        się Notiak –
# 476              jego                 doskonale jego Syna
# 477                to                        może to jego
# 478              jego                      to jego samego
# 479            samego                      jego samego bo
# 480            dokoła                obszerna dokoła ławy
# 481              ławy                       dokoła ławy i
# 482              stół                      i stół nakryty
# 483           nakryty                 stół nakryty długim
# 484           bielone              szerokie bielone grube
# 485             grube                    bielone grube po
# 486         zkończone                   białą zkończone )
# 487          bochenek                 nim bochenek chleba
# 488               sól                             i sól –
# 489             dzban                           i dzban –
# 490           niewiem                       – niewiem czy
# 491               czy                       niewiem czy z
# 492            gotowe                     – gotowe każdej
# 493                Ty                    mu Ty człowiecze
# 494        człowiecze                    Ty człowiecze na
# 495      nieporadzisz                   mi nieporadzisz –
# 496         chłopisko                gdy chłopisko zaczął
# 497              2000             potrzebuję 2000 Dukatów
# 498           Dukatów                      2000 Dukatów –
# 499         poradzisz                      to poradzisz ?
# 500                 A                         ? A wówczas
# 501         przyniósł              poczekaniu przyniósł i
# 502              2000                 wyliczył 2000 sztuk
# 503             mojey                    za mojey pamięci
# 504           liczono             pamięci liczono sześciu
# 505           sześciu                   liczono sześciu w
# 506    Mandatariuszem                  . Mandatariuszem w
# 507           jaszcze                     był jaszcze tam
# 508               tam                      jaszcze tam za
# 509         księżunio                      , księżunio od
# 510               był                     człowiek był to
# 511            oyciec                     to oyciec owego
# 512             owego            oyciec owego Głoweckiego
# 513       Głoweckiego                 owego Głoweckiego –
# 514             który                   – który przeszedł
# 515         przeszedł                   który przeszedł w
# 516                 w               przeszedł w Lubelskie
# 517         Lubelskie                    w Lubelskie jako
# 518              jako                  Lubelskie jako pop
# 519               pop                jako pop szyzmatycki
# 520       szyzmatycki                pop szyzmatycki jako
# 521              jako            szyzmatycki jako renegat
# 522           renegat                    jako renegat tam
# 523                 I                             . I tak
# 524            późney                  tak późney dokupił
# 525             Dziad                   dokupił Dziad móy
# 526               móy                   Dziad móy Dorchów
# 527           Dorchów                       móy Dorchów i
# 528           Kurypów                         i Kurypów –
# 529     nayjstarszego          osadził nayjstarszego syna
# 530              Toje                         – Toje diło
# 531              diło                    Toje diło daruju
# 532            daruju              diło daruju ukochanomu
# 533        ukochanomu              daruju ukochanomu Synu
# 534              Synu              ukochanomu Synu mojomu
# 535            mojomu              Synu mojomu Mychayłowu
# 536        Mychayłowu                 mojomu Mychayłowu .
# 537          Bludniki                    . Bludniki oddał
# 538             iOycu               Józefowi iOycu mojemu
# 539            mojemu                      iOycu mojemu .
# 540               tak                           to tak aż
# 541            mojego                     się mojego Oyca
# 542              Oyca                    mojego Oyca pono
# 543              pono                      Oyca pono 1813
# 544              1813                      pono 1813 albo
# 545              1814                         albo 1814 –
# 546              Pana                       – Pana Józefa
# 547            Józefa                   Pana Józefa wziął
# 548               móy                      Dziadek móy do
# 549            Siebie                        do Siebie do
# 550         dośmierci                   aż dośmierci Oyca
# 551              Oyca                 dośmierci Oyca przy
# 552               Nim                   przy Nim zostawał
# 553         ociemniał                   życia ociemniał .
# 554         Zdejmował                      . Zdejmował Mu
# 555                Mu              Zdejmował Mu kataraktę
# 556               ile                         i ile sobie
# 557             około              przypominam około 1826
# 558              1826                        około 1826 .
# 559         Semiginów                własność Semiginów .
# 560            Oyciec             wydzielił Oyciec schedę
# 561              pono                        końcu pono w
# 562                to                       która to Lipa
# 563          niewinem                     Lipa niewinem .
# 564        Bludnikami                      z Bludnikami o
# 565        Temerowiec                      z Temerowiec ,
# 566        Zabilskich             Stanisława Zabilskich –
# 567          jedynaka                Syna jedynaka Sabina
# 568            Sabina                   jedynaka Sabina .
# 569                za                    poszedł za Oycem
# 570        doszedłszy                Oycem doszedłszy lat
# 571             około                        lat około 24
# 572                24                         około 24 na
# 573         przeszedł              sukcessyi przeszedł po
# 574             synie                         po synie na
# 575           Dorchów              zapisała Dorchów bratu
# 576             bratu               Dorchów bratu swojemu
# 577              temu                      żona temu pono
# 578              pono                         temu pono z
# 579               ten                      , ten zostawił
# 580          zostawił                ten zostawił Dorchów
# 581           Dorchów            zostawił Dorchów swojemu
# 582            niebył                – niebył gospodarzem
# 583            więcey         gospodarzem więcey fantasta
# 584             wgłos                    czytywał wgłos „
# 585              Pana                     „ Pana Tadeusza
# 586          Tadeusza                     Pana Tadeusza ”
# 587            masami            skupował masami poziomki
# 588          poziomki                   masami poziomki i
# 589         częstował                    i częstował cały
# 590         Zapraszał                      – Zapraszał do
# 591               tey                     do tey praktyki
# 592                ci                     ale ci niemogli
# 593          niemogli                   ci niemogli długo
# 594          uciekali                        i uciekali .
# 595         przyszedł                Gdy przyszedł wielki
# 596            wielki             przyszedł wielki piątek
# 597            piątek                     wielki piątek –
# 598          nietylko                  – nietylko czeladź
# 599           czeladź                nietylko czeladź ale
# 600            suszyć                 musiało suszyć więc
# 601             sądny                       więc sądny to
# 602          niemożna              obeyściu niemożna było
# 603             prawa               ukończył prawa bardzo
# 604               był                 bardzo był oczytany
# 605          oczytany                      był oczytany –
# 606          poczciwy                        – poczciwy –
# 607             zacny                       – zacny tylko
# 608             tylko                  zacny tylko raptus
# 609                go                      Zastała go raz
# 610         klęczącym                 służba klęczącym ze
# 611         złożonymi                 ze złożonymi rękoma
# 612            rękoma           złożonymi rękoma nieżywym
# 613          nieżywym                   rękoma nieżywym .
# 614                po                     Sukcesya po mim
# 615               mim                            po mim ,
# 616             część                      której część i
# 617          Siostrom                   On Siostrom swoim
# 618             swoim             Siostrom swoim rodzonym
# 619          rodzonym           swoim rodzonym Treterowej
# 620        Treterowej               rodzonym Treterowej i
# 621       Swieżaskiey                     i Swieżaskiey .
# 622              Oyca                      śmierci Oyca z
# 623             Panną                       z Panną Julią
# 624        Świeżyńską           Julią Świeżyńską urodzoną
# 625          urodzoną              Świeżyńską urodzoną ze
# 626                ze              urodzoną ze Zawadzkich
# 627        Zawadzkich                     ze Zawadzkich –
# 628          Łukowiec                      wsi Łukowiec w
# 629               czy              górach czy Kruszelnicę
# 630             kilka               razem kilka generacyi
# 631            jednem                  na jednem obeyściu
# 632          obeyściu                jednem obeyściu było
# 633               dwa                      było dwa dwory
# 634             dwory                         dwa dwory -
# 635                 2                           - 2 Panny
# 636             Panny                    2 Panny niemając
# 637              obie               ( obie nauczycielkami
# 638             jakby                      – jakby jakieś
# 639             Panna                   fatum Panna Julia
# 640             Julia                 Panna Julia dostała
# 641           Bludnik               sąsiedztwo Bludnik do
# 642         Martynowa                     do Martynowa do
# 643          Rudzkich              Państwa Rudzkich gdzie
# 644              były                     gdzie były dwie
# 645              dwie                  były dwie panienki
# 646          panienki                     dwie panienki –
# 647               tąd                        z tąd bywała
# 648             Jakby               . Jakby instynktownie
# 649               jey                     moja jey znieść
# 650          niemogła                   znieść niemogła .
# 651           osiadły                    Józef osiadły na
# 652           talarki           zbijał talarki oszczędzał
# 653            krewni                     to krewni Panny
# 654             niema                że niema sukcessorów
# 655       sukcessorów                 niema sukcessorów ,
# 656         odmłodził              swoją odmłodził piękną
# 657        niechciało          Józefowi niechciało ruszać
# 658              Ojcu              po Ojcu oddziedziczone
# 659    oddziedziczone         Ojcu oddziedziczone znaczne
# 660              sady                  pielęgnował sady i
# 661             kilka                         o kilka mil
# 662          odległey                     mil odległey od
# 663        Siemignowa                     od Siemignowa –
# 664              hoża                        się hoża jak
# 665               jak                      hoża jak łania
# 666             łania                     jak łania Panna
# 667             Panna                   łania Panna Julia
# 668             Julia                       Panna Julia i
# 669         Jegomości             wyswatano Jegomości już
# 670                to                       Było to około
# 671             około                       to około 1829
# 672              tego                małżeństwa tego była
# 673       sukcessorka      jedyna sukcessorka Siemiginowa
# 674       Siemiginowa           sukcessorka Siemiginowa –
# 675       miejscowość        Józef miejscowość Leśniowice
# 676        Leśniowice            miejscowość Leśniowice z
# 677             życie                 tam życie zakończył
# 678         zakończył                życie zakończył roku
# 679           ciepłey                   ale ciepłey wdowy
# 680             wdowy                     ciepłey wdowy .
# 681        Bałamuciła            . Bałamuciła przebierała
# 682              pana           wybrała pana Szołayskiego
# 683                24                        około 24 lat
# 684         liczącego                     lat liczącego –
# 685          sybarytę                – sybarytę próżniaka
# 686         próżniaka            sybarytę próżniaka toteż
# 687         dwuletnim                      po dwuletnim z
# 688           pożyciu                       nim pożyciu –
# 689           secundo                  Julia secundo voto
# 690              voto              secundo voto Szołayska
# 691           procesa                    lubiła procesa –
# 692               ich                       miała ich też
# 693         przyległe           Lesniowic przyległe Mosty
# 694             Mosty                   przyległe Mosty .
#
#                         Gold Standard                        Prediction
# 0                     subst:sg:nom:m1                   subst:sg:nom:m3
# 1                   adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 2                     subst:sg:nom:m1                   subst:sg:nom:m3
# 3                   adj:sg:nom:m1:pos           ppas:sg:nom:m3:perf:aff
# 4                 subst:sg:nom:n:ncol               subst:sg:acc:n:ncol
# 5                      subst:sg:loc:f                    subst:sg:gen:f
# 6                     subst:sg:nom:m3                   subst:sg:nom:m1
# 7                  adj:sg:inst:m1:com                adj:sg:inst:m3:pos
# 8                    subst:sg:inst:m1                  subst:sg:inst:m3
# 9                            brev:pun           aglt:sg:sec:imperf:nwok
# 10                          brev:npun                          brev:pun
# 11                     subst:sg:gen:f                    subst:pl:nom:f
# 12                    subst:pl:gen:m1                 adj:pl:gen:m1:pos
# 13                  subst:pl:gen:n:pt                   subst:sg:nom:m1
# 14                subst:sg:nom:n:ncol                   subst:sg:nom:m1
# 15                     subst:sg:gen:f                 adj:sg:nom:m3:pos
# 16                          brev:npun                   subst:sg:nom:m3
# 17                    subst:sg:nom:m1                   subst:sg:nom:m3
# 18                  adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 19                 praet:sg:m1:imperf                praet:sg:m3:imperf
# 20                     prep:inst:nwok                     prep:gen:nwok
# 21                  adj:sg:dat:m1:sup                 adj:pl:gen:m3:sup
# 22                    subst:sg:dat:m1                   subst:sg:gen:m3
# 23             num:pl:acc:m3:rec:ncol                 num:pl:acc:m3:rec
# 24                    subst:pl:gen:m2                   subst:pl:gen:m3
# 25                    subst:pl:acc:m1                   subst:sg:nom:m3
# 26                 praet:sg:m1:imperf                praet:sg:m3:imperf
# 27                           brev:pun                   subst:sg:nom:m3
# 28                    subst:sg:nom:m1                   subst:sg:nom:m3
# 29           num:pl:acc:m1:congr:ncol               num:pl:gen:m1:congr
# 30            ppas:sg:acc:m1:perf:aff           ppas:sg:gen:m3:perf:aff
# 31           num:pl:acc:m3:congr:ncol                 num:pl:nom:m1:rec
# 32                    subst:pl:acc:m1                   subst:pl:gen:m1
# 33                    subst:sg:acc:m1                   subst:sg:gen:m1
# 34                    subst:sg:acc:m1                   subst:sg:gen:m1
# 35                    subst:sg:acc:m1                   subst:sg:gen:m1
# 36                    subst:sg:acc:m1                   subst:sg:gen:m1
# 37                    subst:sg:acc:m1                   subst:sg:gen:m1
# 38                  adj:pl:acc:m1:pos                  adj:pl:gen:f:pos
# 39                    subst:pl:acc:m1                    subst:pl:gen:f
# 40                  adj:pl:acc:m1:pos                  adj:pl:gen:f:pos
# 41                  num:pl:nom:m1:rec                  adj:sg:nom:f:pos
# 42                    subst:pl:gen:m1                   subst:sg:nom:m1
# 43                    subst:sg:nom:m1                   subst:pl:gen:m1
# 44                    subst:sg:gen:m1                   subst:sg:nom:m1
# 45                  fin:sg:pri:imperf                              part
# 46                    subst:sg:nom:m1                   subst:sg:nom:m3
# 47                   praet:sg:m1:perf                  praet:sg:m3:perf
# 48                   subst:sg:inst:m1                  subst:sg:inst:m3
# 49                subst:sg:acc:n:ncol             ger:sg:acc:n:perf:aff
# 50                 adj:sg:inst:m1:pos                 adj:sg:inst:n:pos
# 51                    subst:pl:gen:m1                  adj:pl:gen:f:pos
# 52                               part                           adv:pos
# 53                  subst:pl:gen:n:pt               subst:sg:gen:n:ncol
# 54                subst:sg:gen:n:ncol                   subst:sg:gen:m1
# 55                    subst:sg:acc:m1                   subst:sg:gen:m1
# 56                    subst:sg:acc:m1                    subst:sg:acc:f
# 57                    subst:sg:nom:m1                  adj:sg:nom:f:pos
# 58                subst:sg:nom:n:ncol               subst:sg:acc:n:ncol
# 59   ppron3:sg:acc:m1:ter:nakc:npraep  ppron3:sg:acc:m3:ter:nakc:npraep
# 60                            adv:pos               subst:sg:acc:n:ncol
# 61                            adv:pos                              part
# 62                  subst:pl:nom:n:pt                   subst:sg:gen:m1
# 63                subst:sg:gen:n:ncol                   subst:sg:gen:m1
# 64   ppron3:sg:acc:m1:ter:nakc:npraep  ppron3:sg:acc:m3:ter:nakc:npraep
# 65                subst:sg:gen:n:ncol                   subst:sg:gen:m1
# 66                     subst:sg:gen:f                    subst:pl:nom:f
# 67                     subst:sg:nom:f                  impt:sg:sec:perf
# 68                  praet:sg:f:imperf                   praet:sg:f:perf
# 69                   adj:sg:nom:f:pos                    subst:sg:nom:f
# 70    ppron3:sg:loc:m1:ter:akc:npraep   ppron3:sg:gen:m1:ter:akc:npraep
# 71                   praet:sg:m1:perf                  praet:sg:m3:perf
# 72                  adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# ...
# 479                 adj:sg:acc:m1:pos                 adj:sg:gen:m1:pos
# 480                          prep:gen                               adv
# 481                    subst:sg:nom:f                    subst:pl:acc:f
# 482                   subst:sg:nom:m3                   subst:sg:acc:m3
# 483           ppas:sg:nom:m3:perf:aff           ppas:sg:acc:m3:perf:aff
# 484          ppas:sg:nom:n:imperf:aff                  adj:sg:nom:n:pos
# 485                  adj:sg:nom:n:pos                  adj:pl:acc:f:pos
# 486                 adj:sg:inst:f:pos            ppas:pl:nom:f:perf:aff
# 487                   subst:sg:nom:m3                   subst:sg:acc:m3
# 488                    subst:sg:nom:f                   subst:sg:nom:m3
# 489                   subst:sg:nom:m3               subst:sg:nom:n:ncol
# 490                 fin:sg:pri:imperf              subst:sg:inst:n:ncol
# 491                              part                              conj
# 492               subst:sg:nom:n:ncol                  adj:pl:nom:f:pos
# 493             ppron12:sg:voc:m1:sec             ppron12:sg:nom:m1:sec
# 494                   subst:sg:voc:m1                 fin:sg:ter:imperf
# 495                   fin:sg:sec:perf                 fin:sg:sec:imperf
# 496                   subst:sg:nom:m1               subst:sg:acc:n:ncol
# 497                 num:pl:acc:m2:rec                  num:pl:acc:f:rec
# 498                   subst:pl:gen:m2                   subst:pl:gen:m1
# 499                   fin:sg:sec:perf                 fin:sg:sec:imperf
# 500                              conj                              part
# 501             praet:sg:m1:perf:nagl             praet:sg:m3:perf:nagl
# 502                 num:pl:acc:m2:rec                  num:pl:acc:f:rec
# 503                  adj:sg:gen:f:pos                   subst:pl:acc:m3
# 504                       imps:imperf                         imps:perf
# 505            num:pl:nom:m1:rec:ncol                 num:pl:nom:m1:rec
# 506                  subst:sg:inst:m1                  subst:sg:inst:m3
# 507                              part                  adj:pl:nom:f:pos
# 508                              part                               adv
# 509                   subst:sg:nom:m1                              conj
# 510                praet:sg:m1:imperf                praet:sg:m3:imperf
# 511                   subst:sg:nom:m1                   subst:sg:nom:m3
# 512                 adj:sg:gen:m1:pos                 adj:sg:gen:m3:pos
# 513                   subst:sg:gen:m1                   subst:sg:gen:m3
# 514                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 515                  praet:sg:m1:perf                  praet:sg:m3:perf
# 516                     prep:acc:nwok                     prep:loc:nwok
# 517               subst:sg:acc:n:ncol                   subst:sg:loc:m3
# 518                              conj                              comp
# 519                   subst:sg:nom:m1                   subst:sg:nom:m3
# 520                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 521                              conj                              comp
# 522                   subst:sg:nom:m1                   subst:sg:nom:m3
# 523                              conj                              part
# 524                           adv:com                              comp
# 525                   subst:sg:nom:m1                   subst:sg:acc:m3
# 526                 adj:sg:nom:m1:pos                 adj:sg:acc:m3:pos
# 527                   subst:sg:acc:m3                   subst:pl:gen:m1
# 528                   subst:sg:acc:m3                   subst:pl:gen:m1
# 529                 adj:sg:acc:m1:sup                 adj:sg:acc:m1:pos
# 530                               ign               subst:sg:nom:n:ncol
# 531                               ign                   praet:sg:n:perf
# 532                               ign                   subst:sg:gen:m3
# 533                               ign                   subst:sg:gen:m3
# 534                               ign                   subst:sg:gen:m3
# 535                               ign                   subst:sg:gen:m3
# 536                               ign                   subst:sg:gen:m3
# 537                 subst:pl:nom:n:pt                   subst:sg:nom:m1
# 538                   subst:sg:dat:m1                   subst:sg:gen:m3
# 539                 adj:sg:dat:m1:pos                 adj:sg:gen:m3:pos
# 540                              part                           adv:pos
# 541                 adj:sg:gen:m1:pos                 adj:sg:acc:m1:pos
# 542                   subst:sg:gen:m1                   subst:sg:acc:m1
# 543                              part                         imps:perf
# 544                 adj:sg:gen:m3:pos                               dig
# 545                 adj:sg:gen:m3:pos                               dig
# 546                   subst:sg:acc:m1                   subst:sg:gen:m1
# 547                   subst:sg:acc:m1                   subst:sg:gen:m1
# 548                 adj:sg:nom:m1:pos                    subst:sg:gen:f
# 549                        siebie:gen                    subst:sg:gen:f
# 550                    subst:pl:gen:f                   subst:pl:nom:m1
# 551                   subst:sg:gen:m1                   subst:sg:gen:m3
# 552    ppron3:sg:loc:m1:ter:akc:praep               subst:sg:loc:n:ncol
# 553                praet:sg:m1:imperf                  praet:sg:m1:perf
# 554                praet:sg:m1:imperf                  praet:sg:m1:perf
# 555  ppron3:sg:dat:m1:ter:nakc:npraep                   subst:sg:dat:m1
# 556                               adv                 num:pl:acc:m3:rec
# 557                              part                          prep:gen
# 558                 adj:sg:gen:m3:pos                               dig
# 559                   subst:pl:acc:m1                   subst:pl:gen:m1
# 560                   subst:sg:nom:m1                    subst:sg:acc:f
# 561                              part                         imps:perf
# 562                              comp                              pred
# 563                 fin:sg:pri:imperf                  subst:sg:inst:m3
# 564                subst:pl:inst:n:pt                  subst:pl:inst:m1
# 565               subst:pl:gen:n:ncol                 subst:pl:gen:n:pt
# 566                   subst:pl:acc:m1                  adj:pl:gen:f:pos
# 567                   subst:sg:acc:m1                  adj:sg:nom:f:pos
# 568                   subst:sg:gen:m1                    subst:sg:nom:f
# 569                          prep:acc                         prep:inst
# 570                         pant:perf                   fin:sg:ter:perf
# 571                              part                          prep:gen
# 572                 num:pl:gen:m3:rec                 adj:sg:gen:m3:pos
# 573                  praet:sg:m3:perf                  praet:sg:m1:perf
# 574                   subst:sg:loc:m3                    subst:sg:loc:f
# 575                   subst:pl:acc:m3                   subst:pl:acc:m1
# 576                   subst:sg:dat:m1                   subst:sg:gen:m3
# 577               subst:sg:dat:n:ncol                          prep:acc
# 578                              part                         imps:perf
# 579                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 580                  praet:sg:m1:perf                  praet:sg:m3:perf
# 581                   subst:pl:acc:m1                   subst:pl:gen:m3
# 582               praet:sg:ter:imperf                praet:sg:m1:imperf
# 583                           adv:com                 adj:sg:nom:m1:pos
# 584                               adv                   subst:sg:acc:m3
# 585                   subst:sg:acc:m1                   subst:sg:gen:m1
# 586                   subst:sg:acc:m1                   subst:sg:gen:m1
# 587                   subst:pl:inst:f                  subst:pl:inst:m3
# 588                    subst:pl:acc:f                    subst:sg:gen:f
# 589                praet:sg:m3:imperf                praet:sg:m1:imperf
# 590                praet:sg:m1:imperf                  praet:sg:m1:perf
# 591                  adj:sg:gen:f:pos                    subst:sg:gen:f
# 592        ppron12:sg:dat:m1:sec:nakc                 adj:pl:nom:m1:pos
# 593                praet:pl:m1:imperf                   subst:pl:nom:m1
# 594                praet:pl:m1:imperf                  praet:pl:m1:perf
# 595                  praet:sg:m1:perf                  praet:sg:m3:perf
# 596                 adj:sg:nom:m3:pos                 adj:sg:acc:m3:pos
# 597                   subst:sg:nom:m3                   subst:sg:acc:m3
# 598                              part                           adv:pos
# 599                    subst:sg:nom:f                impt:sg:sec:imperf
# 600                        inf:imperf                          inf:perf
# 601                 adj:sg:nom:m3:pos                   subst:pl:nom:m3
# 602                              pred                  adj:sg:nom:f:pos
# 603               subst:pl:acc:n:ncol               subst:sg:gen:n:ncol
# 604                praet:sg:m1:imperf                praet:sg:m3:imperf
# 605           ppas:sg:nom:m1:perf:aff                 adj:sg:nom:m3:pos
# 606                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 607                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 608                              conj                              part
# 609  ppron3:sg:acc:m1:ter:nakc:npraep  ppron3:sg:acc:m3:ter:nakc:npraep
# 610                adj:sg:inst:m1:pos        pact:sg:inst:m1:imperf:aff
# 611                 adj:pl:inst:f:pos           ppas:pl:inst:f:perf:aff
# 612                   subst:pl:inst:f                  subst:sg:inst:m3
# 613                 adj:pl:inst:f:pos                adj:sg:inst:m3:pos
# 614                          prep:acc                          prep:loc
# 615    ppron3:sg:acc:m1:ter:akc:praep                 adj:sg:loc:m3:pos
# 616                    subst:sg:nom:f                    subst:sg:acc:f
# 617                    subst:pl:dat:f                   subst:pl:dat:m1
# 618                  adj:sg:dat:f:pos                 adj:pl:dat:m1:pos
# 619          ppas:sg:dat:f:imperf:aff                   subst:pl:dat:m1
# 620                    subst:sg:dat:f                  adj:sg:gen:f:pos
# 621                    subst:sg:dat:f                   subst:sg:nom:m1
# 622                    subst:sg:gen:f                   subst:sg:gen:m1
# 623                   subst:sg:inst:f                 adj:sg:inst:f:pos
# 624                   subst:sg:inst:f                 adj:sg:inst:f:pos
# 625                 adj:sg:inst:f:pos                   subst:sg:inst:f
# 626                      prep:gen:wok                     prep:inst:wok
# 627                   subst:pl:gen:m1                 adj:pl:gen:m1:pos
# 628                   subst:sg:nom:m3                   subst:sg:nom:m1
# 629                              part                              conj
# 630             num:pl:nom:f:rec:ncol                  num:pl:acc:f:rec
# 631                 adj:sg:loc:m3:pos               subst:sg:loc:n:ncol
# 632                   subst:sg:loc:m3               subst:sg:loc:n:ncol
# 633          num:pl:nom:m3:congr:ncol               num:pl:acc:m3:congr
# 634                   subst:pl:nom:m3                   subst:pl:acc:m3
# 635                num:pl:nom:f:congr                  adj:sg:gen:f:pos
# 636                    subst:pl:nom:f                    subst:sg:gen:f
# 637           num:pl:nom:f:congr:ncol                num:pl:nom:f:congr
# 638                              part                              comp
# 639                    subst:sg:nom:f                   subst:sg:gen:m1
# 640                    subst:sg:nom:f                   subst:sg:gen:m1
# 641                 subst:pl:gen:n:pt                   subst:sg:nom:m1
# 642                   subst:sg:gen:m3               subst:sg:gen:n:ncol
# 643                 adj:pl:gen:m1:pos                 adj:pl:gen:m3:pos
# 644                 praet:pl:f:imperf                 praet:pl:n:imperf
# 645           num:pl:nom:f:congr:ncol                num:pl:acc:f:congr
# 646                    subst:pl:nom:f                    subst:pl:acc:f
# 647                               adv                    subst:pl:gen:f
# 648                              comp                              part
# 649  ppron3:sg:gen:m1:ter:nakc:npraep                   subst:pl:nom:m2
# 650                 praet:sg:f:imperf                   subst:sg:acc:m1
# 651                 adj:sg:nom:m1:pos                   praet:pl:f:perf
# 652                   subst:pl:nom:m2                    subst:pl:acc:f
# 653                   subst:pl:nom:m1                    subst:sg:nom:f
# 654                 fin:sg:ter:imperf                    subst:sg:nom:f
# 655                   subst:pl:gen:m1                   subst:pl:gen:m3
# 656                  praet:sg:m1:perf                  praet:sg:m3:perf
# 657                 praet:sg:n:imperf                           adv:pos
# 658                   subst:sg:loc:m1                   subst:sg:loc:m3
# 659            ppas:sg:acc:n:perf:aff                  adj:sg:acc:n:pos
# 660                   subst:pl:acc:m3                    subst:pl:acc:f
# 661             num:pl:acc:f:rec:ncol                  num:pl:acc:f:rec
# 662                  adj:sg:gen:f:pos           ppas:sg:nom:m3:perf:aff
# 663                   subst:sg:gen:m1                   subst:sg:gen:m3
# 664                  adj:sg:nom:f:pos                    subst:sg:nom:f
# 665                          prep:nom                              comp
# 666                  adj:sg:nom:f:pos                    subst:sg:nom:f
# 667                    subst:sg:nom:f                   subst:sg:gen:m1
# 668                    subst:sg:nom:f                   subst:sg:gen:m1
# 669                   subst:pl:acc:m1                    subst:pl:acc:f
# 670                              pred               subst:sg:nom:n:ncol
# 671                          prep:gen                              part
# 672                  adj:sg:gen:n:pos               subst:sg:gen:n:ncol
# 673                  adj:sg:nom:f:pos                    subst:sg:nom:f
# 674                    subst:sg:gen:f                  adj:sg:nom:f:pos
# 675                    subst:sg:acc:f                   subst:sg:nom:m1
# 676                 subst:pl:acc:n:pt                   subst:sg:nom:m1
# 677               subst:sg:nom:n:ncol               subst:sg:acc:n:ncol
# 678                  praet:sg:m1:perf                  praet:sg:m3:perf
# 679                  adj:sg:gen:f:pos                 adj:sg:nom:m1:pos
# 680                    subst:sg:gen:f                   subst:sg:nom:m1
# 681                 praet:sg:f:imperf                    subst:sg:nom:f
# 682                   subst:sg:acc:m1                   subst:sg:gen:m1
# 683                 num:pl:gen:m3:rec               num:pl:gen:m3:congr
# 684         pact:sg:acc:m1:imperf:aff                   subst:sg:gen:m1
# 685                   subst:sg:acc:m1                    subst:sg:acc:f
# 686                   subst:sg:acc:m1                 fin:sg:ter:imperf
# 687                  adj:sg:loc:n:pos                 adj:sg:loc:m3:pos
# 688             ger:sg:dat:n:perf:aff             ger:sg:loc:n:perf:aff
# 689                               ign                           adv:pos
# 690                               ign                         imps:perf
# 691                   subst:sg:acc:m3                    subst:sg:nom:f
# 692   ppron3:pl:acc:m3:ter:akc:npraep   ppron3:pl:acc:m1:ter:akc:npraep
# 693                 adj:pl:acc:m3:pos                 adj:pl:nom:m3:pos
# 694                 subst:pl:acc:n:pt                   subst:pl:nom:m3
