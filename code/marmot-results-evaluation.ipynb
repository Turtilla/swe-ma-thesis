# %% [markdown]
# # MARMOT EVALUATION

# %% [markdown]
# ### IMPORTS, VARIABLES

# %%
import conllu
import sklearn.metrics
import pandas as pd
import matplotlib.pyplot as plt
import time

pd.set_option('display.max_rows', None)

# %%
xpos_predictions = './marmot/test_hist_XPOS.out.txt'
upos_predictions = './marmot/test_hist_UPOS.out.txt'

xpos_standard = './marmot/test_hist_XPOS.txt'
upos_standard = './marmot/test_hist_UPOS.txt'

test_predictions = './marmot/test.out.txt'
test_standard = './marmot/test.txt'

# %%
from functions import *

# %% [markdown]
# ### FUNCTIONS

# %%
def get_marmot_tags_and_tokens(filename: str):
    with open(filename) as f:
        tags = f.readlines()
        tokens = [x.strip().split()[0] for x in tags if len(x.strip()) > 0]
        upos = [x.strip().split()[1] for x in tags if len(x.strip()) > 0]
        xpos = [x.strip().split()[2] for x in tags if len(x.strip()) > 0]
        
    return tokens, upos, xpos

# %% [markdown]
# ### EXECUTION - MODERN
# Since unlike the BERT-based tagger Marmot does not output any training/evaluation/testing measures, I need to obtain them myself from contemporary test data.

# %%
# Marmot returns files in a CoNLL-2009 format; it can still be parsed using conllu and my function, but the names of
# the features do not match; here 'feats' corresponds to UPOS tags and 'deprel' to XPOS.
test_tokens, test_upos_preds = extract_conllu_data(test_predictions, 'feats', sentences=False, fulltext=False)
test_tokens, test_xpos_preds = extract_conllu_data(test_predictions, 'deprel', sentences=False, fulltext=False)
# Due to the issue mentioned above, UPOS tags need to be further processed.
test_upos_preds = [list(x.keys())[0] for x in test_upos_preds]

# %%
# Retrieving the gold standard tags
_, test_upos_standard, test_xpos_standard = get_marmot_tags_and_tokens(test_standard)

# %%
get_measures(test_upos_standard, test_upos_preds, details=True)
# Out:
# MEASURES:
# Accuracy: 97.73%
# Precision (weighted): 97.75%
# Recall (weighted): 97.73%
# F1 (weighted): 97.73%
# Matthew's Correlation Coefficient: 97.38%
#
# MEASURES PER CLASS:
# Precision:
# 	ADJ: 97.25%
# 	ADP: 99.46%
# 	ADV: 95.59%
# 	AUX: 91.67%
# 	CCONJ: 96.17%
# 	DET: 98.44%
# 	INTJ: 46.15%
# 	NOUN: 98.23%
# 	NUM: 98.04%
# 	PART: 93.49%
# 	PRON: 99.05%
# 	PROPN: 91.30%
# 	PUNCT: 99.95%
# 	SCONJ: 96.49%
# 	SYM: 100.00%
# 	VERB: 97.96%
# 	X: 89.33%
# Recall:
# 	ADJ: 97.71%
# 	ADP: 99.74%
# 	ADV: 95.33%
# 	AUX: 95.60%
# 	CCONJ: 96.26%
# 	DET: 96.93%
# 	INTJ: 60.00%
# 	NOUN: 98.04%
# 	NUM: 94.34%
# 	PART: 92.42%
# 	PRON: 98.31%
# 	PROPN: 94.09%
# 	PUNCT: 99.95%
# 	SCONJ: 96.21%
# 	SYM: 25.00%
# 	VERB: 97.43%
# 	X: 86.73%

# %%
get_measures(test_xpos_standard, test_xpos_preds)  # measures per class are not as informative here
# Out:
# MEASURES:
# Accuracy: 89.27%
# Precision (weighted): 88.95%
# Recall (weighted): 89.27%
# F1 (weighted): 88.81%
# Matthew's Correlation Coefficient: 88.83%

# %% [markdown]
# ### EXECUTION - HISTORICAL

# %%
# The same is done with the historical data.
hist_upos_tokens, hist_upos_preds = extract_conllu_data(upos_predictions, 'feats', sentences=False, fulltext=False)
hist_xpos_tokens, hist_xpos_preds = extract_conllu_data(xpos_predictions, 'deprel', sentences=False, fulltext=False)

hist_upos_preds = [list(x.keys())[0] for x in hist_upos_preds]

# %%
# Retrieving the gold standard tags - since we have two different files for XPOS and UPOS annotations we need two function calls
_, hist_upos_standard, _ = get_marmot_tags_and_tokens(upos_standard)
_, _, hist_xpos_standard = get_marmot_tags_and_tokens(xpos_standard)

# %%
get_measures(hist_upos_standard, hist_upos_preds, details=True)
# Out:
# MEASURES:
# Accuracy: 90.41%
# Precision (weighted): 90.59%
# Recall (weighted): 90.41%
# F1 (weighted): 90.40%
# Matthew's Correlation Coefficient: 89.12%
#
# MEASURES PER CLASS:
# Precision:
# 	ADJ: 81.02%
# 	ADP: 99.49%
# 	ADV: 86.53%
# 	AUX: 82.77%
# 	CCONJ: 97.20%
# 	DET: 95.25%
# 	NOUN: 89.16%
# 	NUM: 97.98%
# 	PART: 78.39%
# 	PRON: 90.66%
# 	PROPN: 78.49%
# 	PUNCT: 100.00%
# 	SCONJ: 86.26%
# 	VERB: 91.50%
# 	X: 63.16%
# Recall:
# 	ADJ: 84.43%
# 	ADP: 98.90%
# 	ADV: 85.25%
# 	AUX: 85.99%
# 	CCONJ: 95.76%
# 	DET: 75.18%
# 	NOUN: 90.90%
# 	NUM: 72.93%
# 	PART: 75.00%
# 	PRON: 86.36%
# 	PROPN: 86.12%
# 	PUNCT: 100.00%
# 	SCONJ: 91.92%
# 	VERB: 92.31%
# 	X: 52.17%

# %%
get_measures(hist_xpos_standard, hist_xpos_preds)
# Out:
# MEASURES:
# Accuracy: 80.22%
# Precision (weighted): 81.29%
# Recall (weighted): 80.22%
# F1 (weighted): 79.70%
# Matthew's Correlation Coefficient: 79.60%

# %%
full_upos = get_full_table(hist_upos_standard, hist_upos_preds, hist_upos_tokens)
full_upos.to_excel('../data/results/marmot_UPOS.xlsx')

# %%
comparison_upos = get_comparison(hist_upos_standard, hist_upos_preds, hist_upos_tokens)
comparison_upos.to_excel('../data/mistakes/marmot_UPOS_mistakes.xlsx')

# %%
full_xpos = get_full_table(hist_xpos_standard, hist_xpos_preds, hist_xpos_tokens)
full_xpos.to_excel('../data/results/marmot_XPOS.xlsx')

# %%
comparison_xpos = get_comparison(hist_xpos_standard, hist_xpos_preds, hist_xpos_tokens)
comparison_xpos.to_excel('../data/mistakes/marmot_XPOS_mistakes.xlsx')

# %%
comparison_upos
# Out:
#                 Token                            Context Gold Standard  \
# 0            Melchior              mój Melchior urodzony         PROPN
# 1           Komornika               Jana Komornika ziemi          NOUN
# 2                   ś                         bratem ś .             X
# 3          Pinińskich           z Pinińskich właścicieli         PROPN
# 4                Dóbr          właścicieli Dóbr Strużewo          NOUN
# 5             Dąbrowy                   , Dąbrowy części         PROPN
# 6                  śp                        że śp Dziad             X
# 7        Dobrzyńskiej              ziemi Dobrzyńskiej za         PROPN
# 8               Panna              siostra Panna Urszula          NOUN
# 9                  śp                          miał śp .             X
# 10           Melchior                . Melchior czterech         PROPN
# 11              jedną                     i jedną ciotkę           NUM
# 12             Ciotka                        – Ciotka za          NOUN
# 13                 17                          było 17 .           NUM
# 14               było                Antonich było dwóch           AUX
# 15            Niewiem                        . Niewiem o          VERB
# 16             jakoby                     – jakoby Dziad         SCONJ
# 17              Dziad                  jakoby Dziad jego          NOUN
# 18               jego                       Dziad jego a           DET
# 19           Starostą                 podobno Starostą ,          NOUN
# 20          Potockich                  Domem Potockich ,         PROPN
# 21               jego                  całą jego rodzinę           DET
# 22         chłopczyna                był chłopczyna więc          NOUN
# 23                 to                           co to za          PRON
# 24              jeden                         za jeden .           NUM
# 25           Starosta                  Pan Starosta całą          NOUN
# 26             rychło                 natury rychło ujął           ADV
# 27                tak                        i tak umiał           ADV
# 28            Patrona                  swojego Patrona ,          NOUN
# 29               Panu       zaproponował Panu Potockiemu          NOUN
# 30               Myśl                         . Myśl się          NOUN
# 31               Panu           podobała Panu Potockiemu          NOUN
# 32               Panu      zaproponował Panu Melchiorowi          NOUN
# 33         Szczęśliwa                  . Szczęśliwa była           ADJ
# 34             Dziada                  dla Dziada mojego          NOUN
# 35               jego                 przyszłości jego .           DET
# 36               Panu              Dziad Panu Potockiemu          NOUN
# 37                był                 Potockiemu był jak           AUX
# 38                owe                       na owe czasy           DET
# 39             piękny                     czasy piękny –           ADJ
# 40                tem             ujęty tem zaproponował          PRON
# 41               jego              początek jego fortuny           DET
# 42                 to                       mogło to być           AUX
# 43                być                       to być około           AUX
# 44           Halickim                       w Halickim ,           ADJ
# 45              Panną                   z Panną Kobylską          NOUN
# 46           Kobylską                   Panną Kobylską ,         PROPN
# 47              Około                       . Około roku          PART
# 48           Dzianott                domu Dzianott wdowa         PROPN
# 49                 by                  dworu by zapłacić         SCONJ
# 50               rada                        – rada była           ADJ
# 51           gosposia             była gosposia gościowi          NOUN
# 52             Jesteś                     ? Jesteś wdowa          VERB
# 53              wdowa                     Jesteś wdowa –          NOUN
# 54            wdowiec                       ja wdowiec –          NOUN
# 55                 że                          ale że mi         SCONJ
# 56               więc                      , więc jeżeli         CCONJ
# 57             Pannie                  wstąpi Pannie się          NOUN
# 58            Dziekan                 ówczesny Dziekan i          NOUN
# 59             Oyciec              mój Oyciec Franciszek          NOUN
# 60            osiedli                   nauki osiedli na          VERB
# 61              Babki                      mojej Babki ,          NOUN
# 62               pono                       która pono w          PART
# 63       Czermińskiej         starościny Czermińskiej we         PROPN
# 64              druga                         , druga za           ADJ
# 65      Świeżawskiego         za Świeżawskiego komornika         PROPN
# 66            Cyrkule               w Cyrkule Samborskim          NOUN
# 67              jeden                        – jeden był           NUM
# 68              oddał                swój oddał akademii          VERB
# 69              Abbum         drzwiami Abbum Treterianum             X
# 70        Treterianum                Abbum Treterianum .             X
# 71              Lwowa           bombardowaniu Lwowa roku         PROPN
# 72            została                        w została w          VERB
# 73         zniszczały                    te zniszczały .          VERB
# 74               jego                         Syn jego a           DET
# 75                  i                            bo i po          PART
# 76                 to                     , to zarządzał          PART
# 77                 to                    , to dzierżawił          PART
# 78          oświecony               katafalk oświecony a          VERB
# 79              Zaraz                         . Zaraz na           ADV
# 80               Tobą                      z Tobą Stasiu          PRON
# 81               tyle                      Stasiu tyle a           DET
# 82                mię                   Zostawiasz mię z          PRON
# 83               zato                           – zato ,          PRON
# 84                 Ci                       ażeby Ci Bóg          PRON
# 85                Bóg                          Ci Bóg na          NOUN
# 86                ich               obracają ich rodziny           DET
# 87        Świerzawski              wuj Świerzawski kuzyn         PROPN
# 88       Polanowskich               kuzyn Polanowskich z         PROPN
# 89           oblegany                     Pań oblegany –           ADJ
# 90                móy            Dziadek móy Ostaszewski           DET
# 91            służąca               musiała służąca całą          NOUN
# 92            Niewiem                    . Niewiem jakim          VERB
# 93         Treterówną               siostrą Treterówną -         PROPN
# 94         Treterówną               siostrą Treterówną –         PROPN
# 95                 aż                           , aż się          PART
# 96                nim                        się nim Pan          PRON
# 97                móy                 Ojciec móy sierota           DET
# 98                być                       to być około           AUX
# 99         podpodczas                 – podpodczas wojen           ADP
# 100            Cobary              Sachsen Cobary Ułanów             X
# 101            Ułanów                Cobary Ułanów mając          NOUN
# 102                14                           lat 14 .           NUM
# 103          niewiele          czasów niewiele opowiadał           DET
# 104                 ś                             mi ś .             X
# 105         najwięcej                  a najwięcej czasu           ADJ
# 106            Oyciec                    a Oyciec ciągle          NOUN
# 107               móy                       . móy Oyciec           DET
# 108            Oyciec                   móy Oyciec około          NOUN
# 109             około                  Oyciec około 1808           ADP
# 110              1808                       około 1808 –           ADJ
# 111              1809                        albo 1809 –           ADJ
# 112               był                    Iglan był ranny          VERB
# 113            pieszy              pułk pieszy Francuzów           ADJ
# 114         skrzętnem    fortuny skrzętnem gospodarstwem           ADJ
# 115               tem                         po tem jak          PRON
# 116               set                     parę set sztuk           NUM
# 117     Rozwadowskiej           Pani Rozwadowskiej 10000         PROPN
# 118     Rozwadowskiej             Pani Rozwadowskiej nie         PROPN
# 119          Dziedzic             Nowy Dziedzic wchodził          NOUN
# 120           któremi              nad któremi obeymował           DET
# 121         pierwszey    policyjną pierwszey instantacyi           ADJ
# 122               Zaś                       . Zaś daniny         CCONJ
# 123              byli                        - byli więc          VERB
# 124                ci                         – ci winni          PRON
# 125             pewną               odrabiać pewną ilość           ADJ
# 126                ci                     - ci odrabiali          PRON
# 127              tego                      Oprócz tego z           DET
# 128             jeden              korce jeden gospodarz           NUM
# 129              tego                     Oprócz tego ci           DET
# 130                ci                          tego ci i          PRON
# 131            spaśne                     zwane spaśne -          NOUN
# 132             pewną                chałupy pewną ilość           ADJ
# 133         pastwisko                - pastwisko ratował          NOUN
# 134            Wieleż                        . Wieleż to           DET
# 135                to                     Wieleż to razy          PART
# 136              jego                    że jego kmiecie           DET
# 137            suchey                 morgów suchey łąki           ADJ
# 138      nayskładniey            a nayskładniey położone           ADV
# 139            Niebył                        . Niebył to           AUX
# 140                to                Niebył to obowiązek           AUX
# 141        Oycowskiey                     . Oycowskiey .           ADJ
# 142               tak              obszarze tak dworskim         CCONJ
# 143           poddani                - poddani uwolnieni          NOUN
# 144                to                          , to jest          PRON
# 145            takiem             przy takiem obciążeniu           DET
# 146               tak                   jednakże tak nie           ADV
# 147              Herb                 był Herb Dziedzica          NOUN
# 148         Dziedzica                   Herb Dziedzica –          NOUN
# 149            dokoła                     a dokoła napis           ADP
# 150          Dominium            napis Dominium Bludniki          NOUN
# 151      Nieszlachcic             . Nieszlachcic niemógł          NOUN
# 152          Dziedzic             . Dziedzic postanawiał          NOUN
# 153            swojem                  na swojem mieycus           DET
# 154     Mandatariusza            mieycus Mandatariusza -          NOUN
# 155               Był                          . Był też          VERB
# 156           dopokąd                        – dopokąd z         SCONJ
# 157           Dominii             z Dominii nieprzyniósł          NOUN
# 158                 A                        . A chociaż         CCONJ
# 159           chociaż                        A chociaż i         SCONJ
# 160             ktoby                        a ktoby był          PRON
# 161         szlachcic                 Podola szlachcic w          NOUN
# 162          Sanockie                       w Sanockie –           ADJ
# 163         poddanych             zdzierstwa poddanych –          NOUN
# 164               móy                 Dziadek móy mawiał           DET
# 165              tego                      Pana tego nie           DET
# 166          ludowemi              dziś ludowemi zwanych           ADJ
# 167             lizną                czasem lizną trochę          VERB
# 168            trochę                lizną trochę łaciny           DET
# 169             prawa                     trochę prawa –          NOUN
# 170       manipulacyi            – manipulacyi urzędowey          NOUN
# 171         urzędowey            manipulacyi urzędowey –           ADJ
# 172        Starostwie                     w Starostwie w          NOUN
# 173           Cyrkule                        w Cyrkule i          NOUN
# 174     Mandataryusza              czyli Mandataryusza .          NOUN
# 175      Mandatyrusza          . Mandatyrusza przyjmował          NOUN
# 176          Dziedzic             przyjmował Dziedzic na          NOUN
# 177      Mandataryusz            . Mandataryusz pobierał          NOUN
# 178              opał                pomieszkanie opał –          NOUN
# 179         Dziedzica             zastępował Dziedzica .          NOUN
# 180           dotacyi    szczupłey dotacyi uwzględniając          NOUN
# 181               one                        w one czasy           DET
# 182                 4                  dzisiejszych 4 do           NUM
# 183              żyta           korzec żyta dzisiejszych          NOUN
# 184                 1                  dzisiejszych 1 fl           NUM
# 185                fl                             1 fl –             X
# 186                10                       korzec 10 do           NUM
# 187           przytem                mając przytem jakiś          PRON
# 188                ci                   Panowie ci mieli           DET
# 189             ładąn                       – ładąn parą           ADJ
# 190                fl                           600 fl .             X
# 191               móy                      gdy móy Dziad           DET
# 192             jeden                          – jeden z           NUM
# 193              jego                doskonale jego Syna           DET
# 194                to                       może to jego          PART
# 195            dokoła               obszerna dokoła ławy           ADP
# 196           niewiem                      – niewiem czy          VERB
# 197               czy                      niewiem czy z          PART
# 198           naprzód                      się naprzód i           ADP
# 199              Panu                co Panu Dziedzicowi          NOUN
# 200       Dziedzicowi            Panu Dziedzicowi chodzi          NOUN
# 201               móy           Dziadek móy odpowiedział           DET
# 202        człowiecze                   Ty człowiecze na          NOUN
# 203                 A                        ? A wówczas         CCONJ
# 204          Dziedzic              żeby Dziedzic przyjął          NOUN
# 205              jego                 przyjął jego pomoc           DET
# 206            Takich                . Takich gospodarzy           DET
# 207             mojey                   za mojey pamięci           DET
# 208               owe                        w owe czasy           DET
# 209               był                      i był jaszcze          VERB
# 210           jaszcze                    był jaszcze tam          PART
# 211         księżunio                     , księżunio od          NOUN
# 212         Lubelskie                   w Lubelskie jako           ADJ
# 213                 I                            . I tak         CCONJ
# 214            późney                 tak późney dokupił           ADV
# 215               móy                  Dziad móy Dorchów           DET
# 216              Toje                        – Toje diło             X
# 217              diło                   Toje diło daruju             X
# 218            daruju             diło daruju ukochanomu             X
# 219        ukochanomu             daruju ukochanomu Synu             X
# 220              Synu             ukochanomu Synu mojomu             X
# 221            mojomu             Synu mojomu Mychayłowu             X
# 222        Mychayłowu                mojomu Mychayłowu .             X
# 223             iOycu              Józefowi iOycu mojemu          NOUN
# 224               móy                   Oyciec móy objął           DET
# 225              Oyca                   mojego Oyca pono          NOUN
# 226              pono                     Oyca pono 1813          PART
# 227              1813                     pono 1813 albo           ADJ
# 228              1814                        albo 1814 –           ADJ
# 229               móy                     Dziadek móy do           DET
# 230            Siebie                       do Siebie do          PRON
# 231              Oyca                dośmierci Oyca przy          NOUN
# 232               Nim                  przy Nim zostawał          PRON
# 233               móy                     Dziadek móy ku           DET
# 234                Mu             Zdejmował Mu kataraktę          PRON
# 235            Doktor       kataraktę Doktor Słowikowski          NOUN
# 236               ile                        i ile sobie           ADV
# 237              1826                       około 1826 .           ADJ
# 238              pono                       końcu pono w          PART
# 239          niewinem                    Lipa niewinem .          VERB
# 240        Zabilskich            Stanisława Zabilskich –         PROPN
# 241          jedynaka               Syna jedynaka Sabina          NOUN
# 242            Oyciec                  go Oyciec odumarł          NOUN
# 243             Oycem                za Oycem doszedłszy          NOUN
# 244                24                        około 24 na           NUM
# 245             Matkę                         na Matkę –          NOUN
# 246              temu                     żona temu pono           DET
# 247              pono                        temu pono z          PART
# 248           Dorchów           zostawił Dorchów swojemu         PROPN
# 249            więcey        gospodarzem więcey fantasta           ADV
# 250             wgłos                   czytywał wgłos „           ADV
# 251               Był                       . Był bardzo          VERB
# 252               tey                    do tey praktyki           DET
# 253                ci                    ale ci niemogli          PRON
# 254          niemogli                  ci niemogli długo          VERB
# 255          nietylko                 – nietylko czeladź         CCONJ
# 256           czeladź               nietylko czeladź ale          NOUN
# 257             sądny                      więc sądny to           ADJ
# 258          niemożna             obeyściu niemożna było          VERB
# 259             tylko                 zacny tylko raptus         CCONJ
# 260               mim                           po mim ,          PRON
# 261              Oyca                mojego Oyca spadała          NOUN
# 262          rodzonym          swoim rodzonym Treterowej           ADJ
# 263        Treterowej              rodzonym Treterowej i         PROPN
# 264              Oyca                     śmierci Oyca z          NOUN
# 265             Panną                      z Panną Julią          NOUN
# 266        Świeżyńską          Julią Świeżyńską urodzoną         PROPN
# 267          urodzoną             Świeżyńską urodzoną ze           ADJ
# 268        Zawadzkich                    ze Zawadzkich –         PROPN
# 269       Kruszelnicę                  czy Kruszelnicę –         PROPN
# 270            jednem                 na jednem obeyściu           NUM
# 271                 2                          - 2 Panny           NUM
# 272             Panny                   2 Panny niemając          NOUN
# 273             Panna                  fatum Panna Julia          NOUN
# 274          Rudzkich             Państwa Rudzkich gdzie         PROPN
# 275               tąd                       z tąd bywała           ADV
# 276             Jakby              . Jakby instynktownie         SCONJ
# 277               jey                    moja jey znieść          PRON
# 278          niemogła                  znieść niemogła .          VERB
# 279           osiadły                   Józef osiadły na           ADJ
# 280             Panny                  krewni Panny Juli          NOUN
# 281             niema               że niema sukcessorów          VERB
# 282              Panu                  ale Panu Józefowi          NOUN
# 283        niechciało         Józefowi niechciało ruszać          VERB
# 284              hoża                       się hoża jak           ADJ
# 285             Panna                  łania Panna Julia          NOUN
# 286              Było                          . Było to           AUX
# 287                to                      Było to około           AUX
# 288             około                      to około 1829           ADP
# 289              tego               małżeństwa tego była           DET
# 290              była                   tego była jedyna          VERB
# 291       Siemiginowa          sukcessorka Siemiginowa –         PROPN
# 292        Bałamuciła           . Bałamuciła przebierała          VERB
# 293             około                  młodzika około 24           ADP
# 294                24                       około 24 lat           ADJ
# 295         liczącego                    lat liczącego –          VERB
# 296         próżniaka           sybarytę próżniaka toteż          NOUN
# 297         Separacya              nastąpiła Separacya .          NOUN
# 298           secundo                 Julia secundo voto             X
# 299              voto             secundo voto Szołayska             X
# 300             Mosty                  przyległe Mosty .         PROPN
# 301             Panną                 z Panną Polanowską          NOUN
# 302            Ciotką                      a Ciotką Pana          NOUN
# 303               jak                        Ale jak się         SCONJ
# 304               móy              dowiedział móy Oyciec           DET
# 305          Bludniki                  o Bludniki służbę         PROPN
# 306             Matce                       Po Matce wuy          NOUN
# 307               wuy                     Matce wuy Oyca          NOUN
# 308              Oyca              wuy Oyca Pieścioroski          NOUN
# 309                Mu              zaproponował Mu Pannę          PRON
# 310             Pannę                Mu Pannę Franciszkę          NOUN
# 311       Ostaszewską       Franciszkę Ostaszewską córkę         PROPN
# 312         Chorążego          córkę Chorążego Kawaleryi          NOUN
# 313         Kawaleryi      Chorążego Kawaleryi Narodowey          NOUN
# 314         Narodowey              Kawaleryi Narodowey i           ADJ
# 315         Dziedzica               i Dziedzica Zarszyna          NOUN
# 316         Załęskich                     ze Załęskich .         PROPN
# 317             Jakoż              . Jakoż zaprezentował         CCONJ
# 318                Go           zaprezentował Go Państwu          PRON
# 319      Ostaszewskim           Państwu Ostaszewskim Pan         PROPN
# 320              Oycu                      – Oycu mojemu          NOUN
# 321             Panna                     mojemu Panna i          NOUN
# 322               Jey           staropolski Jey Rodziców           DET
# 323      etykietalney     Zamiast etykietalney pierwszey           ADJ
# 324         pierwszey      etykietalney pierwszey wizyty           ADJ
# 325            został                – został zatrzymany          VERB
# 326              Veni                           . Veni –             X
# 327              vici                           – vici .             X
# 328           Niewiem                      . Niewiem czy          VERB
# 329            swojey               razą swojey bytności           DET
# 330                al               malowidłem al fresco             X
# 331            fresco                        al fresco –             X
# 332           Bludnik                   widoki Bludnik i         PROPN
# 333             Skała                         – Skała na          NOUN
# 334              niey                    na niey Sokołów          PRON
# 335           Łomnica                    dołem Łomnica –         PROPN
# 336            Ś-tego            widok Ś-tego Stanisława             X
# 337        Stanisława        Ś-tego Stanisława klasztoru             X
# 338           Łomnicą              nad Łomnicą wpadającą         PROPN
# 339          Dniestru                      do Dniestru ,         PROPN
# 340                to                         , to znowu           AUX
# 341             Ruiny                  znowu Ruiny zamku          NOUN
# 342        Halickiego            zamku Halickiego opodal           ADJ
# 343            opodal                Halickiego opodal –           ADP
# 344             droga                   wreszcie droga z          NOUN
# 345              niey                  przy niey kaplica          PRON
# 346     nayjświętszey        kaplica nayjświętszey Panny           ADJ
# 347             Panny  nayjświętszey Panny Niepokalanego          NOUN
# 348             daley                        – daley jak           ADV
# 349               jak                    daley jak droga           ADV
# 350          Swiętego              kaplica Swiętego Jana           ADJ
# 351                to                    Wszystko to tak          PRON
# 352          podobnem        czemś podobnem niespotkałem           ADJ
# 353      niespotkałem        podobnem niespotkałem nawet          VERB
# 354               jak               wrażenia jak wówczas           ADV
# 355                 i                        też i temat         CCONJ
# 356           łamiąca                Łomnica łamiąca się           ADJ
# 357             skałą                   pod skałą wysoką          NOUN
# 358            wysoką              skałą wysoką oddającą           ADJ
# 359             ujęta                          – ujęta w          VERB
# 360            strome                w strome pochyłości           ADJ
# 361           Łomnicy                 ku Łomnicy porosłe         PROPN
# 362             Skała                   . Skała ożywiona          NOUN
# 363          tysiącem           ożywiona tysiącem gniazd           NUM
# 364      przyjezdnych    witających przyjezdnych wesołym          NOUN
# 365        Bludnickey              na Bludnickey stronie           ADJ
# 366           Karpaty     nibieszczeją Karpaty huculskie         PROPN
# 367             droga                         a droga do          NOUN
# 368          spaśnemi         ożewionemi spaśnemi wołami           ADJ
# 369        przedewsią           droga przedewsią smętarz          NOUN
# 370           okolony                   płotem okolony –           ADJ
# 371           główney               drogi główney traktu           ADJ
# 372             prawo                         na prawo –           ADV
# 373            prawey                   po prawey ciągną           ADJ
# 374             gumna                  się gumna staynie          NOUN
# 375           staynie             gumna staynie wozownia          NOUN
# 376          oddziela                   żywy oddziela od          VERB
# 377          pośrodku                   a pośrodku front           ADP
# 378        kamiennemi              płytami kamiennemi na           ADJ
# 379               tey                    w tey proporcyi           DET
# 380         proporcyi                  tey proporcyi jak          NOUN
# 381               jak               proporcyi jak środek           ADV
# 382               był                       – był zamiar          VERB
# 383              Oyca                  zamiar Oyca takie          NOUN
# 384                 ś                 prawdopodobnie ś .             X
# 385             Dziad                    . Dziad murować          NOUN
# 386               był                    pokoi był drugi          VERB
# 387            gładki                 szafirowy gładki ,           ADJ
# 388             tylko                         , tylko od          PART
# 389             szale         koloru szale podtrzymywane          NOUN
# 390             takoż            orłami takoż bronzowemi           ADV
# 391            obicie                         , obicie z          NOUN
# 392         jedwabney           żółtej jedwabney materyi           ADJ
# 393              Sala                     . Sala jadalna          NOUN
# 394            freski                   to freski bardzo          NOUN
# 395               jak                     palmowe jak na           ADV
# 396              dziś                          po dziś .          NOUN
# 397               jak                    pamiętam jak mi         SCONJ
# 398             niemi                pod niemi siedzenia          PRON
# 399            takowy               most takowy obszerny           DET
# 400               tey                    Dokoło tey kępy           DET
# 401              była                  kępy była szeroka          VERB
# 402           zarosła              fosa zarosła szuwarem           ADJ
# 403           trzciną                        i trzciną –          NOUN
# 404         widocznie                – widocznie miejsce           ADV
# 405                to                    miejsce to było           DET
# 406               był                 kamiennym był duży          VERB
# 407             Skała                          . Skała w          NOUN
# 408      nieciosanemi       bryłami nieciosanemi ułożona           ADJ
# 409               ani         niechwytało ani pruchniało          PART
# 410          Swiętego                broda Swiętego była          NOUN
# 411            jednem                   w jednem miejscu           NUM
# 412         widocznie                  – widocznie przez           ADV
# 413             Jakoż                   . Jakoż pamiętam         SCONJ
# 414               tem                        o tem takie          PRON
# 415         arędujący             Sadownik arędujący ten          VERB
# 416               tey             dopuścić tey zuchwałey           DET
# 417         zuchwałey             tey zuchwałey rozpusty           ADJ
# 418          Oyciciec                    . Oyciciec jego          NOUN
# 419              jego          Oyciciec jego zobaczywszy           DET
# 420              była                   Kapliczka była u          VERB
# 421        wszystkich                     u wszystkich w           DET
# 422          zwodzony               drewniany zwodzony .           ADJ
# 423            Oyciec                 Dopiero Oyciec móy          NOUN
# 424               móy                      Oyciec móy go           DET
# 425               Był                      . Był wówczas          VERB
# 426              most                   się most murował          NOUN
# 427            niebył         Jeszcze niebył zasklepiony           AUX
# 428             cegły                    kamień cegły na          NOUN
# 429               czy               Treter czy Swieżaski          PART
# 430           jeźdźca               uniósł jeźdźca pędem          NOUN
# 431            wprost                    pędem wprost na          PART
# 432          murujący                    na murujący się          VERB
# 433               mię                        ratuj mię !          PRON
# 434              dwór                       – dwór także          NOUN
# 435          okoloney             kępie okoloney różanym           ADJ
# 436               jej            obszar jej szczuplejszy           DET
# 437      szczuplejszy        jej szczuplejszy dochodziło           ADJ
# 438            dokoła                    ale dokoła staw           ADP
# 439            czółno                 i czółno przyjemna          NOUN
# 440            rześki             Dziadek rześki starzec           ADJ
# 441            swojim                  pobycie swojim na           DET
# 442           Kresach                       na Kresach ,         PROPN
# 443             oczem                Krasickiego oczem w          PRON
# 444            piękna                      – piękna miła           ADJ
# 445     obywatelskiey    dystynkcy obywatelskiey Matrona           ADJ
# 446           Matrona            obywatelskiey Matrona –          NOUN
# 447               był                          Dom był w           AUX
# 448             całem                  w całem Sanockiem           ADJ
# 449              jako                  domowych jako też           ADV
# 450               owe                       na owe czasy           DET
# 451          wzorowem                   czasy wzorowem .           ADJ
# 452           niebyło                   A niebyło prawie          VERB
# 453         Sanockiem                  w Sanockiem który           ADJ
# 454               czy                   bliżej czy dalej          PART
# 455            niebył           dalej niebył skoligacony           AUX
# 456       skoligacony               niebył skoligacony z           ADJ
# 457     Ostaszewskich        Kazimierzów Ostaszewskich .         PROPN
# 458              Była                         . Była też          VERB
# 459             Matka        pomieszkanie Matka Kraińska          NOUN
# 460                 A                            . A gdy         CCONJ
# 461     Ostaszewskiej              Pani Ostaszewskiej do         PROPN
# 462               jey                      50 jey wnuków           DET
# 463              tego                         Do tego to           DET
# 464                to                       tego to domu          PART
# 465               móy              przyjechał móy Oyciec           DET
# 466            Oyciec                      móy Oyciec do          NOUN
# 467            Swojey                    do Swojey Frani           DET
# 468               móy                Oyciec móy wystąpił           DET
# 469               owe                       na owe czasy           DET
# 470          gniadych                rosłych gniadych ze           ADJ
# 471   Simiginowskiego     stada Simiginowskiego wartości           ADJ
# 472             Czyli                         . Czyli na         CCONJ
# 473               owe                       na owe czasy           DET
# 474                fl                           120 fl .             X
# 475                to                       Była to cena          PRON
# 476     Kopestyńskich      Komornikostwa Kopestyńskich –         PROPN
# 477        kochającey             grona kochającey Matkę           ADJ
# 478              lubo                     a lubo okolica         SCONJ
# 479                to                      , to niemogła          PART
# 480                Ją              Odwiedzali Ją Rodzice          PRON
# 481        Sanoczanie               Rodzice Sanoczanie ,         PROPN
# 482             niemi                z niemi nieodzownie          PRON
# 483            troski           nieodzownie troski obawy          NOUN
# 484            jedney                    z jedney strony           ADJ
# 485             Matkę                   końcu Matkę moją          NOUN
# 486              było                Dzieci było ośmioro           AUX
# 487             małem             umarła małem dzieckiem           ADJ
# 488              niey                  po niey przyszedł          PRON
# 489            Chrztu                 do Chrztu Świętego          NOUN
# 490        niechciały                chować niechciały –          VERB
# 491             ponim                         i ponim ja          PRON
# 492          nietylko         Ale nietylko niepowodzenie         CCONJ
# 493          troygiem            z troygiem naystarszych           NUM
# 494         pomarłemi         dziećmi pomarłemi okrywały           ADJ
# 495          okrywały          pomarłemi okrywały żałobą          VERB
# 496              były                         – były też          VERB
# 497              pono                ożenieniu pono 1815          PART
# 498            Oyciec              wyjechał Oyciec konno          NOUN
# 499   naypięknieyszey       wśród naypięknieyszey pogody           ADJ
# 500               ani                       – ani kropli          PART
# 501            świeci                   słońce świeci aż          VERB
# 502           Łomnicy                       na Łomnicy –         PROPN
# 503           Dniestr            trzeciey Dniestr sparty         PROPN
# 504        Łomnickiey                 wody Łomnickiey że           ADJ
# 505               nim                      że nim Oyciec         SCONJ
# 506            Oyciec                     nim Oyciec się          NOUN
# 507            szkoda               inwentarza szkoda na          NOUN
# 508               owe                       na owe czasy           DET
# 509        stanowiąca               majątku stanowiąca .           ADJ
# 510               owe                        w owe czasy           DET
# 511           fortuny                   , fortuny prędko          NOUN
# 512                 a                Zarszynie a chłopcy         CCONJ
# 513          egzamina                      ja egzamina w          NOUN
# 514               825                   urodzony 825 był           ADJ
# 515             febra                        – febra mię          NOUN
# 516               mię                  febra mię męczyła          PRON
# 517         niemogłem                    , niemogłem się          VERB
# 518               jey                     się jey pozbyć          PRON
# 519                to                          Już to od          PART
# 520                to                  urodzenia to jest          PRON
# 521              1821                     lipca 1821 był           ADJ
# 522               tak                   wątły tak dalece          PART
# 523          niemiano               że niemiano nadzieji          VERB
# 524            Troska                    . Troska obojga          NOUN
# 525            obojga                Troska obojga moich           NUM
# 526               mię                         o mię była          PRON
# 527               mię                     że mię kompano          PRON
# 528               mię                   odchuchano mię –          PRON
# 529           została                    – została tylko          VERB
# 530             tempy                      i tempy słuch           ADJ
# 531               mię                  odwiedzała mię co          PRON
# 532            kupsze                       jak kupsze .          NOUN
# 533             Biało                        . Biało się           ADV
# 534            dużemi             okryta dużemi koralami           ADJ
# 535             zawoy                  jak zawoy turecki          NOUN
# 536         wzorzysta                turecki wzorzysta .           ADJ
# 537               jak            młodzieniaszkiem jak po           ADV
# 538               tey                       od tey która          PRON
# 539              teme                      w teme słyszę           DET
# 540        niekontent                  się niekontent że           ADJ
# 541               mię                         że mię tak          PRON
# 542           poufale                      tak poufale w           ADV
# 543                to                         a to jakaś          PRON
# 544              było                    których było 30           AUX
# 545                 x                             30 x i             X
# 546                 6                           były 6 x           NUM
# 547                 x                              6 x i             X
# 548                 3                              i 3 x           NUM
# 549                 x                              3 x –             X
# 550              pono                 redukcyi pono 1811          PART
# 551              1811                        pono 1811 .           ADJ
# 552                 A                   – A niepoznajesz         CCONJ
# 553               mię                 niepoznajesz mię ,          PRON
# 554              taże                          , taże ja          PART
# 555              Więc                        ! Więc choć         CCONJ
# 556               czy                         em czy mię          PART
# 557               mię                        czy mię kto          PRON
# 558               one                        W one czasy           DET
# 559               tey                       na tey ulicy           DET
# 560              dużo                    ulicy dużo było           DET
# 561              hożą                       to hożą tęga           ADJ
# 562              tęga                hożą tęga średniego           ADJ
# 563           modrych             wzrostu modrych oczach           ADJ
# 564        ciemnoblnd           oczach ciemnoblnd włosów           ADJ
# 565         roumianey                o roumianey owalney           ADJ
# 566           owalney           roumianey owalney twarzy           ADJ
# 567           śniadey                     cery śniadey .           ADJ
# 568              Była                           . Była .          VERB
# 569        przystoyna          . przystoyna usposobienia           ADJ
# 570         jednająca      towarzyskiego jednająca sobie          VERB
# 571             mojey                matki mojey spotkał           DET
# 572             Panem                    z Panem Józefem          NOUN
# 573      naymłodszych                od naymłodszych lat           ADJ
# 574             Matkę                       moją Matkę –          NOUN
# 575               tak                        i tak gdzie           ADV
# 576               mię              spotkało mię uprzejme          PRON
# 577               tym                 Dzięki tym pięknym           DET
# 578          nietylko              zachowanie nietylko w          PART
# 579      Golejowskich            Julianów Golejowskich z         PROPN
# 580           nietyle                      ale nietyle z          PART
# 581             Panem                   z Panem Julianem          NOUN
# 582             Panią                       z Panią Różą          NOUN
# 583      Czarnomskich          z Czarnomskich Golejowską         PROPN
# 584        Golejowską       Czarnomskich Golejowską były         PROPN
# 585       naywiększey            w naywiększey przyjaźni           ADJ
# 586           odemnie                starszego odemnie i          PRON
# 587            swojey                 Ciotce swojey Pani           DET
# 588           późniey             umarł późniey bezżenny           ADV
# 589              swóy             majątek swóy Antoniemu           DET
# 590               ich                towarzystwo ich dla           DET
# 591            obadwa                dokazywali obadwa –           NUM
# 592              mało                 o mało nieprzyszło           ADV
# 593            Oyciec                       a Oyciec móy          NOUN
# 594               móy                   Oyciec móy objął           DET
# 595      Czortkowskim                   w Czortkowskim ,         PROPN
# 596              pono               brat pono stryjeczny          PART
# 597        skończoney              po skończoney żałobie           ADJ
# 598             wdowa                    prędko wdowa po          NOUN
# 599                Co                            . Co do           ADP
# 600           młodych   towarzystwa młodych Golejowskich           ADJ
# 601      Golejowskich             młodych Golejowskich –         PROPN
# 602              byli                     jakim byli śmy           AUX
# 603              Oyca                przez Oyca trzymani          NOUN
# 604            Kornel                       . Kornel był         PROPN
# 605        Szczęsnego      za Szczęsnego Koziobrodzkiego         PROPN
# 606              dziś                      po dziś dzień          NOUN
# 607       poczciwości           Jan poczciwości człowiek          NOUN
# 608               jak                     go jak jakiego           ADV
# 609              były                  domem były ciągłe          VERB
# 610           Luboscy                  Państwo Luboscy –         PROPN
# 611             jedną                 córkę jedną ułomną           NUM
# 612            ułomną                     jedną ułomną –           ADJ
# 613           milutka            Marynia milutka powiena           ADJ
# 614           powiena                  milutka powiena –           ADJ
# 615              pono            Martynowie pono Janiccy          PART
# 616                ci                     ale ci jakoteż          PRON
# 617           jakoteż                       ci jakoteż z         CCONJ
# 618          Woyniłów     należał Woyniłów Kopystyńskich         PROPN
# 619     Kopystyńskich           Woyniłów Kopystyńskich ,         PROPN
# 620          Żelibory           , Żelibory Kunaszowskich         PROPN
# 621     Kunaszowskich       Żelibory Kunaszowskich gdzie         PROPN
# 622            jednem                 która jednem okiem           ADJ
# 623              obie             nieszpetne obie wyszły           NUM
# 624               831                    powstaniu 831 –           ADJ
# 625               był                  drugi był późniey          VERB
# 626           późniey               był późniey sąsiadem           ADV
# 627               Ten                    . Ten niechciał          PRON
# 628               móy                      to móy Oyciec           DET
# 629            Oyciec               móy Oyciec zgorszony          NOUN
# 630             Panem        zgorszony Panem Władysławem          NOUN
# 631         niebędzie                 i niebędzie zawadą          VERB
# 632            zawadą                 niebędzie zawadą w          NOUN
# 633             mojeg            przemówienie mojeg Oyca           DET
# 634              Oyca                       mojeg Oyca –          NOUN
# 635            jestem                 kim jestem zbliżył          VERB
# 636              Oycu                     Twojemu Oycu .          NOUN
# 637            zżadka                     , zżadka bywał           ADV
# 638             bywał                     zżadka bywał u           AUX
# 639              byli              Bodzowcu byli Babiccy           AUX
# 640            Oyciec                         – Oyciec „          NOUN
# 641              były                        że były dwa          VERB
# 642            ormian                    samych ormian .         PROPN
# 643          niemogła               rozpoznać niemogła i          VERB
# 644              było                     Zabawne było z          VERB
# 645       najzabawney                    a najzabawney z           ADV
# 646            bawiła                 druga bawiła gości          VERB
# ...
# 45       PROPN
# 46         ADJ
# 47         ADP
# 48        NOUN
# 49         AUX
# 50        NOUN
# 51         ADJ
# 52         AUX
# 53         ADJ
# 54        VERB
# 55        PART
# 56       SCONJ
# 57         ADV
# 58       PROPN
# 59       PROPN
# 60        NOUN
# 61       PROPN
# 62        VERB
# 63         ADJ
# 64        NOUN
# 65         ADJ
# 66       PROPN
# 67         ADJ
# 68        NOUN
# 69       PROPN
# 70       PROPN
# 71         ADJ
# 72         AUX
# 73        NOUN
# 74        PRON
# 75       CCONJ
# 76       SCONJ
# 77       SCONJ
# 78         ADJ
# 79        PART
# 80       PROPN
# 81         ADV
# 82        NOUN
# 83        VERB
# 84         DET
# 85       PROPN
# 86        PRON
# 87         ADJ
# 88         ADJ
# 89        NOUN
# 90         ADJ
# 91         ADJ
# 92        NOUN
# 93         ADJ
# 94         ADJ
# 95       SCONJ
# 96       SCONJ
# 97        NOUN
# 98        VERB
# 99        NOUN
# 100      PROPN
# 101      PROPN
# 102          X
# 103        ADV
# 104        AUX
# 105        DET
# 106      PROPN
# 107        ADJ
# 108      PROPN
# 109       PART
# 110        NUM
# 111          X
# 112        AUX
# 113       VERB
# 114       NOUN
# 115       NOUN
# 116       NOUN
# 117        ADJ
# 118        ADJ
# 119      PROPN
# 120       NOUN
# 121       NOUN
# 122        ADP
# 123        AUX
# 124        DET
# 125        DET
# 126        DET
# 127       PRON
# 128        ADJ
# 129       PRON
# 130       NOUN
# 131        ADJ
# 132        DET
# 133        ADV
# 134       NOUN
# 135        AUX
# 136       PRON
# 137       NOUN
# 138       NOUN
# 139       VERB
# 140       PRON
# 141      PROPN
# 142        ADV
# 143        ADJ
# 144        AUX
# 145       NOUN
# 146       PART
# 147      PROPN
# 148      PROPN
# 149        ADV
# 150      PROPN
# 151      PROPN
# 152      PROPN
# 153       NOUN
# 154      PROPN
# 155        AUX
# 156        ADV
# 157      PROPN
# 158       PART
# 159       PART
# 160       NOUN
# 161       VERB
# 162      PROPN
# 163        ADJ
# 164        ADJ
# 165       PRON
# 166       NOUN
# 167        ADJ
# 168        ADV
# 169        ADJ
# 170       VERB
# 171       NOUN
# 172      PROPN
# 173      PROPN
# 174      PROPN
# 175      PROPN
# 176      PROPN
# 177      PROPN
# 178       VERB
# 179      PROPN
# 180       VERB
# 181       PRON
# 182          X
# 183        ADJ
# 184        ADJ
# 185       NOUN
# 186          X
# 187       NOUN
# 188       PRON
# 189          X
# 190       NOUN
# 191        ADJ
# 192        ADJ
# 193       PRON
# 194        AUX
# 195        ADV
# 196       NOUN
# 197      CCONJ
# 198        ADV
# 199      PROPN
# 200      PROPN
# 201        ADJ
# 202       VERB
# 203       PART
# 204      PROPN
# 205       PRON
# 206        ADJ
# 207       NOUN
# 208        ADJ
# 209        AUX
# 210        ADJ
# 211      CCONJ
# 212      PROPN
# 213       PART
# 214      SCONJ
# 215        ADJ
# 216      PROPN
# 217       VERB
# 218       NOUN
# 219       NOUN
# 220       NOUN
# 221       NOUN
# 222      PROPN
# 223      PROPN
# 224        ADJ
# 225      PROPN
# 226       VERB
# 227          X
# 228          X
# 229       NOUN
# 230      PROPN
# 231      PROPN
# 232      PROPN
# 233        ADJ
# 234      PROPN
# 235      PROPN
# 236        DET
# 237          X
# 238       VERB
# 239       NOUN
# 240        ADJ
# 241        ADJ
# 242      PROPN
# 243      PROPN
# 244        ADJ
# 245      PROPN
# 246        ADP
# 247       VERB
# 248       NOUN
# 249        ADJ
# 250       NOUN
# 251        AUX
# 252       NOUN
# 253        DET
# 254       NOUN
# 255        ADV
# 256       VERB
# 257       NOUN
# 258        ADJ
# 259       PART
# 260        ADJ
# 261      PROPN
# 262       NOUN
# 263        ADJ
# 264      PROPN
# 265        ADJ
# 266        ADJ
# 267       NOUN
# 268        ADJ
# 269       NOUN
# 270       NOUN
# 271        ADJ
# 272      PROPN
# 273      PROPN
# 274        ADJ
# 275       NOUN
# 276       PART
# 277       NOUN
# 278       NOUN
# 279       VERB
# 280      PROPN
# 281       NOUN
# 282      PROPN
# 283        ADV
# 284       NOUN
# 285      PROPN
# 286       VERB
# 287       PRON
# 288       PART
# 289       PRON
# 290        AUX
# 291        ADJ
# 292       NOUN
# 293       PART
# 294        NUM
# 295       NOUN
# 296       VERB
# 297      PROPN
# 298        ADV
# 299       VERB
# 300       NOUN
# 301        ADJ
# 302      PROPN
# 303        ADV
# 304        ADJ
# 305       NOUN
# 306      PROPN
# 307        ADJ
# 308      PROPN
# 309      PROPN
# 310      PROPN
# 311        ADJ
# 312      PROPN
# 313      PROPN
# 314      PROPN
# 315      PROPN
# 316        ADJ
# 317      PROPN
# 318      PROPN
# 319        ADJ
# 320       INTJ
# 321      PROPN
# 322        ADJ
# 323       NOUN
# 324       NOUN
# 325        AUX
# 326        ADJ
# 327       NOUN
# 328      SCONJ
# 329       NOUN
# 330       NOUN
# 331       NOUN
# 332       NOUN
# 333       VERB
# 334        ADJ
# 335       NOUN
# 336        ADJ
# 337      PROPN
# 338       NOUN
# 339       NOUN
# 340      SCONJ
# 341      PROPN
# 342      PROPN
# 343        ADV
# 344        ADJ
# 345       NOUN
# 346       NOUN
# 347      PROPN
# 348        ADJ
# 349      SCONJ
# 350      PROPN
# 351        DET
# 352       NOUN
# 353        ADV
# 354      SCONJ
# 355       PART
# 356       VERB
# 357        ADJ
# 358       NOUN
# 359        ADJ
# 360       NOUN
# 361       NOUN
# 362       VERB
# 363       NOUN
# 364        ADJ
# 365      PROPN
# 366       NOUN
# 367        ADJ
# 368       NOUN
# 369       VERB
# 370       NOUN
# 371       NOUN
# 372       NOUN
# 373       NOUN
# 374        ADJ
# 375        ADV
# 376          X
# 377        ADV
# 378       NOUN
# 379       NOUN
# 380       VERB
# 381      SCONJ
# 382        AUX
# 383      PROPN
# 384        AUX
# 385      PROPN
# 386        AUX
# 387       NOUN
# 388      CCONJ
# 389        ADV
# 390        ADP
# 391      CCONJ
# 392       NOUN
# 393      PROPN
# 394        ADJ
# 395      SCONJ
# 396        ADV
# 397        ADV
# 398       NOUN
# 399        ADJ
# 400       NOUN
# 401        AUX
# 402       VERB
# 403        ADJ
# 404       PART
# 405        AUX
# 406        AUX
# 407       VERB
# 408       NOUN
# 409      CCONJ
# 410      PROPN
# 411        ADJ
# 412       PART
# 413       PART
# 414       NOUN
# 415        ADJ
# 416       NOUN
# 417       NOUN
# 418       VERB
# 419       PRON
# 420        AUX
# 421       PRON
# 422       NOUN
# 423      PROPN
# 424       VERB
# 425        AUX
# 426        ADV
# 427       VERB
# 428        ADJ
# 429      CCONJ
# 430        ADJ
# 431        ADV
# 432        ADJ
# 433       NOUN
# 434          X
# 435       NOUN
# 436       PRON
# 437       NOUN
# 438        ADV
# 439        ADV
# 440       NOUN
# 441        ADJ
# 442       NOUN
# 443       NOUN
# 444       NOUN
# 445       NOUN
# 446      PROPN
# 447       VERB
# 448       NOUN
# 449      SCONJ
# 450        ADJ
# 451       NOUN
# 452        ADV
# 453      PROPN
# 454      CCONJ
# 455       VERB
# 456       NOUN
# 457        ADJ
# 458        AUX
# 459      PROPN
# 460       PART
# 461        ADJ
# 462       NOUN
# 463       PRON
# 464        AUX
# 465        ADJ
# 466      PROPN
# 467      PROPN
# 468        ADJ
# 469        ADJ
# 470       NOUN
# 471      PROPN
# 472       VERB
# 473        ADJ
# 474       NOUN
# 475        AUX
# 476        ADJ
# 477       NOUN
# 478      CCONJ
# 479      SCONJ
# 480        ADJ
# 481       NOUN
# 482       NOUN
# 483        ADJ
# 484       NOUN
# 485      PROPN
# 486       VERB
# 487       NOUN
# 488        ADJ
# 489      PROPN
# 490       NOUN
# 491       PART
# 492        ADV
# 493       NOUN
# 494       VERB
# 495        ADJ
# 496        AUX
# 497       VERB
# 498      PROPN
# 499       NOUN
# 500      CCONJ
# 501       NOUN
# 502       NOUN
# 503       NOUN
# 504      PROPN
# 505       PRON
# 506       VERB
# 507       VERB
# 508        ADJ
# 509       NOUN
# 510        ADJ
# 511        ADJ
# 512       PART
# 513       VERB
# 514          X
# 515       VERB
# 516       NOUN
# 517        ADV
# 518       PART
# 519       PRON
# 520        AUX
# 521          X
# 522        ADV
# 523        ADP
# 524        ADJ
# 525       NOUN
# 526       NOUN
# 527       NOUN
# 528       NOUN
# 529        AUX
# 530       NOUN
# 531       NOUN
# 532       VERB
# 533       VERB
# 534       NOUN
# 535        ADJ
# 536       NOUN
# 537      SCONJ
# 538       NOUN
# 539       NOUN
# 540       NOUN
# 541       NOUN
# 542       VERB
# 543       PART
# 544       VERB
# 545       NOUN
# 546        ADJ
# 547       NOUN
# 548        ADJ
# 549       NOUN
# 550       VERB
# 551          X
# 552       PART
# 553       NOUN
# 554      SCONJ
# 555      SCONJ
# 556      CCONJ
# 557       NOUN
# 558       PRON
# 559       NOUN
# 560        ADV
# 561       NOUN
# 562       NOUN
# 563       NOUN
# 564      CCONJ
# 565       NOUN
# 566       NOUN
# 567       NOUN
# 568        AUX
# 569       NOUN
# 570        ADJ
# 571       NOUN
# 572      PROPN
# 573       NOUN
# 574      PROPN
# 575       PART
# 576       NOUN
# 577       PRON
# 578        ADV
# 579        ADJ
# 580        ADV
# 581      PROPN
# 582        ADJ
# 583        ADJ
# 584        ADJ
# 585       NOUN
# 586        ADV
# 587       NOUN
# 588       NOUN
# 589        ADJ
# 590       PRON
# 591       NOUN
# 592        DET
# 593      PROPN
# 594        ADJ
# 595        ADJ
# 596       VERB
# 597       NOUN
# 598       VERB
# 599       PART
# 600       NOUN
# 601        ADJ
# 602       VERB
# 603      PROPN
# 604       NOUN
# 605        ADJ
# 606        ADV
# 607       VERB
# 608      SCONJ
# 609        AUX
# 610        ADJ
# 611        ADJ
# 612       VERB
# 613       NOUN
# 614       NOUN
# 615       VERB
# 616        DET
# 617        DET
# 618       NOUN
# 619        ADJ
# 620      SCONJ
# 621        ADJ
# 622       NOUN
# 623       NOUN
# 624          X
# 625        AUX
# 626        ADJ
# 627        DET
# 628        ADJ
# 629      PROPN
# 630      PROPN
# 631        ADV
# 632       VERB
# 633          X
# 634      PROPN
# 635        AUX
# 636      PROPN
# 637       NOUN
# 638       VERB
# 639       VERB
# 640      PROPN
# 641        AUX
# 642       NOUN
# 643        ADV
# 644        AUX
# 645       NOUN
# 646       NOUN
# 647       NOUN
# 648       NOUN
# 649        ADV
# 650       PART
# 651       PRON
# 652       PART
# 653      PROPN
# 654       VERB
# 655      PROPN
# 656       NOUN
# 657       NOUN
# 658        AUX
# 659      SCONJ
# 660        ADJ
# 661        ADJ
# 662      PROPN
# 663      PROPN
# 664      PROPN
# 665       PART
# 666       NOUN
# 667        ADJ
# 668        ADV
# 669      SCONJ
# 670       NOUN
# 671       NOUN
# 672       NOUN
# 673       VERB
# 674       NOUN
# 675        ADJ
# 676        ADJ
# 677       PRON
# 678       VERB
# 679       NOUN
# 680      PROPN
# 681        ADJ
# 682        ADJ
# 683      PROPN
# 684      PROPN
# 685       NOUN
# 686        ADJ
# 687       NOUN
# 688       PRON
# 689        ADJ
# 690        ADJ
# 691        ADJ
# 692       NOUN
# 693       NOUN
# 694       NOUN
# 695       PRON
# 696       NOUN
# 697       NOUN
# 698       NOUN
# 699       NOUN
# 700        ADJ
# 701      PROPN
# 702       NOUN
# 703       PRON
# 704       PRON
# 705        ADJ
# 706       NOUN
# 707        ADJ
# 708        ADJ
# 709       VERB
# 710       NOUN
# 711       VERB
# 712       PRON
# 713       NOUN
# 714       NOUN
# 715      PROPN
# 716       VERB
# 717          X
# 718      PROPN
# 719       NOUN
# 720        ADJ
# 721       VERB
# 722       PRON
# 723      PROPN
# 724       NOUN
# 725       PRON
# 726       VERB
# 727       NOUN
# 728        ADJ
# 729      PROPN
# 730        ADP
# 731       NOUN
# 732      PROPN
# 733       NOUN
# 734       NOUN
# 735       VERB
# 736       NOUN
# 737        DET
# 738        ADJ
# 739       NOUN
# 740       NOUN
# 741      CCONJ
# 742        ADJ
# 743       NOUN
# 744       NOUN
# 745      PROPN
# 746        ADJ
# 747        ADJ
# 748        AUX
# 749      PROPN
# 750      PROPN
# 751        ADJ
# 752       NOUN
# 753      PROPN
# 754       NOUN
# 755        ADJ
# 756      SCONJ
# 757       NOUN
# 758        ADJ
# 759      SCONJ
# 760       VERB
# 761      PROPN
# 762       VERB
# 763        ADJ
# 764       NOUN
# 765       NOUN
# 766       NOUN
# 767       NOUN
# 768       NOUN
# 769       NOUN
# 770       VERB
# 771       VERB
# 772        ADJ
# 773       NOUN
# 774        ADJ
# 775      SCONJ
# 776       VERB
# 777       NOUN
# 778        ADJ
# 779        ADJ
# 780       VERB
# 781       VERB
# 782        ADJ
# 783       NOUN
# 784        ADJ
# 785        ADV
# 786        ADV
# 787        ADJ
# 788      SCONJ
# 789       NOUN
# 790       NOUN
# 791       NOUN
# 792      PROPN
# 793       PART
# 794      SCONJ
# 795       VERB
# 796       PRON
# 797          X
# 798       NOUN
# 799       NOUN
# 800        ADJ
# 801       NOUN
# 802      PROPN
# 803       PART
# 804       PART
# 805       VERB
# 806       NOUN
# 807        ADV
# 808      PROPN
# 809      CCONJ
# 810       NOUN
# 811       NOUN
# 812       NOUN
# 813       NOUN
# 814       NOUN
# 815       PRON
# 816       NOUN
# 817        ADJ
# 818       NOUN
# 819      PROPN
# 820       PRON
# 821       NOUN
# 822       VERB
# 823       VERB
# 824       VERB
# 825       VERB
# 826        DET
# 827       VERB
# 828       NOUN
# 829      PROPN
# 830        ADJ
# 831       NOUN
# 832        ADJ
# 833      PROPN
# 834      PROPN
# 835       NOUN
# 836       NOUN
# 837        ADJ
# 838      PROPN
# 839        ADJ
# 840        ADV
# 841        ADJ
# 842       VERB
# 843       NOUN
# 844       NOUN
# 845       NOUN
# 846       VERB
# 847        ADJ
# 848       NOUN
# 849        ADJ
# 850       PART
# 851       PART
# 852        ADJ
# 853          X
# 854       PRON
# 855      PROPN
# 856      PROPN
# 857       VERB
# 858      PROPN
# 859        AUX
# 860       NOUN
# 861        ADJ
# 862        ADJ
# 863      PROPN
# 864       PRON
# 865       VERB
# 866       NOUN
# 867        AUX
# 868       VERB
# 869        ADJ
# 870      PROPN
# 871       NOUN
# 872       NOUN
# 873        ADJ
# 874       NOUN
# 875       NOUN
# 876          X
# 877       PART
# 878      PROPN
# 879        ADJ
# 880      PROPN
# 881      PROPN
# 882       NOUN
# 883       NOUN
# 884       NOUN
# 885      SCONJ
# 886      PROPN
# 887      PROPN
# 888      PROPN
# 889       NOUN
# 890      PROPN
# 891       NOUN
# 892          X
# 893       NOUN
# 894       VERB
# 895       PART
# 896       PART
# 897       PRON
# 898        ADJ
# 899        ADJ
# 900      PROPN
# 901        ADJ
# 902      PROPN
# 903        ADJ
# 904       VERB
# 905        AUX
# 906       PRON
# 907        ADJ
# 908       NOUN
# 909      PROPN
# 910       VERB
# 911       NOUN
# 912        ADJ
# 913       VERB
# 914       VERB
# 915        ADJ
# 916        ADJ
# 917      PROPN
# 918       NOUN
# 919       NOUN
# 920       VERB
# 921      SCONJ
# 922       NOUN
# 923       NOUN
# 924       VERB
# 925       NOUN
# 926       NOUN
# 927        DET
# 928       PART
# 929       PRON
# 930        ADJ
# 931        ADJ
# 932       VERB
# 933       NOUN
# 934       PRON
# 935        ADV
# 936       PART
# 937       NOUN
# 938        ADJ
# 939        AUX
# 940        ADJ
# 941       NOUN
# 942      PROPN
# 943      SCONJ
# 944      PROPN
# 945        AUX
# 946          X
# 947       VERB
# 948       NOUN
# 949       PART
# 950      PROPN
# 951        ADJ
# 952       NOUN
# 953       PART
# 954       PART
# 955        ADJ
# 956        ADJ
# 957       NOUN
# 958       NOUN
# 959        ADJ
# 960      PROPN
# 961      CCONJ
# 962       NOUN
# 963       NOUN
# 964        ADJ
# 965      PROPN
# 966       NOUN
# 967        ADJ
# 968       NOUN
# 969       NOUN
# 970       NOUN
# 971      PROPN
# 972      PROPN
# 973      PROPN
# 974      PROPN
# 975        AUX
# 976        AUX
# 977        AUX
# 978       VERB
# 979       NOUN
# 980      PROPN
# 981        ADV
# 982       NOUN
# 983        ADV
# 984      PROPN
# 985       VERB

# %%
comparison_xpos
# Out:
#                 Token                             Context  \
# 0               Dziad                           Dziad mój
# 1                 mój                  Dziad mój Melchior
# 2            Melchior               mój Melchior urodzony
# 3            urodzony              Melchior urodzony roku
# 4          Godziszewo              wsi Godziszewo parafii
# 5             parafii           Godziszewo parafii Rypnin
# 6              Rypnin                  parafii Rypnin syn
# 7            starszym                 był starszym bratem
# 8              bratem                   starszym bratem ś
# 9                   ś                          bratem ś .
# 10                  p                               . p .
# 11              matki                         i matki Ewy
# 12         Pinińskich            z Pinińskich właścicieli
# 13               Dóbr           właścicieli Dóbr Strużewo
# 14           Strużewo                     Dóbr Strużewo z
# 15            Dąbrowy                    , Dąbrowy części
# 16                 śp                         że śp Dziad
# 17              Dziad                        śp Dziad mój
# 18                mój                       Dziad mój był
# 19                był                  mój był najmłodszy
# 20           pomiędzy               z pomiędzy Rodzeństwa
# 21       najstarszemu            część najstarszemu bratu
# 22              bratu          najstarszemu bratu swojemu
# 23                ośm                      za ośm tysięcy
# 24             tynfów                    tysięcy tynfów .
# 25            Stryjów                      . Stryjów miał
# 26               miał                     Stryjów miał śp
# 27                 śp                           miał śp .
# 28           Melchior                 . Melchior czterech
# 29           czterech                 Melchior czterech i
# 30         ożenionego              Wawrzyńca ożenionego z
# 31             trzech                   niej trzech synów
# 32              synów                 trzech synów Jakuba
# 33             Jakuba                      synów Jakuba ,
# 34            Łukasza                         , Łukasza i
# 35           Floyrana                        i Floyrana .
# 36               syna                  mieli syna Ludwika
# 37            Ludwika                      syna Ludwika –
# 38         wszystkich                  – wszystkich braci
# 39              braci       wszystkich braci stryjecznych
# 40       stryjecznych               braci stryjecznych śp
# 41                 17                           było 17 .
# 42           Antonich                     . Antonich było
# 43               brat                     dwóch brat Jana
# 44          Melchiora                    brat Melchiora .
# 45            Niewiem                         . Niewiem o
# 46              stryj                   a stryj Melchiora
# 47        zaopiekował           Melchiora zaopiekował się
# 48   młodzieniaszkiem              się młodzieniaszkiem i
# 49         wychowanie                    na wychowanie po
# 50              jakim               ale jakim niepamiętam
# 51          Potockich                   Domem Potockich ,
# 52            Brzeżan                Dziedziców Brzeżan i
# 53            Skolego                         i Skolego w
# 54               Pana             odwiedzał Pana Starostę
# 55           Starostę                     Pana Starostę ,
# 56         chłopczyna                 był chłopczyna więc
# 57                 co                       Potocki co to
# 58                 go                       chce go wziąć
# 59             rychło                  natury rychło ujął
# 60               Pana               sobie Pana Potockiego
# 61         Potockiego                   Pana Potockiego ,
# 62                tak                         i tak umiał
# 63           Brzeżany                   swoich Brzeżany i
# 64            Skolego                     i Skolego wziął
# 65                 go                      wziął go sobie
# 66            Skolego                do Skolego przekonał
# 67            intraty                    czynią intraty –
# 68               Myśl                          . Myśl się
# 69           podobała                   się podobała Panu
# 70         Szczęśliwa                   . Szczęśliwa była
# 71               jego                  przyszłości jego .
# 72             okazał                     jaki okazał mój
# 73                mój                    okazał mój Dziad
# 74              Dziad                      mój Dziad Panu
# 75             piękny                      czasy piękny –
# 76              ujęty                        że ujęty tem
# 77                tem              ujęty tem zaproponował
# 78                 to                        mogło to być
# 79           Czołhany                dzierżawę Czołhany w
# 80           Halickim                        w Halickim ,
# 81           Kobylską                    Panną Kobylską ,
# 82             trzech                    nią trzech synów
# 83              synów                trzech synów Michała
# 84            Michała                     synów Michała ,
# 85             Józefa                          , Józefa i
# 86         Kazimierza                      i Kazimierza –
# 87           owdowiał                 niebawem owdowiał .
# 88             wołami                         za wołami .
# 89        Chyrowskiey      Posadzie Chyrowskiey zapędziły
# 90          zapędziły           Chyrowskiey zapędziły się
# 91               woły                          się woły w
# 92               parę                        i parę sztuk
# 93           Dzianott                 domu Dzianott wdowa
# 94              wdowa                   Dzianott wdowa po
# 95              dwóch                     po dwóch mężach
# 96             mężach                      dwóch mężach –
# 97                 by                   dworu by zapłacić
# 98      wynagrodzeniu                 o wynagrodzeniu nie
# 99             starym                      z starym winem
# 100             winem                      starym winem –
# 101              rada                         – rada była
# 102          gosposia              była gosposia gościowi
# 103          gościowi                 gosposia gościowi a
# 104               oko                             w oko –
# 105          Asińdźka                   wiesz Asińdźka co
# 106                co                       Asińdźka co ?
# 107             wdowa                      Jesteś wdowa –
# 108           wdowiec                        ja wdowiec –
# 109                Ja                            „ Ja już
# 110                że                           ale że mi
# 111                mi                           że mi się
# 112          Waszmość                się Waszmość podobał
# 113           podobał                 Waszmość podobał eś
# 114          ucałował                   , ucałował rączkę
# 115            Pannie                   wstąpi Pannie się
# 116              dwie                     były dwie córki
# 117             córki                        dwie córki i
# 118            Starsi                     . Starsi bracia
# 119            mojego                  bracia mojego Ojca
# 120              Ojca            mojego Ojca pokończywszy
# 121             nauki          pokończywszy nauki osiedli
# 122           osiedli                    nauki osiedli na
# 123             córki                           a córki w
# 124              pono                        która pono w
# 125            bawiły                        , bawiły pod
# 126      Czermińskiej          starościny Czermińskiej we
# 127               mąż                        za mąż jedna
# 128      szambelanica                    – szambelanica ,
# 129             druga                          , druga za
# 130     Świeżawskiego          za Świeżawskiego komornika
# 131         komornika  Świeżawskiego komornika ziemskiego
# 132        ziemskiego              komornika ziemskiego i
# 133               był             Tretera był szambelanem
# 134       szambelanem                  był szambelanem za
# 135                za                 szambelanem za Stan
# 136            wielki                    – wielki literat
# 137           literat                    wielki literat .
# 138             oddał                 swój oddał akademii
# 139          akademii                   oddał akademii we
# 140             Abbum          drzwiami Abbum Treterianum
# 141       Treterianum                 Abbum Treterianum .
# 142             Lwowa            bombardowaniu Lwowa roku
# 143              więc                            – więc i
# 144            zbiory                         i zbiory te
# 145                te                zbiory te zniszczały
# 146        zniszczały                     te zniszczały .
# 147               Syn                          . Syn jego
# 148               mój                           a mój wuj
# 149               wuj                         mój wuj był
# 150               był                          wuj był to
# 151          fantasta                       to fantasta –
# 152          oryginał                   – oryginał jakich
# 153            jakich                oryginał jakich dziś
# 154                 i                             bo i po
# 155          polskich                        . polskich w
# 156          wielkimi        plenipotent wielkimi dobrami
# 157           dobrami                  wielkimi dobrami ,
# 158        dzierżawił                     to dzierżawił –
# 159                po                jeździł po znajomych
# 160         znajomych                      po znajomych i
# 161             różne              wyśpiewywał różne arye
# 162              arye               różne arye krakowiaki
# 163        krakowiaki                   arye krakowiaki i
# 164         kołomyjki                       i kołomyjki .
# 165                na                    jeździł na koniu
# 166         znajomych                      po znajomych a
# 167           śpiewem                       ze śpiewem na
# 168            mojego                    domu mojego Oyca
# 169              Oyca                       mojego Oyca –
# 170              dużo                niej dużo szczegółów
# 171              Oyca                    familii Oyca się
# 172        Opowiadano                     . Opowiadano mi
# 173             moich              pożycia moich wujostwa
# 174         oświecony                katafalk oświecony a
# 175             Zaraz                          . Zaraz na
# 176               jej            opowiedziała jej czeladź
# 177           czeladź                       jej czeladź ,
# 178      nieboszczyka               żałuje nieboszczyka -
# 179      nieboszczyka           do nieboszczyka przemawia
# 180              Tobą                       z Tobą Stasiu
# 181            Stasiu                    Tobą Stasiu tyle
# 182              tyle                       Stasiu tyle a
# 183        Zostawiasz                    ! Zostawiasz mię
# 184               mię                    Zostawiasz mię z
# 185              kęsa                     ani kęsa chleba
# 186              zato                            – zato ,
# 187                Ci                        ażeby Ci Bóg
# 188      nieboszczyka              okładać nieboszczyka –
# 189               ich                obracają ich rodziny
# 190           rodziny                       ich rodziny .
# 191             Drugi                         . Drugi mój
# 192               mój                       Drugi mój wuj
# 193               wuj                 mój wuj Świerzawski
# 194       Świerzawski               wuj Świerzawski kuzyn
# 195             kuzyn      Świerzawski kuzyn Polanowskich
# 196      Polanowskich                kuzyn Polanowskich z
# 197         Bełzkiego                  z Bełzkiego często
# 198               Pań                     od Pań oblegany
# 199          oblegany                      Pań oblegany –
# 200         strojeniu                    na strojeniu się
# 201         trefieniu                       i trefieniu a
# 202           służąca                musiała służąca całą
# 203              stać                       drogę stać na
# 204         stopniach                 na stopniach powozu
# 205      Komornikowej        Pani Komornikowej niepomięła
# 206             nauki                pokończyli nauki ale
# 207           Niewiem                     . Niewiem jakim
# 208         zniszczał                 majątek zniszczał –
# 209        Treterówną                siostrą Treterówną -
# 210          nierobił                   wstydu nierobił .
# 211        Treterówną                siostrą Treterówną –
# 212        napastował             dziwak napastował ludzi
# 213               nim                         się nim Pan
# 214          nierobił                   wstydu nierobił .
# 215               móy                  Ojciec móy sierota
# 216            oddany                   sierota oddany do
# 217        podpodczas                  – podpodczas wojen
# 218           Sachsen                   do Sachsen Cobary
# 219            Cobary               Sachsen Cobary Ułanów
# 220                14                            lat 14 .
# 221                 ś                              mi ś .
# 222             Oycem                          z Oycem na
# 223  Młodzieniaszkiem           . Młodzieniaszkiem oddany
# 224            oddany          Młodzieniaszkiem oddany do
# 225                 w                spacery w sąsiedztwa
# 226        sąsiedztwa                      w sąsiedztwa ,
# 227         najwięcej                   a najwięcej czasu
# 228           podróże                     czasu podróże i
# 229         Zarszynie                       w Zarszynie i
# 230         zakończył               wojskową zakończył śp
# 231             około                   Oyciec około 1808
# 232              1808                        około 1808 –
# 233              1809                         albo 1809 –
# 234             kończ                      do kończ życia
# 235             wielu                    we wielu bitwach
# 236           bitwach                     wielu bitwach –
# 237             Iglan                       pod Iglan był
# 238               pod                        a pod Wagram
# 239            Wagram                   pod Wagram stojąc
# 240             armat           assekuracyi armat utracił
# 241      kontuzjowany              sam kontuzjowany leżał
# 242           nieżywy                       jak nieżywy –
# 243            pieszy               pułk pieszy Francuzów
# 244         Francuzów     pieszy Francuzów przemaszerował
# 245    przemaszerował         Francuzów przemaszerował po
# 246               nim                            po nim ,
# 247          zwinięty          płaszcz zwinięty obwiązany
# 248         obwiązany            zwinięty obwiązany przez
# 249             plecy                           i plecy ,
# 250              małe                  tylko małe ukłucia
# 251           ukłucia              małe ukłucia dostawały
# 252         dostawały               ukłucia dostawały się
# 253         skrzętnem     fortuny skrzętnem gospodarstwem
# 254              wieś            własność wieś Siemiginów
# 255        Siemiginów                   wieś Siemiginów w
# 256               tem                          po tem jak
# 257         powiadano                    jak powiadano za
# 258            indyki                   za indyki których
# 259           których                   indyki których po
# 260             Lwowa                          do Lwowa w
# 261          Bludniki                   kupił Bludniki za
# 262             które                   za które wyliczył
# 263              Pani         wyliczył Pani Rozwadowskiej
# 264     Rozwadowskiej            Pani Rozwadowskiej 10000
# 265             10000         Rozwadowskiej 10000 dukatów
# 266           dukatów                     10000 dukatów .
# 267              2000              brakowało 2000 dukatów
# 268           dukatów          2000 dukatów pełnłnomocnik
# 269     Rozwadowskiej              Pani Rozwadowskiej nie
# 270          zmieniał               właściciel zmieniał –
# 271            wójtem                         z wójtem na
# 272                 w                   sposób w fizyczne
# 273                we              fizyczne we posiadanie
# 274           osypami   pańszczyźnianymi osypami daninami
# 275          daninami                 osypami daninami od
# 276           któremi               nad któremi obeymował
# 277         obeymował       któremi obeymował Dziedzictwo
# 278       juryzdyksye           prawną juryzdyksye sądową
# 279         pierwszey     policyjną pierwszey instantacyi
# 280               Zaś                        . Zaś daniny
# 281            daniny                        Zaś daniny w
# 282           robocie                  w robocie odbywali
# 283       posiadanych           ilości posiadanych morgów
# 284            bydłem                       dni bydłem co
# 285              tego                       Oprócz tego z
# 286              owsa                        ilość owsa –
# 287                ci                           tego ci i
# 288             zwane                    tak zwane spaśne
# 289            spaśne                      zwane spaśne -
# 290              kury                      - kury kapłony
# 291           kapłony                 kury kapłony kaczki
# 292            kaczki                    kapłony kaczki i
# 293              gęsi                            i gęsi ,
# 294              jaja                            , jaja –
# 295         pastwiska                   oni pastwiska dla
# 296         pastwisko                 - pastwisko ratował
# 297           biedzie                    w biedzie zbożem
# 298            zbożem                    biedzie zbożem a
# 299       inwentarzem                 nawet inwentarzem .
# 300            Wieleż                         . Wieleż to
# 301                to                      Wieleż to razy
# 302           Dziadka             . Dziadka Ostaszewskigo
# 303     Ostaszewskigo           Dziadka Ostaszewskigo jak
# 304           kmiecie                     jego kmiecie na
# 305         najlepsze               Długim najlepsze mają
# 306             bydle                 padło bydle robocze
# 307           robocze                     bydle robocze –
# 308            żalili                 Dłużanie żalili się
# 309              koni                          dla koni –
# 310          Oddzieli                       – Oddzieli śp
# 311            suchey                  morgów suchey łąki
# 312        podedworem                   łąki podedworem a
# 313      nayskładniey             a nayskładniey położone
# 314            kmieci                        dla kmieci ,
# 315            Niebył                         . Niebył to
# 316                to                 Niebył to obowiązek
# 317         obowiązek              to obowiązek spełniony
# 318         spełniony             obowiązek spełniony ale
# 319             napar                wyszynku napar prawo
# 320             prawo                napar prawo warżenia
# 321          warżenia                 prawo warżenia piwa
# 322             prawo               wódki prawo stawiania
# 323         polowania                      i polowania na
# 324          dworskim                    tak dworskim jak
# 325        gromadzkim                      i gromadzkim .
# 326           poddani                 - poddani uwolnieni
# 327         suszonych            wianki suszonych grzybów
# 328           miarkmi                    – miarkmi wianki
# 329            wianki              miarkmi wianki powinny
# 330           powinny                 wianki powinny były
# 331              były                powinny były mierzyć
# 332                to                           , to jest
# 333         dziesiąty                jest dziesiąty pniak
# 334             pniak                  dziesiąty pniak do
# 335            takiem              przy takiem obciążeniu
# 336             chłop                         – chłop był
# 337               był                    chłop był biedny
# 338            biedny                        był biedny -
# 339               tak                    jednakże tak nie
# 340           majątki                      – majątki były
# 341              były              majątki były wyłącznie
# 342               był                jurysdykcyi był Herb
# 343              Herb                  był Herb Dziedzica
# 344         Dziedzica                    Herb Dziedzica –
# 345          Dominium             napis Dominium Bludniki
# 346          Bludniki                 Dominium Bludniki –
# 347           Zarszyn                         – Zarszyn –
# 348                na               postanawiał na swojem
# 349            swojem                   na swojem mieycus
# 350           mieycus        swojem mieycus Mandatariusza
# 351     Mandatariusza             mieycus Mandatariusza -
# 352           rekruta                  wybierał rekruta i
# 353         urzędował                       , urzędował –
# 354          niemogło                      – niemogło się
# 355           dopokąd                         – dopokąd z
# 356      nieprzyniósł         Dominii nieprzyniósł kartki
# 357            kartki      nieprzyniósł kartki pozwolenia
# 358                 A                         . A chociaż
# 359           chociaż                         A chociaż i
# 360             mogły                        tu mogły się
# 361         nadużycia                   dziać nadużycia –
# 362             mogły                         – mogły one
# 363               one                       mogły one być
# 364         wyjątkowe                     być wyjątkowe ,
# 365             dbano                        czas dbano o
# 366         szlachcic                  Podola szlachcic w
# 367                 w                szlachcic w Sanockie
# 368          Sanockie                        w Sanockie –
# 369         poddanych              zdzierstwa poddanych –
# 370              tego                       Pana tego nie
# 371         obsadzane               części obsadzane były
# 372              były             obsadzane były szlachtą
# 373         cząstkową                       – cząstkową –
# 374         czynszową                       – czynszową –
# 375          ludowemi               dziś ludowemi zwanych
# 376             lizną                 czasem lizną trochę
# 377            trochę                 lizną trochę łaciny
# 378            łaciny                     trochę łaciny w
# 379             prawa                      trochę prawa –
# 380       manipulacyi             – manipulacyi urzędowey
# 381         urzędowey             manipulacyi urzędowey –
# 382           Cyrkule                         w Cyrkule i
# 383      Mandatyrusza           . Mandatyrusza przyjmował
# 384        przyjmował    Mandatyrusza przyjmował Dziedzic
# 385          Dziedzic              przyjmował Dziedzic na
# 386          depozyta            i depozyta starościńskie
# 387     starościńskie            depozyta starościńskie .
# 388         Dziedzica                 od Dziedzica pensyę
# 389               120                           od 120 do
# 390               200                            do 200 –
# 391               300                            – 300 fl
# 392                20                            fl 20 do
# 393         ordynaryi                   korcy ordynaryi –
# 394      pomieszkanie                 , pomieszkanie opał
# 395              opał                 pomieszkanie opał –
# 396         pastwisko                       – pastwisko –
# 397             jakim                  w jakim zastępował
# 398        zastępował          jakim zastępował Dziedzica
# 399         Dziedzica              zastępował Dziedzica .
# 400         szczupłey               tak szczupłey dotacyi
# 401           dotacyi     szczupłey dotacyi uwzględniając
# 402                 w                         życia w one
# 403               one                         w one czasy
# 404         kosztował        mięsa kosztował dzisiejszych
# 405      dzisiejszych            kosztował dzisiejszych 4
# 406                 4                   dzisiejszych 4 do
# 407                 5                         do 5 centów
# 408            centów                          5 centów –
# 409            korzec                       – korzec owsa
# 410              owsa              korzec owsa cwansigera
# 411        cwansigera                   owsa cwansigera –
# 412                33                      czyli 33 centy
# 413             centy                          33 centy –
# 414              żyta            korzec żyta dzisiejszych
# 415      dzisiejszych                 żyta dzisiejszych 1
# 416                 1                   dzisiejszych 1 fl
# 417                fl                              1 fl –
# 418                10                        korzec 10 do
# 419                14                        do 14 centów
# 420            centów                         14 centów –
# 421           przytem                 mając przytem jakiś
# 422           Panowie                  obrywki Panowie ci
# 423                ci                    Panowie ci mieli
# 424            lepiey                   nieraz lepiey jak
# 425        dzisiejszy             jak dzisiejszy komisarz
# 426          komisarz      dzisiejszy komisarz cyrkularny
# 427        cyrkularny               komisarz cyrkularny .
# 428       Cyrkularnym            Urzędnikom Cyrkularnym –
# 429             ładąn                        – ładąn parą
# 430          siwoszów                     parą siwoszów ,
# 431            pensyi                     brał pensyi 600
# 432               600                       pensyi 600 fl
# 433                fl                            600 fl .
# 434               móy                       gdy móy Dziad
# 435             Dziad               móy Dziad podbierając
# 436         Pokasowce                należały Pokasowce i
# 437         Siedliska                       i Siedliska –
# 438      zakłopotania           wobec zakłopotania nowego
# 439        najbliższy           gromady najbliższy sąsiad
# 440              jego                 doskonale jego Syna
# 441                to                        może to jego
# 442              jego                      to jego samego
# 443            samego                      jego samego bo
# 444            dokoła                obszerna dokoła ławy
# 445              ławy                       dokoła ławy i
# 446              stół                      i stół nakryty
# 447           nakryty                 stół nakryty długim
# 448           bielone              szerokie bielone grube
# 449             grube                    bielone grube po
# 450         zkończone                   białą zkończone )
# 451          bochenek                 nim bochenek chleba
# 452               sól                             i sól –
# 453             dzban                           i dzban –
# 454           niewiem                       – niewiem czy
# 455               czy                       niewiem czy z
# 456                Ty                    mu Ty człowiecze
# 457        człowiecze                    Ty człowiecze na
# 458      nieporadzisz                   mi nieporadzisz –
# 459         chłopisko                gdy chłopisko zaczął
# 460              2000             potrzebuję 2000 Dukatów
# 461           Dukatów                      2000 Dukatów –
# 462         poradzisz                      to poradzisz ?
# 463                 A                         ? A wówczas
# 464         przyniósł              poczekaniu przyniósł i
# 465            Takich                 . Takich gospodarzy
# 466        gospodarzy           Takich gospodarzy jeszcze
# 467                za                    jeszcze za mojey
# 468             mojey                    za mojey pamięci
# 469           liczono             pamięci liczono sześciu
# 470           sześciu                   liczono sześciu w
# 471    Mandatariuszem                  . Mandatariuszem w
# 472           jaszcze                     był jaszcze tam
# 473         księżunio                      , księżunio od
# 474               był                     człowiek był to
# 475            oyciec                     to oyciec owego
# 476             owego            oyciec owego Głoweckiego
# 477       Głoweckiego                 owego Głoweckiego –
# 478             który                   – który przeszedł
# 479         przeszedł                   który przeszedł w
# 480                 w               przeszedł w Lubelskie
# 481         Lubelskie                    w Lubelskie jako
# 482               pop                jako pop szyzmatycki
# 483       szyzmatycki                pop szyzmatycki jako
# 484           renegat                    jako renegat tam
# 485                 I                             . I tak
# 486            późney                  tak późney dokupił
# 487             Dziad                   dokupił Dziad móy
# 488               móy                   Dziad móy Dorchów
# 489           Dorchów                       móy Dorchów i
# 490           Kurypów                         i Kurypów –
# 491     nayjstarszego          osadził nayjstarszego syna
# 492              Toje                         – Toje diło
# 493              diło                    Toje diło daruju
# 494            daruju              diło daruju ukochanomu
# 495        ukochanomu              daruju ukochanomu Synu
# 496              Synu              ukochanomu Synu mojomu
# 497            mojomu              Synu mojomu Mychayłowu
# 498        Mychayłowu                 mojomu Mychayłowu .
# 499          Bludniki                    . Bludniki oddał
# 500             iOycu               Józefowi iOycu mojemu
# 501            mojemu                      iOycu mojemu .
# 502            mojego                     się mojego Oyca
# 503              Oyca                    mojego Oyca pono
# 504              pono                      Oyca pono 1813
# 505              1813                      pono 1813 albo
# 506              1814                         albo 1814 –
# 507              Pana                       – Pana Józefa
# 508            Józefa                   Pana Józefa wziął
# 509               móy                      Dziadek móy do
# 510            Siebie                        do Siebie do
# 511         dośmierci                   aż dośmierci Oyca
# 512              Oyca                 dośmierci Oyca przy
# 513               Nim                   przy Nim zostawał
# 514         ociemniał                   życia ociemniał .
# 515         Zdejmował                      . Zdejmował Mu
# 516                Mu              Zdejmował Mu kataraktę
# 517               ile                         i ile sobie
# 518              1826                        około 1826 .
# 519         Semiginów                własność Semiginów .
# 520            Oyciec             wydzielił Oyciec schedę
# 521              pono                        końcu pono w
# 522          niewinem                     Lipa niewinem .
# 523        Bludnikami                      z Bludnikami o
# 524        Temerowiec                      z Temerowiec ,
# 525        Zabilskich             Stanisława Zabilskich –
# 526          jedynaka                Syna jedynaka Sabina
# 527            Sabina                   jedynaka Sabina .
# 528        doszedłszy                Oycem doszedłszy lat
# 529                24                         około 24 na
# 530         przeszedł              sukcessyi przeszedł po
# 531             synie                         po synie na
# 532           Dorchów              zapisała Dorchów bratu
# 533             bratu               Dorchów bratu swojemu
# 534              temu                      żona temu pono
# 535              pono                         temu pono z
# 536               ten                      , ten zostawił
# 537          zostawił                ten zostawił Dorchów
# 538           Dorchów            zostawił Dorchów swojemu
# 539            niebył                – niebył gospodarzem
# 540            więcey         gospodarzem więcey fantasta
# 541             wgłos                    czytywał wgłos „
# 542              Pana                     „ Pana Tadeusza
# 543          Tadeusza                     Pana Tadeusza ”
# 544            masami            skupował masami poziomki
# 545          poziomki                   masami poziomki i
# 546         Zapraszał                      – Zapraszał do
# 547               tey                     do tey praktyki
# 548                ci                     ale ci niemogli
# 549          niemogli                   ci niemogli długo
# 550          uciekali                        i uciekali .
# 551            wielki             przyszedł wielki piątek
# 552            piątek                     wielki piątek –
# 553          nietylko                  – nietylko czeladź
# 554           czeladź                nietylko czeladź ale
# 555            suszyć                 musiało suszyć więc
# 556             sądny                       więc sądny to
# 557          niemożna              obeyściu niemożna było
# 558             prawa               ukończył prawa bardzo
# 559               był                 bardzo był oczytany
# 560          oczytany                      był oczytany –
# 561          poczciwy                        – poczciwy –
# 562             zacny                       – zacny tylko
# 563             tylko                  zacny tylko raptus
# 564                go                      Zastała go raz
# 565         złożonymi                 ze złożonymi rękoma
# 566            rękoma           złożonymi rękoma nieżywym
# 567          nieżywym                   rękoma nieżywym .
# 568                po                     Sukcesya po mim
# 569               mim                            po mim ,
# 570             część                      której część i
# 571          Siostrom                   On Siostrom swoim
# 572             swoim             Siostrom swoim rodzonym
# 573          rodzonym           swoim rodzonym Treterowej
# 574        Treterowej               rodzonym Treterowej i
# 575       Swieżaskiey                     i Swieżaskiey .
# 576             Panną                       z Panną Julią
# 577        Świeżyńską           Julią Świeżyńską urodzoną
# 578          urodzoną              Świeżyńską urodzoną ze
# 579                ze              urodzoną ze Zawadzkich
# 580        Zawadzkich                     ze Zawadzkich –
# 581          Łukowiec                      wsi Łukowiec w
# 582             kilka               razem kilka generacyi
# 583            jednem                  na jednem obeyściu
# 584               dwa                      było dwa dwory
# 585             dwory                         dwa dwory -
# 586                 2                           - 2 Panny
# 587             Panny                    2 Panny niemając
# 588            jakieś                  jakby jakieś fatum
# 589             fatum                  jakieś fatum Panna
# 590             Panna                   fatum Panna Julia
# 591             Julia                 Panna Julia dostała
# 592           Bludnik               sąsiedztwo Bludnik do
# 593         Martynowa                     do Martynowa do
# 594           Państwa                 do Państwa Rudzkich
# 595          Rudzkich              Państwa Rudzkich gdzie
# 596              były                     gdzie były dwie
# 597              dwie                  były dwie panienki
# 598          panienki                     dwie panienki –
# 599               tąd                        z tąd bywała
# 600             Jakby               . Jakby instynktownie
# 601               jey                     moja jey znieść
# 602          niemogła                   znieść niemogła .
# 603           osiadły                    Józef osiadły na
# 604           talarki           zbijał talarki oszczędzał
# 605            krewni                     to krewni Panny
# 606             niema                że niema sukcessorów
# 607       sukcessorów                 niema sukcessorów ,
# 608         odmłodził              swoją odmłodził piękną
# 609        niechciało          Józefowi niechciało ruszać
# 610              Ojcu              po Ojcu oddziedziczone
# 611    oddziedziczone         Ojcu oddziedziczone znaczne
# 612              sady                  pielęgnował sady i
# 613          odległey                     mil odległey od
# 614        Siemignowa                     od Siemignowa –
# 615              hoża                        się hoża jak
# 616             Panna                   łania Panna Julia
# 617             Julia                       Panna Julia i
# 618         Jegomości             wyswatano Jegomości już
# 619                to                       Było to około
# 620             około                       to około 1829
# 621              tego                małżeństwa tego była
# 622       Siemiginowa           sukcessorka Siemiginowa –
# 623       miejscowość        Józef miejscowość Leśniowice
# 624        Leśniowice            miejscowość Leśniowice z
# 625             życie                 tam życie zakończył
# 626         zakończył                życie zakończył roku
# 627           ciepłey                   ale ciepłey wdowy
# 628             wdowy                     ciepłey wdowy .
# 629        Bałamuciła            . Bałamuciła przebierała
# 630              pana           wybrała pana Szołayskiego
# 631      Szołayskiego          pana Szołayskiego młodzika
# 632          młodzika         Szołayskiego młodzika około
# 633             około                   młodzika około 24
# 634                24                        około 24 lat
# 635         liczącego                     lat liczącego –
# 636          sybarytę                – sybarytę próżniaka
# 637         próżniaka            sybarytę próżniaka toteż
# 638         dwuletnim                      po dwuletnim z
# 639           pożyciu                       nim pożyciu –
# 640           secundo                  Julia secundo voto
# 641              voto              secundo voto Szołayska
# 642           procesa                    lubiła procesa –
# 643               ich                       miała ich też
# 644             sporo                         też sporo –
# 645         przyległe           Lesniowic przyległe Mosty
# 646             Mosty                   przyległe Mosty .
#
#                         Gold Standard                        Prediction
# 0                     subst:sg:nom:m1                   subst:sg:nom:m3
# 1                   adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 2                     subst:sg:nom:m1                   subst:sg:nom:m3
# 3             ppas:sg:nom:m1:perf:aff           ppas:sg:nom:m3:perf:aff
# 4                 subst:sg:nom:n:ncol               subst:sg:acc:n:ncol
# 5                      subst:sg:loc:f                    subst:sg:gen:f
# 6                     subst:sg:nom:m3                   subst:sg:nom:m1
# 7                  adj:sg:inst:m1:com                adj:sg:inst:m3:pos
# 8                    subst:sg:inst:m1                  subst:sg:inst:m3
# 9                            brev:pun           aglt:sg:sec:imperf:nwok
# 10                          brev:npun                          brev:pun
# 11                     subst:sg:gen:f                    subst:pl:nom:f
# 12                    subst:pl:gen:m1                 adj:pl:gen:m1:pos
# 13                  subst:pl:gen:n:pt                   subst:sg:nom:m1
# 14                subst:sg:nom:n:ncol                   subst:sg:nom:m1
# 15                     subst:sg:gen:f                 adj:sg:nom:m3:pos
# 16                          brev:npun                   subst:sg:nom:m3
# 17                    subst:sg:nom:m1                   subst:sg:nom:m3
# 18                  adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 19                 praet:sg:m1:imperf                praet:sg:m3:imperf
# 20                           prep:acc                         prep:inst
# 21                  adj:sg:dat:m1:sup                 adj:pl:gen:m3:sup
# 22                    subst:sg:dat:m1                   subst:sg:gen:m3
# 23             num:pl:acc:m3:rec:ncol                 num:pl:acc:m3:rec
# 24                    subst:pl:gen:m2                   subst:pl:gen:m3
# 25                    subst:pl:acc:m1                   subst:sg:nom:m3
# 26                 praet:sg:m1:imperf                praet:sg:m3:imperf
# 27                           brev:pun                   subst:sg:nom:m3
# 28                    subst:sg:nom:m1                   subst:sg:nom:m3
# 29                num:pl:acc:m1:congr               num:pl:gen:m1:congr
# 30            ppas:sg:acc:m1:perf:aff           ppas:sg:gen:m3:perf:aff
# 31                num:pl:acc:m1:congr                 num:pl:nom:m1:rec
# 32                    subst:pl:acc:m1                   subst:pl:gen:m1
# 33                    subst:sg:acc:m1                   subst:sg:gen:m1
# 34                    subst:sg:acc:m1                   subst:sg:gen:m1
# 35                    subst:sg:acc:m1                   subst:sg:gen:m1
# 36                    subst:sg:acc:m1                   subst:sg:gen:m1
# 37                    subst:sg:acc:m1                   subst:sg:gen:m1
# 38                  adj:pl:acc:m1:pos                  adj:pl:gen:f:pos
# 39                    subst:pl:acc:m1                    subst:pl:gen:f
# 40                  adj:pl:acc:m1:pos                  adj:pl:gen:f:pos
# 41                  num:pl:nom:m1:rec                  adj:sg:nom:f:pos
# 42                    subst:pl:gen:m1                   subst:sg:nom:m1
# 43                    subst:sg:nom:m1                   subst:pl:gen:m1
# 44                    subst:sg:gen:m1                   subst:sg:nom:m1
# 45                  fin:sg:pri:imperf                              part
# 46                    subst:sg:nom:m1                   subst:sg:nom:m3
# 47                   praet:sg:m1:perf                  praet:sg:m3:perf
# 48                   subst:sg:inst:m1                  subst:sg:inst:m3
# 49                subst:sg:acc:n:ncol             ger:sg:acc:n:perf:aff
# 50                 adj:sg:inst:m1:pos                 adj:sg:inst:n:pos
# 51                    subst:pl:gen:m1                  adj:pl:gen:f:pos
# 52                  subst:pl:gen:n:pt               subst:sg:gen:n:ncol
# 53                subst:sg:gen:n:ncol                   subst:sg:gen:m1
# 54                    subst:sg:acc:m1                   subst:sg:gen:m1
# 55                    subst:sg:acc:m1                    subst:sg:acc:f
# 56                    subst:sg:nom:m1                  adj:sg:nom:f:pos
# 57                subst:sg:nom:n:ncol               subst:sg:acc:n:ncol
# 58   ppron3:sg:acc:m1:ter:nakc:npraep  ppron3:sg:acc:m3:ter:nakc:npraep
# 59                            adv:pos               subst:sg:acc:n:ncol
# 60                    subst:sg:acc:m1                   subst:sg:gen:m1
# 61                    subst:sg:acc:m1                   subst:sg:gen:m1
# 62                            adv:pos                              part
# 63                  subst:pl:nom:n:pt                   subst:sg:gen:m1
# 64                subst:sg:gen:n:ncol                   subst:sg:gen:m1
# 65   ppron3:sg:acc:m1:ter:nakc:npraep  ppron3:sg:acc:m3:ter:nakc:npraep
# 66                subst:sg:gen:n:ncol                   subst:sg:gen:m1
# 67                     subst:sg:gen:f                    subst:pl:nom:f
# 68                     subst:sg:nom:f                  impt:sg:sec:perf
# 69                  praet:sg:f:imperf                   praet:sg:f:perf
# 70                   adj:sg:nom:f:pos                    subst:sg:nom:f
# 71    ppron3:sg:loc:m1:ter:akc:npraep   ppron3:sg:gen:m1:ter:akc:npraep
# 72                   praet:sg:m1:perf                  praet:sg:m3:perf
# 73                  adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 74                    subst:sg:nom:m1                   subst:sg:nom:m3
# 75                  adj:sg:nom:m3:pos                    subst:sg:gen:f
# 76            ppas:sg:nom:m1:perf:aff           ppas:sg:nom:m3:perf:aff
# 77               subst:sg:inst:n:ncol                  subst:sg:inst:m3
# 78                               pred               subst:sg:acc:n:ncol
# 79                  subst:pl:acc:n:pt                    subst:sg:gen:f
# 80                  adj:sg:loc:m3:pos               subst:sg:loc:n:ncol
# 81                    subst:sg:inst:f                 adj:sg:inst:f:pos
# 82                num:pl:acc:m1:congr                 num:pl:nom:m1:rec
# 83                    subst:pl:acc:m1                   subst:pl:gen:m1
# 84                    subst:sg:acc:m1                   subst:sg:gen:m1
# 85                    subst:sg:acc:m1                   subst:sg:gen:m1
# 86                    subst:sg:acc:m1                   subst:sg:gen:m1
# 87                   praet:sg:m1:perf                praet:sg:m1:imperf
# 88                   subst:pl:inst:m2                   subst:pl:inst:f
# 89                   adj:sg:loc:f:pos                   subst:sg:gen:m1
# 90                   praet:pl:m2:perf                   praet:pl:f:perf
# 91                    subst:pl:nom:m2                   subst:pl:nom:m3
# 92                   num:pl:acc:f:rec                  num:pl:nom:f:rec
# 93                     subst:sg:nom:f                   subst:sg:gen:m3
# 94                     subst:sg:nom:f                   subst:sg:gen:m3
# 95                num:pl:loc:m1:congr               num:pl:loc:m3:congr
# 96                    subst:pl:loc:m1                   subst:pl:loc:m3
# 97                               comp                              part
# 98                subst:sg:loc:n:ncol             ger:sg:loc:n:perf:aff
# 99                  adj:sg:inst:n:pos                adj:sg:inst:m3:pos
# 100              subst:sg:inst:n:ncol                  subst:sg:inst:m3
# 101                  adj:sg:nom:f:pos                    subst:sg:nom:f
# 102                    subst:sg:nom:f                  adj:sg:nom:f:pos
# 103                   subst:sg:dat:m1                   subst:sg:dat:m3
# 104                subst:sg:acc:n:col               subst:sg:acc:n:ncol
# 105                    subst:sg:voc:f                    subst:sg:nom:f
# 106               subst:sg:acc:n:ncol               subst:sg:nom:n:ncol
# 107                    subst:sg:nom:f                  adj:sg:nom:f:pos
# 108                   subst:sg:nom:m1                          inf:perf
# 109              ppron12:sg:nom:f:pri             ppron12:sg:nom:m1:pri
# 110                              comp                              part
# 111         ppron12:sg:dat:f:pri:nakc        ppron12:sg:dat:m1:pri:nakc
# 112                   subst:sg:nom:m1                    subst:sg:nom:f
# ...
# 431                              part                    subst:pl:acc:f
# 432                 num:pl:acc:m2:rec                  num:pl:acc:f:rec
# 433                         brev:npun                    subst:pl:gen:f
# 434                 adj:sg:nom:m1:pos                 adj:sg:acc:m3:pos
# 435                   subst:sg:nom:m1                   subst:sg:acc:m3
# 436                    subst:pl:nom:f                    subst:sg:dat:f
# 437                 subst:pl:nom:n:pt               subst:sg:gen:n:ncol
# 438               subst:sg:gen:n:ncol             ger:sg:gen:n:perf:aff
# 439                 adj:sg:nom:m1:sup                 adj:sg:acc:m3:sup
# 440   ppron3:sg:gen:m1:ter:akc:npraep   ppron3:sg:gen:m3:ter:akc:npraep
# 441                              part                              pred
# 442   ppron3:sg:acc:m1:ter:akc:npraep   ppron3:sg:gen:m1:ter:akc:npraep
# 443                 adj:sg:acc:m1:pos                 adj:sg:gen:m1:pos
# 444                          prep:gen                               adv
# 445                    subst:sg:nom:f                    subst:pl:acc:f
# 446                   subst:sg:nom:m3                   subst:sg:acc:m3
# 447           ppas:sg:nom:m3:perf:aff           ppas:sg:acc:m3:perf:aff
# 448          ppas:sg:nom:n:imperf:aff                  adj:sg:nom:n:pos
# 449                  adj:sg:nom:n:pos                  adj:pl:acc:f:pos
# 450            ppas:sg:acc:n:perf:aff            ppas:pl:nom:f:perf:aff
# 451                   subst:sg:nom:m3                   subst:sg:acc:m3
# 452                    subst:sg:nom:f                   subst:sg:nom:m3
# 453                   subst:sg:nom:m3               subst:sg:nom:n:ncol
# 454                 fin:sg:pri:imperf              subst:sg:inst:n:ncol
# 455                              part                              conj
# 456             ppron12:sg:voc:m1:sec             ppron12:sg:nom:m1:sec
# 457                   subst:sg:voc:m1                 fin:sg:ter:imperf
# 458                   fin:sg:sec:perf                 fin:sg:sec:imperf
# 459               subst:sg:nom:n:ncol               subst:sg:acc:n:ncol
# 460                 num:pl:acc:m2:rec                  num:pl:acc:f:rec
# 461                   subst:pl:gen:m2                   subst:pl:gen:m1
# 462                   fin:sg:sec:perf                 fin:sg:sec:imperf
# 463                              conj                              part
# 464             praet:sg:m1:perf:nagl             praet:sg:m3:perf:nagl
# 465                 adj:pl:acc:m1:pos                 adj:pl:gen:m1:pos
# 466                   subst:pl:acc:m1                   subst:pl:gen:m1
# 467                          prep:gen                          prep:acc
# 468                  adj:sg:gen:f:pos                   subst:pl:acc:m3
# 469                       imps:imperf                         imps:perf
# 470               num:pl:acc:m1:congr                 num:pl:nom:m1:rec
# 471                  subst:sg:inst:m1                  subst:sg:inst:m3
# 472                              part                  adj:pl:nom:f:pos
# 473                   subst:sg:nom:m1                              conj
# 474                praet:sg:m1:imperf                praet:sg:m3:imperf
# 475                   subst:sg:nom:m1                   subst:sg:nom:m3
# 476                 adj:sg:gen:m1:pos                 adj:sg:gen:m3:pos
# 477                   subst:sg:gen:m1                   subst:sg:gen:m3
# 478                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 479                  praet:sg:m1:perf                  praet:sg:m3:perf
# 480                     prep:acc:nwok                     prep:loc:nwok
# 481                  adj:sg:acc:n:pos                   subst:sg:loc:m3
# 482                   subst:sg:nom:m1                   subst:sg:nom:m3
# 483                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 484                   subst:sg:nom:m1                   subst:sg:nom:m3
# 485                              conj                              part
# 486                           adv:com                              comp
# 487                   subst:sg:nom:m1                   subst:sg:acc:m3
# 488                 adj:sg:nom:m1:pos                 adj:sg:acc:m3:pos
# 489                   subst:sg:acc:m3                   subst:pl:gen:m1
# 490                   subst:sg:acc:m3                   subst:pl:gen:m1
# 491                 adj:sg:acc:m1:sup                 adj:sg:acc:m1:pos
# 492                               ign               subst:sg:nom:n:ncol
# 493                               ign                   praet:sg:n:perf
# 494                               ign                   subst:sg:gen:m3
# 495                               ign                   subst:sg:gen:m3
# 496                               ign                   subst:sg:gen:m3
# 497                               ign                   subst:sg:gen:m3
# 498                               ign                   subst:sg:gen:m3
# 499                 subst:pl:nom:n:pt                   subst:sg:nom:m1
# 500                   subst:sg:dat:m1                   subst:sg:gen:m3
# 501                 adj:sg:dat:m1:pos                 adj:sg:gen:m3:pos
# 502                 adj:sg:gen:m1:pos                 adj:sg:acc:m1:pos
# 503                   subst:sg:gen:m1                   subst:sg:acc:m1
# 504                              part                         imps:perf
# 505                 adj:sg:gen:m3:pos                               dig
# 506                 adj:sg:gen:m3:pos                               dig
# 507                   subst:sg:acc:m1                   subst:sg:gen:m1
# 508                   subst:sg:acc:m1                   subst:sg:gen:m1
# 509                 adj:sg:nom:m1:pos                    subst:sg:gen:f
# 510                        siebie:gen                    subst:sg:gen:f
# 511                    subst:pl:gen:f                   subst:pl:nom:m1
# 512                   subst:sg:gen:m1                   subst:sg:gen:m3
# 513    ppron3:sg:loc:m1:ter:akc:praep               subst:sg:loc:n:ncol
# 514                praet:sg:m1:imperf                  praet:sg:m1:perf
# 515                praet:sg:m1:imperf                  praet:sg:m1:perf
# 516  ppron3:sg:dat:m1:ter:nakc:npraep                   subst:sg:dat:m1
# 517                               adv                 num:pl:acc:m3:rec
# 518                 adj:sg:gen:m3:pos                               dig
# 519                   subst:pl:acc:m1                   subst:pl:gen:m1
# 520                   subst:sg:nom:m1                    subst:sg:acc:f
# 521                              part                         imps:perf
# 522                 fin:sg:pri:imperf                  subst:sg:inst:m3
# 523                subst:pl:inst:n:pt                  subst:pl:inst:m1
# 524               subst:pl:gen:n:ncol                 subst:pl:gen:n:pt
# 525                   subst:pl:gen:m1                  adj:pl:gen:f:pos
# 526                   subst:sg:acc:m1                  adj:sg:nom:f:pos
# 527                   subst:sg:acc:m1                    subst:sg:nom:f
# 528                         pant:perf                   fin:sg:ter:perf
# 529               num:pl:gen:m3:congr                 adj:sg:gen:m3:pos
# 530                  praet:sg:m3:perf                  praet:sg:m1:perf
# 531                   subst:sg:loc:m3                    subst:sg:loc:f
# 532                   subst:pl:acc:m3                   subst:pl:acc:m1
# 533                   subst:sg:dat:m1                   subst:sg:gen:m3
# 534               subst:sg:dat:n:ncol                          prep:acc
# 535                              part                         imps:perf
# 536                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 537                  praet:sg:m1:perf                  praet:sg:m3:perf
# 538                   subst:pl:acc:m1                   subst:pl:gen:m3
# 539               praet:sg:ter:imperf                praet:sg:m1:imperf
# 540                           adv:com                 adj:sg:nom:m1:pos
# 541                               adv                   subst:sg:acc:m3
# 542                   subst:sg:acc:m1                   subst:sg:gen:m1
# 543                   subst:sg:acc:m1                   subst:sg:gen:m1
# 544                   subst:pl:inst:f                  subst:pl:inst:m3
# 545                    subst:pl:acc:f                    subst:sg:gen:f
# 546                praet:sg:m1:imperf                  praet:sg:m1:perf
# 547                  adj:sg:gen:f:pos                    subst:sg:gen:f
# 548        ppron12:sg:dat:m1:sec:nakc                 adj:pl:nom:m1:pos
# 549                praet:pl:m1:imperf                   subst:pl:nom:m1
# 550                praet:pl:m1:imperf                  praet:pl:m1:perf
# 551                 adj:sg:nom:m3:pos                 adj:sg:acc:m3:pos
# 552                   subst:sg:nom:m3                   subst:sg:acc:m3
# 553                              conj                           adv:pos
# 554                    subst:sg:nom:f                impt:sg:sec:imperf
# 555                        inf:imperf                          inf:perf
# 556                 adj:sg:nom:m3:pos                   subst:pl:nom:m3
# 557                              pred                  adj:sg:nom:f:pos
# 558               subst:pl:acc:n:ncol               subst:sg:gen:n:ncol
# 559                praet:sg:m1:imperf                praet:sg:m3:imperf
# 560           ppas:sg:nom:m1:perf:aff                 adj:sg:nom:m3:pos
# 561                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 562                 adj:sg:nom:m1:pos                 adj:sg:nom:m3:pos
# 563                              conj                              part
# 564  ppron3:sg:acc:m1:ter:nakc:npraep  ppron3:sg:acc:m3:ter:nakc:npraep
# 565                 adj:pl:inst:f:pos           ppas:pl:inst:f:perf:aff
# 566                   subst:pl:inst:f                  subst:sg:inst:m3
# 567                 adj:pl:inst:f:pos                adj:sg:inst:m3:pos
# 568                          prep:acc                          prep:loc
# 569    ppron3:sg:acc:m1:ter:akc:praep                 adj:sg:loc:m3:pos
# 570                    subst:sg:nom:f                    subst:sg:acc:f
# 571                    subst:pl:dat:f                   subst:pl:dat:m1
# 572                  adj:sg:dat:f:pos                 adj:pl:dat:m1:pos
# 573          ppas:sg:dat:f:imperf:aff                   subst:pl:dat:m1
# 574                    subst:sg:dat:f                  adj:sg:gen:f:pos
# 575                    subst:sg:dat:f                   subst:sg:nom:m1
# 576                   subst:sg:inst:f                 adj:sg:inst:f:pos
# 577                   subst:sg:inst:f                 adj:sg:inst:f:pos
# 578                ppas:sg:inst:f:pos                   subst:sg:inst:f
# 579                      prep:gen:wok                     prep:inst:wok
# 580                   subst:pl:gen:m1                 adj:pl:gen:m1:pos
# 581                   subst:sg:nom:m3                   subst:sg:nom:m1
# 582                  num:pl:nom:f:rec                  num:pl:acc:f:rec
# 583                  adj:sg:loc:n:pos               subst:sg:loc:n:ncol
# 584               num:pl:nom:m3:congr               num:pl:acc:m3:congr
# 585                   subst:pl:nom:m3                   subst:pl:acc:m3
# 586                num:pl:nom:f:congr                  adj:sg:gen:f:pos
# 587                    subst:pl:nom:f                    subst:sg:gen:f
# 588                  adj:sg:acc:n:pos                  adj:sg:nom:n:pos
# 589               subst:sg:acc:n:ncol               subst:sg:nom:n:ncol
# 590                    subst:sg:nom:f                   subst:sg:gen:m1
# 591                    subst:sg:nom:f                   subst:sg:gen:m1
# 592                 subst:pl:gen:n:pt                   subst:sg:nom:m1
# 593                   subst:sg:gen:m3               subst:sg:gen:n:ncol
# 594               subst:pl:gen:n:ncol               subst:sg:gen:n:ncol
# 595                  adj:pl:gen:n:pos                 adj:pl:gen:m3:pos
# 596                 praet:pl:f:imperf                 praet:pl:n:imperf
# 597                num:pl:nom:f:congr                num:pl:acc:f:congr
# 598                    subst:pl:nom:f                    subst:pl:acc:f
# 599                               adv                    subst:pl:gen:f
# 600                              comp                              part
# 601  ppron3:sg:gen:m1:ter:nakc:npraep                   subst:pl:nom:m2
# 602                 praet:sg:f:imperf                   subst:sg:acc:m1
# 603           ppas:sg:nom:m1:perf:aff                   praet:pl:f:perf
# 604                   subst:pl:nom:m2                    subst:pl:acc:f
# 605                   subst:pl:nom:m1                    subst:sg:nom:f
# 606                 fin:sg:ter:imperf                    subst:sg:nom:f
# 607                   subst:pl:gen:m1                   subst:pl:gen:m3
# 608                  praet:sg:m1:perf                  praet:sg:m3:perf
# 609                 praet:sg:n:imperf                           adv:pos
# 610                   subst:sg:loc:m1                   subst:sg:loc:m3
# 611            ppas:sg:acc:n:perf:aff                  adj:sg:acc:n:pos
# 612                   subst:pl:acc:m3                    subst:pl:acc:f
# 613                  adj:sg:gen:f:pos           ppas:sg:nom:m3:perf:aff
# 614                   subst:sg:gen:m1                   subst:sg:gen:m3
# 615                  adj:sg:nom:f:pos                    subst:sg:nom:f
# 616                    subst:sg:nom:f                   subst:sg:gen:m1
# 617                    subst:sg:nom:f                   subst:sg:gen:m1
# 618                   subst:pl:acc:m1                    subst:pl:acc:f
# 619                              pred               subst:sg:nom:n:ncol
# 620                          prep:gen                              part
# 621                  adj:sg:gen:n:pos               subst:sg:gen:n:ncol
# 622                    subst:sg:gen:f                  adj:sg:nom:f:pos
# 623                    subst:sg:acc:f                   subst:sg:nom:m1
# 624                 subst:pl:acc:n:pt                   subst:sg:nom:m1
# 625               subst:sg:nom:n:ncol               subst:sg:acc:n:ncol
# 626                  praet:sg:m1:perf                  praet:sg:m3:perf
# 627                  adj:sg:gen:f:pos                 adj:sg:nom:m1:pos
# 628                    subst:sg:gen:f                   subst:sg:nom:m1
# 629                 praet:sg:f:imperf                    subst:sg:nom:f
# 630                   subst:sg:acc:m1                   subst:sg:gen:m1
# 631                   subst:sg:acc:m1                   subst:sg:gen:m1
# 632                   subst:sg:acc:m1                   subst:sg:gen:m1
# 633                          prep:gen                              part
# 634                 num:pl:acc:m3:rec               num:pl:gen:m3:congr
# 635         pact:sg:acc:m1:imperf:aff                   subst:sg:gen:m1
# 636                   subst:sg:acc:m1                    subst:sg:acc:f
# 637                   subst:sg:acc:m1                 fin:sg:ter:imperf
# 638                  adj:sg:loc:n:pos                 adj:sg:loc:m3:pos
# 639                   subst:sg:loc:m3             ger:sg:loc:n:perf:aff
# 640                               ign                           adv:pos
# 641                               ign                         imps:perf
# 642                   subst:sg:acc:m3                    subst:sg:nom:f
# 643   ppron3:pl:gen:m3:ter:akc:npraep   ppron3:pl:acc:m1:ter:akc:npraep
# 644                 num:pl:acc:m3:rec                 num:pl:nom:m3:rec
# 645                 adj:pl:acc:m3:pos                 adj:pl:nom:m3:pos
# 646                 subst:pl:acc:n:pt                   subst:pl:nom:m3
